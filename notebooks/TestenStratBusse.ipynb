# %% [markdown]
# # Testen Strat Busse
#
# In dit notebook wordt kort getest of de strategie Busse werkt in de code.
# We beginnen met het importeren van de nodige functies en classes.

# %%
import sys
import os

# Ophalen path van de src folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Voeg de folder to aan path
if src_path not in sys.path:
    sys.path.append(src_path)

# Importeren van src is nu mogelijk
from utils import ZweedsPesten

# %% [markdown]
# Nu kunnen we speler namen (player_names) definiëren en de game opstarten en uitvoeren.

# %%
# Lijst met spelers
player_names = ["jasper", "busse", "tim", "natasja", "low", "justice_and_terror"]

# Opstarten spel met speler lijst
game = ZweedsPesten(player_names)

# Simuleren van een enkele game
winners = game.game_loop(verbose=2)
# Out:
# ------------ Starting Game ------------
# jasper:
# Hand:       ['♠K', '♦8', '♠4']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
# -----------------------------------------
# busse:
# Hand:       ['♠6', '♠8', '♦7']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
# -----------------------------------------
# tim:
# Hand:       ['♠7', '♠5', '♦J']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
# -----------------------------------------
# natasja:
# Hand:       ['♥A', '♥4', '♥J']
# Displayed:  ['♣2', '♦2', '♥2']
# Hidden:     ['♥5', '♣K', '♥3']
# -----------------------------------------
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠K', '♦8', '♠4']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♠K', '♦8', '♠4']
# jasper plays ♠4 from hand.
# jasper draws a card: ♥K
#
# busse's turn
# Top of stack:   ♠4
# Hand:       ['♠6', '♠8', '♦7']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠6', '♠8', '♦7', 'take']
# busse plays ♠6 from hand.
# busse draws a card: ♣9
#
# tim's turn
# Top of stack:   ♠6
# Hand:       ['♠7', '♠5', '♦J']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♠7', '♦J', 'take']
# tim plays ♠7 from hand.
# tim draws a card: ♠3
#
# natasja's turn
# Top of stack:   ♠7
# Hand:       ['♥A', '♥4', '♥J']
# Displayed:  ['♣2', '♦2', '♥2']
# Hidden:     ['♥5', '♣K', '♥3']
#
# Playable cards: ['♥4', 'take']
# natasja plays ♥4 from hand.
# natasja draws a card: ♣J
#
# jasper's turn
# Top of stack:   ♥4
# Hand:       ['♠K', '♦8', '♥K']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♠K', '♦8', '♥K', 'take']
# jasper plays ♦8 from hand.
# jasper draws a card: ♣8
#
# busse's turn
# Top of stack:   ♦8
# Hand:       ['♠8', '♦7', '♣9']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠8', '♣9', 'take']
# busse plays ♠8 from hand.
# busse draws a card: ♣7
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♠5', '♦J', '♠3']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♦J', '♠3', 'take']
# tim plays ♦J from hand.
# tim draws a card: ♣4
#
# natasja's turn
# Top of stack:   ♦J
# Hand:       ['♥A', '♥J', '♣J']
# Displayed:  ['♣2', '♦2', '♥2']
# Hidden:     ['♥5', '♣K', '♥3']
#
# Playable cards: ['♥A', '♥J', '♣J', 'take']
# natasja plays ♥A from hand.
# natasja draws a card: ♠J
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       ['♠K', '♥K', '♣8']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['take']
# jasper takes the stack (8 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦7', '♣9', '♣7']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♦7', '♣9', '♣7']
# busse plays ♦7 from hand.
# busse can play a double card (7).
# busse plays ♣7 from hand.
# busse draws a card: ♠Q
# busse draws a card: ♦9
#
# tim's turn
# Top of stack:   ♣7
# Hand:       ['♠5', '♠3', '♣4']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♠5', '♣4', 'take']
# tim plays ♣4 from hand.
# tim draws a card: ♦4
#
# natasja's turn
# Top of stack:   ♣4
# Hand:       ['♥J', '♣J', '♠J']
# Displayed:  ['♣2', '♦2', '♥2']
# Hidden:     ['♥5', '♣K', '♥3']
#
# Playable cards: ['♥J', '♣J', '♠J', 'take']
# natasja plays ♥J from hand.
# natasja can play a double card (J).
# natasja plays ♣J from hand.
# natasja can play a double card (J).
# natasja plays ♠J from hand.
# natasja draws a card: ♦K
# natasja draws a card: ♣10
# natasja draws a card: ♦6
#
# jasper's turn
# Top of stack:   ♠J
# Hand:       ['♠K', '♥K', '♣8', '♠4', '♠6', '♠7', '♥4', '♦8', '♠8', '♦J', '♥A']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♠K', '♥K', '♦J', '♥A', 'take']
# jasper plays ♦J from hand.
# Four of a kind detected - Stack cleared!
# jasper can play a double card (4).
# jasper plays ♥4 from hand.
#
# busse's turn
# Top of stack:   ♥4
# Hand:       ['♣9', '♠Q', '♦9']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♣9', '♠Q', '♦9', 'take']
# busse plays ♣9 from hand.
# busse can play a double card (9).
# busse plays ♦9 from hand.
# busse draws a card: ♥8
# busse draws a card: ♥7
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♠5', '♠3', '♦4']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♠3', 'take']
# tim plays ♠3 from hand.
# tim played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♠5', '♦4']
#
# natasja's turn
# Top of stack:   ♦4
# Hand:       ['♦K', '♣10', '♦6']
# Displayed:  ['♣2', '♦2', '♥2']
# Hidden:     ['♥5', '♣K', '♥3']
#
# Playable cards: ['♦K', '♣10', '♦6', 'take']
# natasja plays ♣10 from hand.
#
# jasper's turn
# Top of stack:   ♣10
# Hand:       ['♠K', '♥K', '♣8', '♠6', '♠7', '♦8', '♠8', '♥A']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♠K', '♥K', '♣8', '♠6', '♠7', '♦8', '♠8', '♥A', 'take']
# jasper plays ♠6 from hand.
#
# busse's turn
# Top of stack:   ♠6
# Hand:       ['♠Q', '♥8', '♥7']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠Q', '♥8', '♥7', 'take']
# busse plays ♥7 from hand.
#
# tim's turn
# Top of stack:   ♥7
# Hand:       ['♠5']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♠5', 'take']
# tim plays ♠5 from hand.
#
# natasja's turn
# Top of stack:   ♠5
# Hand:       ['♦K', '♦6']
# Displayed:  ['♣2', '♦2', '♥2']
# Hidden:     ['♥5', '♣K', '♥3']
#
# Playable cards: ['♦K', '♦6', 'take']
# natasja plays ♦6 from hand.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♠K', '♥K', '♣8', '♠7', '♦8', '♠8', '♥A']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♠K', '♥K', '♣8', '♠7', '♦8', '♠8', '♥A', 'take']
# jasper plays ♠7 from hand.
#
# busse's turn
# Top of stack:   ♠7
# Hand:       ['♠Q', '♥8']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['take']
# busse takes the stack (7 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♠2', '♥10', '♠10']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦K']
# Displayed:  ['♣2', '♦2', '♥2']
# Hidden:     ['♥5', '♣K', '♥3']
#
# Playable cards: ['♦K']
# natasja plays ♦K from hand.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       ['♠K', '♥K', '♣8', '♦8', '♠8', '♥A']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♠K', '♥K', '♥A', 'take']
# jasper plays ♠K from hand.
# jasper can play a double card (K).
# jasper plays ♥K from hand.
#
# busse's turn
# Top of stack:   ♥K
# Hand:       ['♠Q', '♥8', '♦4', '♣10', '♠6', '♥7', '♠5', '♦6', '♠7']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♣10', 'take']
# busse plays ♣10 from hand.
#
# tim's turn
# Top of stack:   ♣10
# Hand:       []
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♠2', '♥10', '♠10', 'take']
# tim takes the stack (4 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♣2', '♦2', '♥2']
# Hidden:     ['♥5', '♣K', '♥3']
#
# Playable cards: ['♣2', '♦2', '♥2']
# natasja plays ♣2 from displayed.
# natasja can play a double card (2).
# natasja plays ♦2 from displayed.
# natasja can play a double card (2).
# natasja plays ♥2 from displayed.
#
# jasper's turn
# Top of stack:   ♥2
# Hand:       ['♣8', '♦8', '♠8', '♥A']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♣8', '♦8', '♠8', '♥A', 'take']
# jasper plays ♣8 from hand.
# jasper can play a double card (8).
# jasper plays ♦8 from hand.
# jasper can play a double card (8).
# jasper plays ♠8 from hand.
#
# busse's turn
# Top of stack:   ♠8
# Hand:       ['♠Q', '♥8', '♦4', '♠6', '♥7', '♠5', '♦6', '♠7']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠Q', '♥8', 'take']
# busse plays ♥8 from hand.
# Four of a kind detected - Stack cleared!
#
# tim's turn
# Top of stack:   ♦4
# Hand:       ['♦K', '♠K', '♥K', '♣10']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♦K', '♠K', '♥K', '♣10', 'take']
# tim plays ♣10 from hand.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       []
# Displayed:  []
# Hidden:     ['♥5', '♣K', '♥3']
#
# Playable cards: ['♥3', 'take']
# natasja plays ♥3 from hidden.
# natasja played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♣K']
#
# jasper's turn
# Top of stack:   ♣K
# Hand:       ['♥A']
# Displayed:  ['♣3', '♠A', '♣A']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♥A', 'take']
# jasper plays ♥A from hand.
# jasper can play a double card (A).
# jasper plays ♠A from displayed.
# jasper can play a double card (A).
# jasper plays ♣A from displayed.
#
# busse's turn
# Top of stack:   ♣A
# Hand:       ['♠Q', '♠6', '♥7', '♠5', '♦6', '♠7']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦K', '♠K', '♥K']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♦K', '♠K', '♥K']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♥5']
#
# Playable cards: ['♥5']
# natasja plays ♥5 from hidden.
# natasja has won the game!
#
# jasper's turn
# Top of stack:   ♥5
# Hand:       []
# Displayed:  ['♣3']
# Hidden:     ['♦A', '♦5', '♣6']
#
# Playable cards: ['♣3', 'take']
# jasper plays ♣3 from displayed.
# jasper played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♣6']
#
# busse's turn
# Top of stack:   ♣6
# Hand:       ['♠Q', '♠6', '♥7', '♠5', '♦6', '♠7', '♣K', '♥A', '♠A', '♣A']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠Q', '♠6', '♥7', '♦6', '♠7', '♣K', '♥A', '♠A', '♣A', 'take']
# busse plays ♠6 from hand.
# busse can play a double card (6).
# busse plays ♦6 from hand.
#
# tim's turn
# Top of stack:   ♦6
# Hand:       ['♦K', '♠K', '♥K']
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♦K', '♠K', '♥K', 'take']
# tim plays ♦K from hand.
# tim can play a double card (K).
# tim plays ♥K from hand.
# tim can play a double card (K).
# tim plays ♠K from hand.
#
# jasper's turn
# Top of stack:   ♠K
# Hand:       []
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (6 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠Q', '♥7', '♠5', '♠7', '♣K', '♥A', '♠A', '♣A']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠Q', '♥7', '♠5', '♠7', '♣K', '♥A', '♠A', '♣A']
# busse plays ♠5 from hand.
#
# tim's turn
# Top of stack:   ♠5
# Hand:       []
# Displayed:  ['♠2', '♥10', '♠10']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♠2', '♥10', '♠10', 'take']
# tim plays ♥10 from displayed.
# tim can play a double card (10).
# tim plays ♠10 from displayed.
#
# jasper's turn
# Top of stack:   ♠10
# Hand:       ['♣6', '♠6', '♦6', '♦K', '♥K', '♠K']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♣6', '♠6', '♦6', '♦K', '♥K', '♠K', 'take']
# jasper plays ♣6 from hand.
# jasper can play a double card (6).
# jasper plays ♠6 from hand.
# jasper can play a double card (6).
# jasper plays ♦6 from hand.
#
# busse's turn
# Top of stack:   ♦6
# Hand:       ['♠Q', '♥7', '♠7', '♣K', '♥A', '♠A', '♣A']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠Q', '♥7', '♠7', '♣K', '♥A', '♠A', '♣A', 'take']
# busse plays ♥7 from hand.
# busse can play a double card (7).
# busse plays ♠7 from hand.
#
# tim's turn
# Top of stack:   ♠7
# Hand:       []
# Displayed:  ['♠2']
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♠2', 'take']
# tim plays ♠2 from displayed.
#
# jasper's turn
# Top of stack:   ♠2
# Hand:       ['♦K', '♥K', '♠K']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦K', '♥K', '♠K', 'take']
# jasper plays ♦K from hand.
# jasper can play a double card (K).
# jasper plays ♥K from hand.
# jasper can play a double card (K).
# jasper plays ♠K from hand.
#
# busse's turn
# Top of stack:   ♠K
# Hand:       ['♠Q', '♣K', '♥A', '♠A', '♣A']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♣K', '♥A', '♠A', '♣A', 'take']
# busse plays ♣K from hand.
# Four of a kind detected - Stack cleared!
#
# tim's turn
# Top of stack:   ♠Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♣5', '♥9', '♦3']
#
# Playable cards: ['♦3', 'take']
# tim plays ♦3 from hidden.
# tim played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♥9']
#
# jasper's turn
# Top of stack:   ♥9
# Hand:       []
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥A', '♠A', '♣A']
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♥A', '♠A', '♣A']
# busse plays ♥A from hand.
# busse can play a double card (A).
# busse plays ♠A from hand.
# busse can play a double card (A).
# busse plays ♣A from hand.
#
# tim's turn
# Top of stack:   ♣A
# Hand:       []
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥9']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥9']
# jasper takes the stack (0 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥Q', '♦Q', '♠9']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♥Q', '♦Q', '♠9']
# busse plays ♠9 from displayed.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♥A', '♠A', '♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥A', '♠A', '♣A', 'take']
# tim plays ♥A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       ['♥9']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥Q', '♦Q']
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♥Q', '♦Q']
# busse plays ♥Q from displayed.
# busse can play a double card (Q).
# busse plays ♦Q from displayed.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♠A', '♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♠A', '♣A', 'take']
# tim plays ♠A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♥9', '♠9', '♥A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥A', 'take']
# jasper plays ♥A from hand.
#
# busse's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♣A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥9', '♠9']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥9', '♠9']
# jasper plays ♥9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       ['♥Q', '♦Q', '♠A', '♥A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♥Q', '♦Q', '♠A', '♥A', 'take']
# busse plays ♥Q from hand.
# busse can play a double card (Q).
# busse plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♣A', 'take']
# tim plays ♣A from hand.
#
# jasper's turn
# Top of stack:   ♣A
# Hand:       []
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠A', '♥A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠A', '♥A']
# busse plays ♠A from hand.
# busse can play a double card (A).
# busse plays ♥A from hand.
#
# tim's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥9', '♠9', '♥Q', '♦Q', '♣A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥9', '♠9', '♥Q', '♦Q', '♣A']
# jasper plays ♥9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       []
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠A', '♥A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♠A', '♥A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦Q', '♣A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥Q', '♦Q', '♣A']
# jasper plays ♥Q from hand.
# jasper can play a double card (Q).
# jasper plays ♦Q from hand.
#
# busse's turn
# Top of stack:   ♦Q
# Hand:       ['♥9', '♠9']
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠A', '♥A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♠A', '♥A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♣A']
# jasper takes the stack (0 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥9', '♠9', '♥Q', '♦Q']
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♥9', '♠9', '♥Q', '♦Q']
# busse plays ♥9 from hand.
# busse can play a double card (9).
# busse plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♠A', '♥A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♠A', '♥A', 'take']
# tim plays ♠A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♣A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♣A', 'take']
# jasper plays ♣A from hand.
#
# busse's turn
# Top of stack:   ♣A
# Hand:       ['♥Q', '♦Q']
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦5']
# jasper takes the stack (0 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦Q', '♥9', '♠9', '♠A', '♣A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♥Q', '♦Q', '♥9', '♠9', '♠A', '♣A']
# busse plays ♥9 from hand.
# busse can play a double card (9).
# busse plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♥A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥A', 'take']
# tim plays ♥A from hand.
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦Q', '♠A', '♣A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♥Q', '♦Q', '♠A', '♣A']
# busse plays ♥Q from hand.
# busse can play a double card (Q).
# busse plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥9', '♠9', '♥A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥9', '♠9', '♥A']
# jasper plays ♥9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       ['♠A', '♣A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♠A', '♣A', 'take']
# busse plays ♠A from hand.
# busse can play a double card (A).
# busse plays ♣A from hand.
#
# tim's turn
# Top of stack:   ♣A
# Hand:       ['♥Q', '♦Q']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥A']
# jasper takes the stack (0 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦10', '♣Q', '♥6']
#
# Playable cards: ['♥6']
# busse plays ♥6 from hidden.
#
# tim's turn
# Top of stack:   ♥6
# Hand:       ['♥Q', '♦Q', '♥9', '♠9', '♠A', '♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥Q', '♦Q', '♥9', '♠9', '♠A', '♣A', 'take']
# tim plays ♥9 from hand.
# tim can play a double card (9).
# tim plays ♠9 from hand.
#
# jasper's turn
# Top of stack:   ♠9
# Hand:       ['♥A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥A', 'take']
# jasper plays ♥A from hand.
#
# busse's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  []
# Hidden:     ['♦10', '♣Q']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦Q', '♠A', '♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥Q', '♦Q', '♠A', '♣A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦5']
# jasper takes the stack (0 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥A']
# busse plays ♥6 from hand.
#
# tim's turn
# Top of stack:   ♥6
# Hand:       ['♥Q', '♦Q', '♠A', '♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥Q', '♦Q', '♠A', '♣A', 'take']
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim plays ♦Q from hand.
#
# jasper's turn
# Top of stack:   ♦Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥9', '♠9', '♥A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q']
#
# Playable cards: ['♥9', '♠9', '♥A']
# busse plays ♥9 from hand.
# busse can play a double card (9).
# busse plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♠A', '♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♠A', '♣A', 'take']
# tim plays ♠A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♥6', '♥Q', '♦Q']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q']
#
# Playable cards: ['♥A']
# busse plays ♥A from hand.
#
# tim's turn
# Top of stack:   ♥A
# Hand:       ['♣A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♣A', 'take']
# tim plays ♣A from hand.
#
# jasper's turn
# Top of stack:   ♣A
# Hand:       ['♥6', '♥Q', '♦Q', '♥9', '♠9', '♠A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♠A', 'take']
# jasper plays ♠A from hand.
#
# busse's turn
# Top of stack:   ♠A
# Hand:       []
# Displayed:  []
# Hidden:     ['♦10', '♣Q']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♣5']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥Q', '♦Q', '♥9', '♠9']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥6', '♥Q', '♦Q', '♥9', '♠9']
# jasper plays ♥6 from hand.
#
# busse's turn
# Top of stack:   ♥6
# Hand:       ['♥A', '♣A', '♠A']
# Displayed:  []
# Hidden:     ['♦10', '♣Q']
#
# Playable cards: ['♥A', '♣A', '♠A', 'take']
# busse plays ♥A from hand.
# busse can play a double card (A).
# busse plays ♣A from hand.
# busse can play a double card (A).
# busse plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       []
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦Q', '♥9', '♠9']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥Q', '♦Q', '♥9', '♠9']
# jasper plays ♥9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       []
# Displayed:  []
# Hidden:     ['♦10', '♣Q']
#
# Playable cards: ['♣Q', 'take']
# busse plays ♣Q from hidden.
#
# tim's turn
# Top of stack:   ♣Q
# Hand:       ['♥6', '♥A', '♣A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥A', '♣A', '♠A', 'take']
# tim plays ♥A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       ['♥Q', '♦Q']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦10']
#
# Playable cards: ['♦10']
# busse plays ♦10 from hidden.
# busse has won the game!
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♥6', '♣A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♣A', '♠A', 'take']
# tim plays ♥6 from hand.
#
# jasper's turn
# Top of stack:   ♥6
# Hand:       ['♥Q', '♦Q', '♥9', '♠9', '♣Q', '♥A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥Q', '♦Q', '♥9', '♠9', '♣Q', '♥A', 'take']
# jasper plays ♥9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♣A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♣A', '♠A', 'take']
# tim plays ♣A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣A
# Hand:       ['♥Q', '♦Q', '♣Q', '♥A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥A', 'take']
# jasper plays ♥A from hand.
#
# tim's turn
# Top of stack:   ♥A
# Hand:       ['♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♠A', 'take']
# tim plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♥Q', '♦Q', '♣Q']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['take']
# jasper takes the stack (7 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♣5']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦Q', '♣Q', '♦10', '♥6', '♥9', '♠9', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥Q', '♦Q', '♣Q', '♦10', '♥6', '♥9', '♠9', '♣A', '♥A', '♠A']
# jasper plays ♥6 from hand.
#
# tim's turn
# Top of stack:   ♥6
# Hand:       []
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (1 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦Q', '♣Q', '♦10', '♥9', '♠9', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥Q', '♦Q', '♣Q', '♦10', '♥9', '♠9', '♣A', '♥A', '♠A']
# jasper plays ♥9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♥6']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦Q', '♣Q', '♦10', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♥Q', '♦Q', '♣Q', '♦10', '♣A', '♥A', '♠A']
# jasper plays ♥Q from hand.
# jasper can play a double card (Q).
# jasper plays ♦Q from hand.
# jasper can play a double card (Q).
# jasper plays ♣Q from hand.
#
# tim's turn
# Top of stack:   ♣Q
# Hand:       ['♥6', '♥9', '♠9']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10', '♣A', '♥A', '♠A']
# jasper plays ♣A from hand.
# jasper can play a double card (A).
# jasper plays ♥A from hand.
# jasper can play a double card (A).
# jasper plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# ...
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦10']
# Displayed:  []
# Hidden:     ['♦A', '♦5']
#
# Playable cards: ['♦10']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# Displayed:  []
# Hidden:     ['♣5']
#
# Playable cards: ['♥6', '♥9', '♠9', '♥Q', '♦Q', '♣Q', '♣A', '♥A', '♠A']
# tim takes the stack (0 cards).
#
# Game over! Winners in order: ['natasja', 'busse', None]

# %% [markdown]
# Nu we zien dat de game runt zonder problemen zullen we 100 rondes simuleren.

# %%
# Het simuleren van 10 games
game.simulate_games(10)
# Out:
# Algemene performance in nummers:
#                     Aantal Games  Aantal Punten  Performance Score   1st  2nd  \
# jasper                      2400           3554            2171.55   628  613
# busse                       2400           5249            4483.70  1175  677
# tim                         2400           1895             500.29   274  306
# natasja                     2400           2325             869.71   343  410
# low                         2400           3469            2017.49   556  682
# justice_and_terror          2400           3423            1952.29   572  613
#
#                     3rd   DNF 1st Ratio 2nd Ratio 3rd Ratio DNF Ratio  \
# jasper              444   715    26.17%    25.54%     18.5%    29.79%
# busse               370   178    48.96%    28.21%    15.42%     7.42%
# tim                 461  1359    11.42%    12.75%    19.21%    56.62%
# natasja             476  1171    14.29%    17.08%    19.83%    48.79%
# low                 437   725    23.17%    28.42%    18.21%    30.21%
# justice_and_terror  481   734    23.83%    25.54%    20.04%    30.58%
#
#                     Gem Eindpositie  Gem punten per game
# jasper                         2.52                 1.48
# busse                          1.81                 2.19
# tim                            3.21                 0.79
# natasja                        3.03                 0.97
# low                            2.55                 1.45
# justice_and_terror             2.57                 1.43
# Overwinningen vanaf verschillende startplekken:
# Punten en Podium verdeling:
# Performance per speler per combinatie van spelers:
