# %% [markdown]
# # Testen Strat Busse

# %%
import sys
import os

# Ophalen path van de src folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Voeg de folder to aan path
if src_path not in sys.path:
    sys.path.append(src_path)

# Importeren van src is nu mogelijk
from utils import ZweedsPesten

# %%
player_names = ["jasper", "busse", "tim", "natasja"]

game = ZweedsPesten(player_names)

winners = game.game_loop(verbose=2)
# Out:
# ------------ Starting Game ------------
# jasper:
# Hand:       ['♠4', '♦7', '♦K']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
# -----------------------------------------
# busse:
# Hand:       ['♥6', '♣4', '♠5']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
# -----------------------------------------
# tim:
# Hand:       ['♣7', '♠A', '♥Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
# -----------------------------------------
# natasja:
# Hand:       ['♦9', '♠9', '♦5']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
# -----------------------------------------
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦7', '♦K']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠4', '♦7', '♦K']
# jasper plays ♦7 from hand.
# jasper draws a card: ♦10
#
# busse's turn
# Top of stack:   ♦7
# Hand:       ['♥6', '♣4', '♠5']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♥6', '♣4', '♠5', 'take']
# busse plays ♣4 from hand.
# busse draws a card: ♣2
#
# tim's turn
# Top of stack:   ♣4
# Hand:       ['♣7', '♠A', '♥Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣7', '♠A', '♥Q', 'take']
# tim plays ♣7 from hand.
# tim draws a card: ♣8
#
# natasja's turn
# Top of stack:   ♣7
# Hand:       ['♦9', '♠9', '♦5']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦5', 'take']
# natasja plays ♦5 from hand.
# natasja draws a card: ♣6
#
# jasper's turn
# Top of stack:   ♦5
# Hand:       ['♠4', '♦K', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♦K', '♦10', 'take']
# jasper plays ♦K from hand.
# jasper draws a card: ♣5
#
# busse's turn
# Top of stack:   ♦K
# Hand:       ['♥6', '♠5', '♣2']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♣2', 'take']
# busse plays ♣2 from hand.
# busse draws a card: ♣9
#
# tim's turn
# Top of stack:   ♣2
# Hand:       ['♠A', '♥Q', '♣8']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠A', '♥Q', '♣8', 'take']
# tim plays ♣8 from hand.
# tim draws a card: ♠Q
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♦9', '♠9', '♣6']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦9', '♠9', 'take']
# natasja plays ♦9 from hand.
# natasja can play a double card (9).
# natasja skipped playing a double card.
# natasja draws a card: ♥7
#
# jasper's turn
# Top of stack:   ♦9
# Hand:       ['♠4', '♦10', '♣5']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♦10', 'take']
# jasper plays ♦10 from hand.
# jasper draws a card: ♥K
#
# busse's turn
# Top of stack:   ♦10
# Hand:       ['♥6', '♠5', '♣9']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♣9', 'take']
# busse plays ♣9 from hand.
# busse draws a card: ♦Q
#
# tim's turn
# Top of stack:   ♣9
# Hand:       ['♠A', '♥Q', '♠Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠A', '♥Q', '♠Q', 'take']
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim skipped playing a double card.
# tim draws a card: ♠2
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♠9', '♣6', '♥7']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (11 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♣5', '♥K']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠4', '♣5', '♥K']
# jasper plays ♥K from hand.
# jasper draws a card: ♥J
#
# busse's turn
# Top of stack:   ♥K
# Hand:       ['♥6', '♠5', '♦Q']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠A', '♠Q', '♠2']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠A', '♠Q', '♠2']
# tim plays ♠A from hand.
# tim draws a card: ♥5
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♠9', '♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♣2', '♣8', '♦9', '♦10', '♣9', '♥Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♣2', '♦10', 'take']
# natasja plays ♣2 from hand.
#
# jasper's turn
# Top of stack:   ♣2
# Hand:       ['♠4', '♣5', '♥J']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠4', '♣5', '♥J', 'take']
# jasper plays ♣5 from hand.
# jasper draws a card: ♥A
#
# busse's turn
# Top of stack:   ♣5
# Hand:       ['♥6', '♠5', '♦Q', '♥K']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♥6', '♠5', '♦Q', '♥K', 'take']
# busse plays ♠5 from hand.
#
# tim's turn
# Top of stack:   ♠5
# Hand:       ['♠Q', '♠2', '♥5']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠Q', '♠2', '♥5', 'take']
# tim plays ♠Q from hand.
# tim draws a card: ♥9
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♠9', '♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♣8', '♦9', '♦10', '♣9', '♥Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦K', '♦10', '♥Q', 'take']
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       ['♠4', '♥J', '♥A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥A', 'take']
# jasper plays ♥A from hand.
# jasper draws a card: ♣A
#
# busse's turn
# Top of stack:   ♥A
# Hand:       ['♥6', '♦Q', '♥K']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['take']
# busse takes the stack (7 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠2', '♥5', '♥9']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠2', '♥5', '♥9']
# tim plays ♥9 from hand.
#
# natasja's turn
# Top of stack:   ♥9
# Hand:       ['♠9', '♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♣8', '♦9', '♣9', '♥Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠9', '♦K', '♦9', '♣9', '♥Q', 'take']
# natasja plays ♥Q from hand.
#
# jasper's turn
# Top of stack:   ♥Q
# Hand:       ['♠4', '♥J', '♣A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♣A', 'take']
# jasper plays ♣A from hand.
#
# busse's turn
# Top of stack:   ♣A
# Hand:       ['♥6', '♦Q', '♥K', '♠A', '♣2', '♣5', '♠5', '♠Q', '♦10', '♥A']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♠A', '♣2', '♦10', '♥A', 'take']
# busse plays ♠A from hand.
# busse can play a double card (A).
# busse plays ♥A from hand.
#
# tim's turn
# Top of stack:   ♥A
# Hand:       ['♠2', '♥5']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠2', 'take']
# tim plays ♠2 from hand.
#
# natasja's turn
# Top of stack:   ♠2
# Hand:       ['♠9', '♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♣8', '♦9', '♣9']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠9', '♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♣8', '♦9', '♣9', 'take']
# natasja plays ♣8 from hand.
#
# jasper's turn
# Top of stack:   ♣8
# Hand:       ['♠4', '♥J']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥J', 'take']
# jasper plays ♥J from hand.
#
# busse's turn
# Top of stack:   ♥J
# Hand:       ['♥6', '♦Q', '♥K', '♣2', '♣5', '♠5', '♠Q', '♦10']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♦Q', '♥K', '♣2', '♠Q', '♦10', 'take']
# busse plays ♦Q from hand.
# busse can play a double card (Q).
# busse plays ♠Q from hand.
#
# tim's turn
# Top of stack:   ♠Q
# Hand:       ['♥5']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (10 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠9', '♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♦9', '♣9']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠9', '♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♦9', '♣9']
# natasja plays ♠9 from hand.
# natasja can play a double card (9).
# natasja plays ♦9 from hand.
# natasja can play a double card (9).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦9
# Hand:       ['♠4']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♥K', '♣2', '♣5', '♠5', '♦10']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♥6', '♥K', '♣2', '♣5', '♠5', '♦10']
# busse plays ♣5 from hand.
# busse can play a double card (5).
# busse plays ♠5 from hand.
#
# tim's turn
# Top of stack:   ♠5
# Hand:       ['♥5', '♥9', '♥Q', '♣A', '♠A', '♥A', '♠2', '♣8', '♥J', '♦Q', '♠Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥5', '♥9', '♥Q', '♣A', '♠A', '♥A', '♠2', '♣8', '♥J', '♦Q', '♠Q', 'take']
# tim plays ♥A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥A
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♣9']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♠9', '♦9']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠4', '♠9', '♦9']
# jasper plays ♠9 from hand.
# jasper can play a double card (9).
# jasper plays ♦9 from hand.
#
# busse's turn
# Top of stack:   ♦9
# Hand:       ['♥6', '♥K', '♣2', '♦10']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♥K', '♣2', '♦10', 'take']
# busse plays ♥K from hand.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♥5', '♥9', '♥Q', '♣A', '♠A', '♠2', '♣8', '♥J', '♦Q', '♠Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣A', '♠A', '♠2', 'take']
# tim plays ♣A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♣A
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♣9', '♣5', '♠5', '♥A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥A', 'take']
# natasja plays ♥A from hand.
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       ['♠4']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♣2', '♦10']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♥6', '♣2', '♦10']
# busse plays ♥6 from hand.
#
# tim's turn
# Top of stack:   ♥6
# Hand:       ['♥5', '♥9', '♥Q', '♠A', '♠2', '♣8', '♥J', '♦Q', '♠Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥9', '♥Q', '♠A', '♠2', '♣8', '♥J', '♦Q', '♠Q', 'take']
# tim plays ♦Q from hand.
# tim can play a double card (Q).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦Q
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♦K', '♣9', '♣5', '♠5']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦K', 'take']
# natasja plays ♦K from hand.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       ['♠4', '♠9', '♦9', '♥K', '♣A', '♥A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥K', '♣A', '♥A', 'take']
# jasper plays ♥K from hand.
#
# busse's turn
# Top of stack:   ♥K
# Hand:       ['♣2', '♦10']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♣2', '♦10', 'take']
# busse plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♥5', '♥9', '♥Q', '♠A', '♠2', '♣8', '♥J', '♠Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠A', '♠2', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♣9', '♣5', '♠5']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (6 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♠9', '♦9', '♣A', '♥A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠4', '♠9', '♦9', '♣A', '♥A']
# jasper plays ♣A from hand.
# jasper can play a double card (A).
# jasper plays ♥A from hand.
#
# busse's turn
# Top of stack:   ♥A
# Hand:       ['♣2']
# Displayed:  ['♥2', '♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♣2', 'take']
# busse plays ♣2 from hand.
# busse can play a double card (2).
# busse plays ♥2 from displayed.
#
# tim's turn
# Top of stack:   ♥2
# Hand:       ['♥5', '♥9', '♥Q', '♠2', '♣8', '♥J', '♠Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥5', '♥9', '♥Q', '♠2', '♣8', '♥J', '♠Q', 'take']
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim plays ♠Q from hand.
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♣9', '♣5', '♠5', '♥6', '♦Q', '♦K', '♥K', '♦10', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦Q', '♦K', '♥K', '♦10', '♠A', 'take']
# natasja plays ♦Q from hand.
#
# jasper's turn
# Top of stack:   ♦Q
# Hand:       ['♠4', '♠9', '♦9']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (7 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♠10', '♦8']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♠10', '♦8']
# busse plays ♦8 from displayed.
#
# tim's turn
# Top of stack:   ♦8
# Hand:       ['♥5', '♥9', '♠2', '♣8', '♥J']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥9', '♠2', '♣8', '♥J', 'take']
# tim plays ♥9 from hand.
#
# natasja's turn
# Top of stack:   ♥9
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♣9', '♣5', '♠5', '♥6', '♦K', '♥K', '♦10', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♣9', '♦K', '♥K', '♦10', '♠A', 'take']
# natasja plays ♣9 from hand.
#
# jasper's turn
# Top of stack:   ♣9
# Hand:       ['♠4', '♠9', '♦9', '♣A', '♥A', '♣2', '♥2', '♥Q', '♠Q', '♦Q']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♦9', '♣A', '♥A', '♣2', '♥2', '♥Q', '♠Q', '♦Q', 'take']
# jasper plays ♥A from hand.
# jasper can play a double card (A).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  ['♠10']
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♠10', 'take']
# busse plays ♠10 from displayed.
#
# tim's turn
# Top of stack:   ♠10
# Hand:       ['♥5', '♠2', '♣8', '♥J']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠2', 'take']
# tim plays ♠2 from hand.
#
# natasja's turn
# Top of stack:   ♠2
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♣5', '♠5', '♥6', '♦K', '♥K', '♦10', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♣5', '♠5', '♥6', '♦K', '♥K', '♦10', '♠A', 'take']
# natasja plays ♠5 from hand.
# natasja can play a double card (5).
# natasja plays ♣5 from hand.
# natasja can play a double card (5).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣5
# Hand:       ['♠4', '♠9', '♦9', '♣A', '♣2', '♥2', '♥Q', '♠Q', '♦Q']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♦9', '♣A', '♣2', '♥2', '♥Q', '♠Q', '♦Q', 'take']
# jasper plays ♥2 from hand.
# jasper can play a double card (2).
# jasper plays ♣2 from hand.
#
# busse's turn
# Top of stack:   ♣2
# Hand:       []
# Displayed:  []
# Hidden:     ['♠8', '♣3', '♠3']
#
# Playable cards: ['♠3', 'take']
# busse plays ♠3 from hidden.
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♣3']
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♠8']
# busse has won the game!
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♥5', '♣8', '♥J']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣8', '♥J', 'take']
# tim plays ♣8 from hand.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♥6', '♦K', '♥K', '♦10', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦K', '♥K', '♦10', '♠A', 'take']
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       ['♠4', '♠9', '♦9', '♣A', '♥Q', '♠Q', '♦Q']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♦9', '♣A', '♥Q', '♠Q', '♦Q', 'take']
# jasper plays ♥Q from hand.
# jasper can play a double card (Q).
# jasper plays ♠Q from hand.
# jasper can play a double card (Q).
# jasper plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♥5', '♥J']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♥6', '♦K', '♥K', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♣6', '♥7', '♦7', '♣4', '♣7', '♦5', '♥6', '♦K', '♥K', '♠A']
# natasja plays ♣7 from hand.
# natasja can play a double card (7).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣7
# Hand:       ['♠4', '♠9', '♦9', '♣A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠4', 'take']
# jasper plays ♠4 from hand.
#
# tim's turn
# Top of stack:   ♠4
# Hand:       ['♥5', '♥J', '♠8', '♣8', '♦10', '♥Q', '♠Q', '♦Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥5', '♥J', '♠8', '♣8', '♦10', '♥Q', '♠Q', '♦Q', 'take']
# tim plays ♠8 from hand.
# tim can play a double card (8).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♦5', '♥6', '♦K', '♥K', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦K', '♥K', '♠A', 'take']
# natasja plays ♥K from hand.
# natasja can play a double card (K).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       ['♠9', '♦9', '♣A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♣A', 'take']
# jasper plays ♣A from hand.
#
# tim's turn
# Top of stack:   ♣A
# Hand:       ['♥5', '♥J', '♣8', '♦10', '♥Q', '♠Q', '♦Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦10', 'take']
# tim plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♦5', '♥6', '♦K', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠A', 'take']
# natasja plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♠9', '♦9']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (7 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♥J', '♣8', '♥Q', '♠Q', '♦Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥5', '♥J', '♣8', '♥Q', '♠Q', '♦Q']
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♦5', '♥6', '♦K']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦K', 'take']
# natasja plays ♦K from hand.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       ['♠9', '♦9', '♣7', '♠4', '♠8', '♥K', '♣A', '♦10', '♠A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥K', '♣A', '♦10', '♠A', 'take']
# jasper plays ♣A from hand.
# jasper can play a double card (A).
# jasper skipped playing a double card.
#
# tim's turn
# Top of stack:   ♣A
# Hand:       ['♥5', '♥J', '♣8', '♠Q', '♦Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣6', '♥7', '♦7', '♣4', '♦5', '♥6']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♣6', '♥7', '♦7', '♣4', '♦5', '♥6']
# natasja plays ♥6 from hand.
# natasja can play a double card (6).
# natasja plays ♣6 from hand.
#
# jasper's turn
# Top of stack:   ♣6
# Hand:       ['♠9', '♦9', '♣7', '♠4', '♠8', '♥K', '♦10', '♠A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♦9', '♣7', '♠8', '♥K', '♦10', '♠A', 'take']
# jasper plays ♦9 from hand.
# jasper can play a double card (9).
# jasper skipped playing a double card.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♥5', '♥J', '♣8', '♠Q', '♦Q', '♥Q', '♦K', '♣A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♠Q', '♦Q', '♥Q', '♦K', '♣A', 'take']
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim plays ♦Q from hand.
# tim can play a double card (Q).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦Q
# Hand:       ['♥7', '♦7', '♣4', '♦5']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠9', '♣7', '♠4', '♠8', '♥K', '♦10', '♠A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♣7', '♠4', '♠8', '♥K', '♦10', '♠A']
# jasper plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♥5', '♥J', '♣8', '♠Q', '♦K', '♣A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣A', 'take']
# tim plays ♣A from hand.
#
# natasja's turn
# Top of stack:   ♣A
# Hand:       ['♥7', '♦7', '♣4', '♦5', '♥6', '♣6', '♦9', '♥Q', '♦Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠9', '♣7', '♠4', '♠8', '♥K', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♣7', '♠4', '♠8', '♥K', '♦10']
# jasper plays ♠8 from hand.
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♥5', '♥J', '♣8', '♠Q', '♦K']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♣8', '♠Q', '♦K', 'take']
# tim plays ♠Q from hand.
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♥7', '♦7', '♣4', '♦5', '♥6', '♣6', '♦9', '♥Q', '♦Q', '♠A', '♣A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥Q', '♦Q', '♠A', '♣A', 'take']
# natasja plays ♣A from hand.
# natasja can play a double card (A).
# natasja plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♠9', '♣7', '♠4', '♥K', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♦10', 'take']
# jasper plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♥5', '♥J', '♣8', '♦K']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (5 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♦7', '♣4', '♦5', '♥6', '♣6', '♦9', '♥Q', '♦Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥7', '♦7', '♣4', '♦5', '♥6', '♣6', '♦9', '♥Q', '♦Q']
# natasja plays ♣4 from hand.
#
# jasper's turn
# Top of stack:   ♣4
# Hand:       ['♠9', '♣7', '♠4', '♥K']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♣7', '♠4', '♥K', 'take']
# jasper plays ♣7 from hand.
#
# tim's turn
# Top of stack:   ♣7
# Hand:       ['♥5', '♥J', '♣8', '♦K', '♠8', '♠Q', '♣A', '♠A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥5', '♦10', 'take']
# tim plays ♥5 from hand.
#
# natasja's turn
# Top of stack:   ♥5
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♥Q', '♦Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♥Q', '♦Q', 'take']
# natasja plays ♦Q from hand.
# natasja can play a double card (Q).
# natasja plays ♥Q from hand.
#
# jasper's turn
# Top of stack:   ♥Q
# Hand:       ['♠9', '♠4', '♥K']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥K', 'take']
# jasper plays ♥K from hand.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♥J', '♣8', '♦K', '♠8', '♠Q', '♣A', '♠A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♣A', '♠A', '♦10', 'take']
# tim plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (7 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠9', '♠4']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♠4']
# jasper plays ♠4 from hand.
#
# tim's turn
# Top of stack:   ♠4
# Hand:       ['♥J', '♣8', '♦K', '♠8', '♠Q', '♣A', '♠A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♣8', '♦K', '♠8', '♠Q', '♣A', '♠A', 'take']
# tim plays ♠Q from hand.
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♦Q', '♥Q', '♥K', '♦10']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦Q', '♥Q', '♥K', '♦10', 'take']
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       ['♠9']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♣8', '♦K', '♠8', '♣A', '♠A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♣8', '♦K', '♠8', '♣A', '♠A']
# tim plays ♠8 from hand.
# tim can play a double card (8).
# tim plays ♣8 from hand.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♦Q', '♥Q', '♥K']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦9', '♦Q', '♥Q', '♥K', 'take']
# natasja plays ♦Q from hand.
# natasja can play a double card (Q).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦Q
# Hand:       ['♠9', '♠4', '♠Q', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠Q', '♦10', 'take']
# jasper plays ♠Q from hand.
#
# tim's turn
# Top of stack:   ♠Q
# Hand:       ['♥J', '♦K', '♣A', '♠A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♣A', '♠A', 'take']
# tim plays ♠A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♥K']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠9', '♠4', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♠4', '♦10']
# jasper plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♥J', '♦K', '♣A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♦K', '♣A', 'take']
# tim plays ♣A from hand.
#
# natasja's turn
# Top of stack:   ♣A
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♥K', '♠8', '♣8', '♦Q', '♠Q', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠A', 'take']
# natasja plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♠9', '♠4']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♦K']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♦K']
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♥K', '♠8', '♣8', '♦Q', '♠Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥K', 'take']
# natasja plays ♥K from hand.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       ['♠9', '♠4', '♦10', '♣A', '♠A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♦10', '♣A', '♠A', 'take']
# jasper plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♥J']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♠8', '♣8', '♦Q', '♠Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♠8', '♣8', '♦Q', '♠Q']
# natasja plays ♠8 from hand.
# natasja can play a double card (8).
# natasja plays ♣8 from hand.
#
# jasper's turn
# Top of stack:   ♣8
# Hand:       ['♠9', '♠4', '♣A', '♠A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♣A', '♠A', 'take']
# jasper plays ♠A from hand.
# jasper can play a double card (A).
# jasper plays ♣A from hand.
#
# tim's turn
# Top of stack:   ♣A
# Hand:       ['♥J', '♦K', '♥K', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦10', 'take']
# tim plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♦Q', '♠Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠9', '♠4']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♠4']
# jasper plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♥J', '♦K', '♥K']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♦K', '♥K', 'take']
# tim plays ♥K from hand.
# tim can play a double card (K).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥K
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♦Q', '♠Q', '♠8', '♣8', '♠A', '♣A', '♦10']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠A', '♣A', '♦10', 'take']
# natasja plays ♠A from hand.
# natasja can play a double card (A).
# natasja plays ♣A from hand.
#
# jasper's turn
# Top of stack:   ♣A
# Hand:       ['♠4']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♦K']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♦K']
# tim plays ♥J from hand.
#
# natasja's turn
# Top of stack:   ♥J
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♦Q', '♠Q', '♠8', '♣8', '♦10']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥Q', '♦Q', '♠Q', '♦10', 'take']
# natasja plays ♦Q from hand.
# natasja can play a double card (Q).
# natasja plays ♥Q from hand.
# natasja can play a double card (Q).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥Q
# Hand:       ['♠4', '♠9', '♥K', '♠A', '♣A']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥K', '♠A', '♣A', 'take']
# jasper plays ♠A from hand.
# jasper can play a double card (A).
# jasper plays ♣A from hand.
#
# tim's turn
# Top of stack:   ♣A
# Hand:       ['♦K']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (5 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♠Q', '♠8', '♣8', '♦10']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♠Q', '♠8', '♣8', '♦10']
# natasja plays ♠8 from hand.
# natasja can play a double card (8).
# natasja plays ♣8 from hand.
#
# jasper's turn
# Top of stack:   ♣8
# Hand:       ['♠4', '♠9', '♥K']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9', '♥K', 'take']
# jasper plays ♥K from hand.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♦K', '♥J', '♦Q', '♥Q', '♠A', '♣A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♠A', '♣A', 'take']
# tim plays ♠A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♠Q', '♦10']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦10', 'take']
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       ['♠4', '♠9']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦K', '♥J', '♦Q', '♥Q', '♣A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♥J', '♦Q', '♥Q', '♣A']
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♠Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠Q', 'take']
# natasja plays ♠Q from hand.
#
# jasper's turn
# Top of stack:   ♠Q
# Hand:       ['♠4', '♠9', '♠8', '♣8', '♥K', '♠A', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥K', '♠A', '♦10', 'take']
# jasper plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♦K', '♥J', '♦Q', '♣A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣A', 'take']
# tim plays ♣A from hand.
#
# natasja's turn
# Top of stack:   ♣A
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♠9', '♠8', '♣8', '♥K', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠4', '♠9', '♠8', '♣8', '♥K', '♦10']
# jasper plays ♣8 from hand.
# jasper can play a double card (8).
# jasper plays ♠8 from hand.
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♦K', '♥J', '♦Q']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♥J', '♦Q', 'take']
# tim plays ♦Q from hand.
#
# natasja's turn
# Top of stack:   ♦Q
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♥Q', '♠Q', '♠A', '♣A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥Q', '♠Q', '♠A', '♣A', 'take']
# natasja plays ♥Q from hand.
# natasja can play a double card (Q).
# natasja plays ♠Q from hand.
#
# jasper's turn
# Top of stack:   ♠Q
# Hand:       ['♠4', '♠9', '♥K', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥K', '♦10', 'take']
# jasper plays ♥K from hand.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♦K', '♥J']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', 'take']
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5', '♠A', '♣A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠A', '♣A', 'take']
# natasja plays ♣A from hand.
# natasja can play a double card (A).
# natasja plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♠4', '♠9', '♦10']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♦10', 'take']
# jasper plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♥J']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (10 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣4', '♣7', '♥5']
# natasja plays ♣4 from hand.
#
# jasper's turn
# Top of stack:   ♣4
# Hand:       ['♠4', '♠9']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠4', '♠9', 'take']
# jasper plays ♠4 from hand.
#
# tim's turn
# Top of stack:   ♠4
# Hand:       ['♥J', '♣8', '♠8', '♦Q', '♥Q', '♠Q', '♥K', '♦K', '♣A', '♠A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♣8', '♠8', '♦Q', '♥Q', '♠Q', '♥K', '♦K', '♣A', '♠A', '♦10', 'take']
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣7', '♥5']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠9']
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠9']
# jasper plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♥J', '♣8', '♠8', '♦Q', '♠Q', '♥K', '♦K', '♣A', '♠A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥J', '♦Q', '♠Q', '♥K', '♦K', '♣A', '♠A', '♦10', 'take']
# tim plays ♥J from hand.
#
# natasja's turn
# Top of stack:   ♥J
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣7', '♥5', '♣4', '♠4', '♥Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥Q', 'take']
# natasja plays ♥Q from hand.
#
# jasper's turn
# Top of stack:   ♥Q
# Hand:       []
# Displayed:  ['♠K', '♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠K', '♦2', 'take']
# jasper plays ♠K from displayed.
#
# tim's turn
# Top of stack:   ♠K
# Hand:       ['♣8', '♠8', '♦Q', '♠Q', '♥K', '♦K', '♣A', '♠A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥K', '♦K', '♣A', '♠A', '♦10', 'take']
# tim plays ♥K from hand.
# tim can play a double card (K).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥K
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣7', '♥5', '♣4', '♠4']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥8', '♦2']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♥8', '♦2']
# jasper plays ♦2 from displayed.
#
# tim's turn
# Top of stack:   ♦2
# Hand:       ['♣8', '♠8', '♦Q', '♠Q', '♦K', '♣A', '♠A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣8', '♠8', '♦Q', '♠Q', '♦K', '♣A', '♠A', '♦10', 'take']
# tim plays ♠8 from hand.
# tim can play a double card (8).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣7', '♥5', '♣4', '♠4', '♠9', '♥J', '♥Q', '♠K', '♥K']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦9', '♠9', '♥J', '♥Q', '♠K', '♥K', 'take']
# natasja plays ♠9 from hand.
# natasja can play a double card (9).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♠9
# Hand:       []
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♦Q', '♠Q', '♦K', '♣A', '♠A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣8', '♦Q', '♠Q', '♦K', '♣A', '♠A', '♦10']
# tim plays ♦Q from hand.
# tim can play a double card (Q).
# tim plays ♠Q from hand.
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣7', '♥5', '♣4', '♠4', '♥J', '♥Q', '♠K', '♥K']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥Q', '♠K', '♥K', 'take']
# natasja plays ♥K from hand.
# natasja can play a double card (K).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       ['♦2', '♠8', '♠9']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♦2', 'take']
# jasper plays ♦2 from hand.
#
# tim's turn
# Top of stack:   ♦2
# Hand:       ['♣8', '♦K', '♣A', '♠A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣8', '♦K', '♣A', '♠A', '♦10', 'take']
# tim plays ♠A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣7', '♥5', '♣4', '♠4', '♥J', '♥Q', '♠K']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠8', '♠9']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠8', '♠9']
# jasper plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♣8', '♦K', '♣A', '♦10']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♣A', '♦10', 'take']
# tim plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♦9', '♣7', '♥5', '♣4', '♠4', '♥J', '♥Q', '♠K', '♦Q', '♠Q', '♥K', '♦2', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦9', '♥J', '♥Q', '♠K', '♦Q', '♠Q', '♥K', '♦2', '♠A', 'take']
# natasja plays ♦9 from hand.
#
# jasper's turn
# Top of stack:   ♦9
# Hand:       ['♠8']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♦K', '♣A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣8', '♦K', '♣A']
# tim plays ♣8 from hand.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♣7', '♥5', '♣4', '♠4', '♥J', '♥Q', '♠K', '♦Q', '♠Q', '♥K', '♦2', '♠A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥J', '♥Q', '♠K', '♦Q', '♠Q', '♥K', '♦2', '♠A', 'take']
# natasja plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♠8', '♠9', '♦10', '♦9']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♦10', 'take']
# jasper plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♦K', '♣A']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣A', 'take']
# tim plays ♣A from hand.
#
# natasja's turn
# Top of stack:   ♣A
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♣7', '♥5', '♣4', '♠4', '♥J', '♥Q', '♠K', '♦Q', '♠Q', '♥K', '♦2']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦2', 'take']
# natasja plays ♦2 from hand.
#
# jasper's turn
# Top of stack:   ♦2
# Hand:       ['♠8', '♠9', '♦9']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠8', '♠9', '♦9', 'take']
# jasper plays ♦9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♦K']
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', 'take']
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♣7', '♥5', '♣4', '♠4', '♥J', '♥Q', '♠K', '♦Q', '♠Q', '♥K']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠K', '♥K', 'take']
# natasja plays ♠K from hand.
# natasja can play a double card (K).
# natasja plays ♥K from hand.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       ['♠8']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['take']
# jasper takes the stack (10 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♠6', '♦A', '♣10']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠6', '♦A', '♣10']
# tim plays ♣10 from displayed.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♥7', '♦7', '♦5', '♥6', '♣6', '♣7', '♥5', '♣4', '♠4', '♥J', '♥Q', '♦Q', '♠Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥7', '♦7', '♦5', '♥6', '♣6', '♣7', '♥5', '♣4', '♠4', '♥J', '♥Q', '♦Q', '♠Q', 'take']
# natasja plays ♣7 from hand.
# natasja can play a double card (7).
# natasja plays ♦7 from hand.
# natasja can play a double card (7).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦7
# Hand:       ['♠8', '♣8', '♠A', '♦10', '♣A', '♦2', '♦9', '♠9', '♦K', '♠K', '♥K']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♦10', '♦2', 'take']
# jasper plays ♦2 from hand.
#
# tim's turn
# Top of stack:   ♦2
# Hand:       []
# Displayed:  ['♠6', '♦A']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠6', '♦A', 'take']
# tim plays ♦A from displayed.
#
# natasja's turn
# Top of stack:   ♦A
# Hand:       ['♥7', '♦5', '♥6', '♣6', '♥5', '♣4', '♠4', '♥J', '♥Q', '♦Q', '♠Q']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠8', '♣8', '♠A', '♦10', '♣A', '♦9', '♠9', '♦K', '♠K', '♥K']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠8', '♣8', '♠A', '♦10', '♣A', '♦9', '♠9', '♦K', '♠K', '♥K']
# jasper plays ♠8 from hand.
# jasper can play a double card (8).
# jasper plays ♣8 from hand.
#
# tim's turn
# Top of stack:   ♣8
# Hand:       []
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♦5', '♥6', '♣6', '♥5', '♣4', '♠4', '♥J', '♥Q', '♦Q', '♠Q', '♣10', '♣7', '♦7', '♦2', '♦A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥7', '♦5', '♥6', '♣6', '♥5', '♣4', '♠4', '♥J', '♥Q', '♦Q', '♠Q', '♣10', '♣7', '♦7', '♦2', '♦A']
# natasja plays ♥6 from hand.
# natasja can play a double card (6).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥6
# Hand:       ['♠A', '♦10', '♣A', '♦9', '♠9', '♦K', '♠K', '♥K']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠A', '♦10', '♣A', '♦9', '♠9', '♦K', '♠K', '♥K', 'take']
# jasper plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♠8', '♣8']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠8', '♣8', 'take']
# tim plays ♣8 from hand.
# tim can play a double card (8).
# tim plays ♠8 from hand.
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       ['♥7', '♦5', '♣6', '♥5', '♣4', '♠4', '♥J', '♥Q', '♦Q', '♠Q', '♣10', '♣7', '♦7', '♦2', '♦A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥J', '♥Q', '♦Q', '♠Q', '♣10', '♦2', '♦A', 'take']
# natasja plays ♥Q from hand.
# natasja can play a double card (Q).
# natasja plays ♦Q from hand.
# natasja can play a double card (Q).
# natasja plays ♠Q from hand.
#
# jasper's turn
# Top of stack:   ♠Q
# Hand:       ['♠A', '♣A', '♦9', '♠9', '♦K', '♠K', '♥K']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♠A', '♣A', '♦K', '♠K', '♥K', 'take']
# jasper plays ♠A from hand.
# jasper can play a double card (A).
# jasper skipped playing a double card.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       []
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (8 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♦5', '♣6', '♥5', '♣4', '♠4', '♥J', '♣10', '♣7', '♦7', '♦2', '♦A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥7', '♦5', '♣6', '♥5', '♣4', '♠4', '♥J', '♣10', '♣7', '♦7', '♦2', '♦A']
# natasja plays ♦2 from hand.
#
# jasper's turn
# Top of stack:   ♦2
# Hand:       ['♣A', '♦9', '♠9', '♦K', '♠K', '♥K']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♣A', '♦9', '♠9', '♦K', '♠K', '♥K', 'take']
# jasper plays ♠9 from hand.
# jasper can play a double card (9).
# jasper plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♥6', '♦10', '♣8', '♠8', '♥Q', '♦Q', '♠Q', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦10', '♥Q', '♦Q', '♠Q', '♠A', 'take']
# tim plays ♦Q from hand.
# tim can play a double card (Q).
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim plays ♠Q from hand.
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♥7', '♦5', '♣6', '♥5', '♣4', '♠4', '♥J', '♣10', '♣7', '♦7', '♦A']
# Displayed:  ['♠7', '♥3', '♦6']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♣10', '♦A', 'take']
# natasja plays ♦A from hand.
#
# jasper's turn
# Top of stack:   ♦A
# Hand:       ['♣A', '♦K', '♠K', '♥K']
# Displayed:  ['♥8']
# Hidden:     ['♠J', '♣J', '♦3']
#
# Playable cards: ['♣A', 'take']
# ...
# Hand:       ['♦9', '♠8', '♥J', '♠J', '♣J', '♠Q', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠A', 'take']
# natasja plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♥5', '♠4', '♣8', '♦6']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦9', '♠8', '♥J', '♠J', '♣J', '♠Q']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦9', '♠8', '♥J', '♠J', '♣J', '♠Q']
# natasja plays ♠8 from hand.
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♥5', '♠4', '♣8', '♦6', '♥K', '♦K', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣8', '♥K', '♦K', '♠A', 'take']
# tim plays ♥K from hand.
# tim can play a double card (K).
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♦9', '♥J', '♠J', '♣J', '♠Q']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♠4', '♣8', '♦6', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥5', '♠4', '♣8', '♦6', '♠A']
# tim plays ♥5 from hand.
#
# natasja's turn
# Top of stack:   ♥5
# Hand:       ['♦9', '♥J', '♠J', '♣J', '♠Q', '♠8', '♥K', '♦K']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦9', '♥J', '♠J', '♣J', '♠Q', '♠8', '♥K', '♦K', 'take']
# natasja plays ♥K from hand.
# natasja can play a double card (K).
# natasja plays ♦K from hand.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♠4', '♣8', '♦6', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♦9', '♥J', '♠J', '♣J', '♠Q', '♠8']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♣8', '♦6']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠4', '♣8', '♦6']
# tim plays ♠4 from hand.
#
# natasja's turn
# Top of stack:   ♠4
# Hand:       ['♦9', '♥J', '♠J', '♣J', '♠Q', '♠8', '♥5', '♥K', '♦K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦9', '♥J', '♠J', '♣J', '♠Q', '♠8', '♥5', '♥K', '♦K', '♠A', 'take']
# natasja plays ♦K from hand.
# natasja can play a double card (K).
# natasja plays ♥K from hand.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♣8', '♦6']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦9', '♥J', '♠J', '♣J', '♠Q', '♠8', '♥5', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦9', '♥J', '♠J', '♣J', '♠Q', '♠8', '♥5', '♠A']
# natasja plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♣8', '♦6', '♠4', '♦K', '♥K']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♥K', 'take']
# tim plays ♥K from hand.
# tim can play a double card (K).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥K
# Hand:       ['♥J', '♠J', '♣J', '♠Q', '♠8', '♥5', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠A', 'take']
# natasja plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♣8', '♦6', '♠4', '♦K']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♠J', '♣J', '♠Q', '♠8', '♥5']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥J', '♠J', '♣J', '♠Q', '♠8', '♥5']
# natasja plays ♠J from hand.
# natasja can play a double card (J).
# natasja plays ♣J from hand.
# natasja can play a double card (J).
# natasja plays ♥J from hand.
#
# tim's turn
# Top of stack:   ♥J
# Hand:       ['♣8', '♦6', '♠4', '♦K', '♦9', '♥K', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♥K', '♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♠Q', '♠8', '♥5']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♦6', '♠4', '♦K', '♦9', '♥K']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣8', '♦6', '♠4', '♦K', '♦9', '♥K']
# tim plays ♣8 from hand.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♠Q', '♠8', '♥5', '♠J', '♣J', '♥J', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠Q', '♠8', '♠J', '♣J', '♥J', '♠A', 'take']
# natasja plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♦6', '♠4', '♦K', '♦9', '♥K']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠Q', '♠8', '♥5', '♠J', '♣J', '♥J']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠Q', '♠8', '♥5', '♠J', '♣J', '♥J']
# natasja plays ♠Q from hand.
#
# tim's turn
# Top of stack:   ♠Q
# Hand:       ['♦6', '♠4', '♦K', '♦9', '♥K', '♣8', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', '♥K', '♠A', 'take']
# tim plays ♦K from hand.
# tim can play a double card (K).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♠8', '♥5', '♠J', '♣J', '♥J']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♠4', '♦9', '♥K', '♣8', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦6', '♠4', '♦9', '♥K', '♣8', '♠A']
# tim plays ♦6 from hand.
#
# natasja's turn
# Top of stack:   ♦6
# Hand:       ['♠8', '♥5', '♠J', '♣J', '♥J', '♠Q', '♦K']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠8', '♠J', '♣J', '♥J', '♠Q', '♦K', 'take']
# natasja plays ♣J from hand.
# natasja can play a double card (J).
# natasja plays ♠J from hand.
# natasja can play a double card (J).
# natasja skipped playing a double card.
#
# tim's turn
# Top of stack:   ♠J
# Hand:       ['♠4', '♦9', '♥K', '♣8', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥K', '♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♠8', '♥5', '♥J', '♠Q', '♦K']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦9', '♥K', '♣8']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠4', '♦9', '♥K', '♣8']
# tim plays ♠4 from hand.
#
# natasja's turn
# Top of stack:   ♠4
# Hand:       ['♠8', '♥5', '♥J', '♠Q', '♦K', '♦6', '♣J', '♠J', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠8', '♥5', '♥J', '♠Q', '♦K', '♦6', '♣J', '♠J', '♠A', 'take']
# natasja plays ♥J from hand.
# natasja can play a double card (J).
# natasja plays ♣J from hand.
# natasja can play a double card (J).
# natasja plays ♠J from hand.
#
# tim's turn
# Top of stack:   ♠J
# Hand:       ['♦9', '♥K', '♣8']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥K', 'take']
# tim plays ♥K from hand.
#
# natasja's turn
# Top of stack:   ♥K
# Hand:       ['♠8', '♥5', '♠Q', '♦K', '♦6', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦K', '♠A', 'take']
# natasja plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♦9', '♣8']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠8', '♥5', '♠Q', '♦K', '♦6']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠8', '♥5', '♠Q', '♦K', '♦6']
# natasja plays ♠Q from hand.
#
# tim's turn
# Top of stack:   ♠Q
# Hand:       ['♦9', '♣8', '♠4', '♥J', '♣J', '♠J', '♥K', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♥K', '♠A', 'take']
# tim plays ♥K from hand.
#
# natasja's turn
# Top of stack:   ♥K
# Hand:       ['♠8', '♥5', '♦K', '♦6']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦K', 'take']
# natasja plays ♦K from hand.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♦9', '♣8', '♠4', '♥J', '♣J', '♠J', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♠8', '♥5', '♦6']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦9', '♣8', '♠4', '♥J', '♣J', '♠J']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦9', '♣8', '♠4', '♥J', '♣J', '♠J']
# tim plays ♣8 from hand.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♠8', '♥5', '♦6', '♠Q', '♥K', '♦K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠8', '♠Q', '♥K', '♦K', '♠A', 'take']
# natasja plays ♠Q from hand.
#
# tim's turn
# Top of stack:   ♠Q
# Hand:       ['♦9', '♠4', '♥J', '♣J', '♠J']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠8', '♥5', '♦6', '♥K', '♦K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠8', '♥5', '♦6', '♥K', '♦K', '♠A']
# natasja plays ♠8 from hand.
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♦9', '♠4', '♥J', '♣J', '♠J', '♣8', '♠Q']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦9', '♥J', '♣J', '♠J', '♣8', '♠Q', 'take']
# tim plays ♣8 from hand.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♥5', '♦6', '♥K', '♦K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥K', '♦K', '♠A', 'take']
# natasja plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♦9', '♠4', '♥J', '♣J', '♠J', '♠Q']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♦6', '♥K', '♦K']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥5', '♦6', '♥K', '♦K']
# natasja plays ♦6 from hand.
#
# tim's turn
# Top of stack:   ♦6
# Hand:       ['♦9', '♠4', '♥J', '♣J', '♠J', '♠Q', '♠8', '♣8', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦9', '♥J', '♣J', '♠J', '♠Q', '♠8', '♣8', '♠A', 'take']
# tim plays ♣8 from hand.
# tim can play a double card (8).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♥5', '♥K', '♦K']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥K', '♦K', 'take']
# natasja plays ♥K from hand.
# natasja can play a double card (K).
# natasja plays ♦K from hand.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♦9', '♠4', '♥J', '♣J', '♠J', '♠Q', '♠8', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♥5']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦9', '♠4', '♥J', '♣J', '♠J', '♠Q', '♠8']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦9', '♠4', '♥J', '♣J', '♠J', '♠Q', '♠8']
# tim plays ♠J from hand.
# tim can play a double card (J).
# tim plays ♥J from hand.
# tim can play a double card (J).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥J
# Hand:       ['♥5', '♦6', '♣8', '♥K', '♦K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥K', '♦K', '♠A', 'take']
# natasja plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♦9', '♠4', '♣J', '♠Q', '♠8']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♦6', '♣8', '♥K', '♦K']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥5', '♦6', '♣8', '♥K', '♦K']
# natasja plays ♦6 from hand.
#
# tim's turn
# Top of stack:   ♦6
# Hand:       ['♦9', '♠4', '♣J', '♠Q', '♠8', '♠J', '♥J', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦9', '♣J', '♠Q', '♠8', '♠J', '♥J', '♠A', 'take']
# tim plays ♦9 from hand.
#
# natasja's turn
# Top of stack:   ♦9
# Hand:       ['♥5', '♣8', '♥K', '♦K']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥K', '♦K', 'take']
# natasja plays ♥K from hand.
# natasja can play a double card (K).
# natasja skipped playing a double card.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♠4', '♣J', '♠Q', '♠8', '♠J', '♥J', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♥5', '♣8', '♦K']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♣J', '♠Q', '♠8', '♠J', '♥J']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠4', '♣J', '♠Q', '♠8', '♠J', '♥J']
# tim plays ♠Q from hand.
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♥5', '♣8', '♦K', '♦6', '♦9', '♥K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦K', '♥K', '♠A', 'take']
# natasja plays ♦K from hand.
# natasja can play a double card (K).
# natasja skipped playing a double card.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♠4', '♣J', '♠8', '♠J', '♥J']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♣8', '♦6', '♦9', '♥K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥5', '♣8', '♦6', '♦9', '♥K', '♠A']
# natasja plays ♥5 from hand.
#
# tim's turn
# Top of stack:   ♥5
# Hand:       ['♠4', '♣J', '♠8', '♠J', '♥J', '♠Q', '♦K']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣J', '♠8', '♠J', '♥J', '♠Q', '♦K', 'take']
# tim plays ♠8 from hand.
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       ['♣8', '♦6', '♦9', '♥K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♣8', '♦9', '♥K', '♠A', 'take']
# natasja plays ♣8 from hand.
#
# tim's turn
# Top of stack:   ♣8
# Hand:       ['♠4', '♣J', '♠J', '♥J', '♠Q', '♦K']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♣J', '♠J', '♥J', '♠Q', '♦K', 'take']
# tim plays ♠J from hand.
# tim can play a double card (J).
# tim plays ♥J from hand.
# tim can play a double card (J).
# tim plays ♣J from hand.
#
# natasja's turn
# Top of stack:   ♣J
# Hand:       ['♦6', '♦9', '♥K', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♥K', '♠A', 'take']
# natasja plays ♥K from hand.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♠4', '♠Q', '♦K']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♦K', 'take']
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♦6', '♦9', '♠A']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♠A', 'take']
# natasja plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♠4', '♠Q']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['take']
# tim takes the stack (9 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♦9']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['♦6', '♦9']
# natasja plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♠4', '♠Q', '♥5', '♠8', '♣8', '♠J', '♥J', '♣J', '♥K', '♦K', '♠A']
# Displayed:  ['♠6']
# Hidden:     ['♦J', '♦4', '♥10']
#
# Playable cards: ['♠Q', '♠J', '♥J', '♣J', '♥K', '♦K', '♠A', 'take']
# tim plays ♠J from hand.
# tim can play a double card (J).
# tim plays ♥J from hand.
# tim can play a double card (J).
# tim plays ♣J from hand.
#
# natasja's turn
# Top of stack:   ♣J
# Hand:       ['♦6']
# Displayed:  ['♠7']
# Hidden:     ['♥4', '♣Q', '♣K']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# Game over! Winners in order: ['busse', 'jasper', None]

# %%
game.simulate_games(100)
