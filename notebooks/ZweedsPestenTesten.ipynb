# %% [markdown]
# # **Zweeds Pesten**

# %% [markdown]
# Importeer de benodigde libraries en importeer de class ZweedsPesten

# %%
import sys
import os

# Ophalen path van de src folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Voeg de folder to aan path
if src_path not in sys.path:
    sys.path.append(src_path)

# Importeren van src is nu mogelijk
from utils import ZweedsPesten

# %% [markdown]
# Maakt variabele player_names aan, definieert en initialiseert een ZweedsPesten object genaamd game met de namen van de spelers.
# Bepaalt een winnaar door de game_loop method door te lopen van het ZweedsPesten-object.

# %%
player_names = ["jasper", "busse", "tim", "natasja"]

game = ZweedsPesten(player_names)

winners = game.game_loop(verbose=2)
# Out:
# ------------ Starting Game ------------
# jasper:
# Hand:       ['♠7', '♥7', '♦A']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
# -----------------------------------------
# busse:
# Hand:       ['♠10', '♦Q', '♦K']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
# -----------------------------------------
# tim:
# Hand:       ['♥Q', '♥6', '♠J']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
# -----------------------------------------
# natasja:
# Hand:       ['♦5', '♦2', '♠4']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
# -----------------------------------------
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠7', '♥7', '♦A']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠7', '♥7', '♦A']
# jasper plays ♠7 from hand.
# jasper can play a double card (7).
# jasper plays ♥7 from hand.
# jasper draws a card: ♠5
# jasper draws a card: ♣5
#
# busse's turn
# Top of stack:   ♥7
# Hand:       ['♠10', '♦Q', '♦K']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠10', 'take']
# busse plays ♠10 from hand.
# busse draws a card: ♦9
#
# tim's turn
# Top of stack:   ♠10
# Hand:       ['♥Q', '♥6', '♠J']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♥6', 'take']
# tim plays ♥6 from hand.
# tim draws a card: ♠2
#
# natasja's turn
# Top of stack:   ♥6
# Hand:       ['♦5', '♦2', '♠4']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦2', 'take']
# natasja plays ♦2 from hand.
# natasja draws a card: ♣Q
#
# jasper's turn
# Top of stack:   ♦2
# Hand:       ['♦A', '♠5', '♣5']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦A', '♠5', '♣5', 'take']
# jasper plays ♦A from hand.
# jasper draws a card: ♣J
#
# busse's turn
# Top of stack:   ♦A
# Hand:       ['♦Q', '♦K', '♦9']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (6 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♠J', '♠2']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♥Q', '♠J', '♠2']
# tim plays ♠J from hand.
# tim draws a card: ♦6
#
# natasja's turn
# Top of stack:   ♠J
# Hand:       ['♦5', '♠4', '♣Q']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣Q', 'take']
# natasja plays ♣Q from hand.
# natasja draws a card: ♥2
#
# jasper's turn
# Top of stack:   ♣Q
# Hand:       ['♠5', '♣5', '♣J']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦Q', '♦K', '♦9', '♠7', '♥7', '♠10', '♥6', '♦2', '♦A']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦Q', '♦K', '♦9', '♠7', '♥7', '♠10', '♥6', '♦2', '♦A']
# busse plays ♥7 from hand.
# busse can play a double card (7).
# busse plays ♠7 from hand.
#
# tim's turn
# Top of stack:   ♠7
# Hand:       ['♥Q', '♠2', '♦6']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♠2', '♦6', 'take']
# tim plays ♦6 from hand.
# tim draws a card: ♦8
#
# natasja's turn
# Top of stack:   ♦6
# Hand:       ['♦5', '♠4', '♥2']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♥2', 'take']
# natasja plays ♥2 from hand.
# natasja draws a card: ♣2
#
# jasper's turn
# Top of stack:   ♥2
# Hand:       ['♠5', '♣5', '♣J', '♠J', '♣Q']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠5', '♣5', '♣J', '♠J', '♣Q', 'take']
# jasper plays ♣J from hand.
# jasper can play a double card (J).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣J
# Hand:       ['♦Q', '♦K', '♦9', '♠10', '♥6', '♦2', '♦A']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦Q', '♦K', '♠10', '♦2', '♦A', 'take']
# busse plays ♦2 from hand.
#
# tim's turn
# Top of stack:   ♦2
# Hand:       ['♥Q', '♠2', '♦8']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♥Q', '♠2', '♦8', 'take']
# tim plays ♥Q from hand.
# tim draws a card: ♠Q
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♦5', '♠4', '♣2']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣2', 'take']
# natasja plays ♣2 from hand.
# natasja draws a card: ♥J
#
# jasper's turn
# Top of stack:   ♣2
# Hand:       ['♠5', '♣5', '♠J', '♣Q']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠5', '♣5', '♠J', '♣Q', 'take']
# jasper plays ♠5 from hand.
# jasper can play a double card (5).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♠5
# Hand:       ['♦Q', '♦K', '♦9', '♠10', '♥6', '♦A']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦Q', '♦K', '♦9', '♠10', '♥6', '♦A', 'take']
# busse plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♠2', '♦8', '♠Q']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♠2', '♠Q', 'take']
# tim plays ♠Q from hand.
# tim draws a card: ♠8
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♦5', '♠4', '♥J']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (11 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣5', '♠J', '♣Q']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♣5', '♠J', '♣Q']
# jasper plays ♣5 from hand.
# jasper draws a card: ♦J
#
# busse's turn
# Top of stack:   ♣5
# Hand:       ['♦K', '♦9', '♠10', '♥6', '♦A']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦K', '♦9', '♠10', '♥6', '♦A', 'take']
# busse plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♠2', '♦8', '♠8']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♠2', 'take']
# tim plays ♠2 from hand.
# tim draws a card: ♦10
#
# natasja's turn
# Top of stack:   ♠2
# Hand:       ['♦5', '♠4', '♥J', '♥7', '♠7', '♦6', '♥2', '♣J', '♦2', '♥Q', '♣2', '♠5', '♦Q', '♠Q']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦5', '♠4', '♥J', '♥7', '♠7', '♦6', '♥2', '♣J', '♦2', '♥Q', '♣2', '♠5', '♦Q', '♠Q', 'take']
# natasja plays ♣2 from hand.
# natasja can play a double card (2).
# natasja plays ♥2 from hand.
# natasja can play a double card (2).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥2
# Hand:       ['♠J', '♣Q', '♦J']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠J', '♣Q', '♦J', 'take']
# jasper plays ♦J from hand.
# jasper can play a double card (J).
# jasper plays ♠J from hand.
# jasper draws a card: ♣3
#
# busse's turn
# Top of stack:   ♠J
# Hand:       ['♦K', '♠10', '♥6', '♦A']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦K', '♠10', '♦A', 'take']
# busse plays ♦A from hand.
#
# tim's turn
# Top of stack:   ♦A
# Hand:       ['♦8', '♠8', '♦10']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♦10', 'take']
# tim plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♦5', '♠4', '♥J', '♥7', '♠7', '♦6', '♣J', '♦2', '♥Q', '♠5', '♦Q', '♠Q']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦2', 'take']
# natasja plays ♦2 from hand.
#
# jasper's turn
# Top of stack:   ♦2
# Hand:       ['♣Q', '♣3']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♣Q', '♣3', 'take']
# jasper plays ♣3 from hand.
# jasper played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♣Q']
#
# busse's turn
# Top of stack:   ♣Q
# Hand:       ['♦K', '♠10', '♥6']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦K', '♠10', 'take']
# busse plays ♦K from hand.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♦8', '♠8']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♠4', '♥J', '♥7', '♠7', '♦6', '♣J', '♥Q', '♠5', '♦Q', '♠Q']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦5', '♠4', '♥J', '♥7', '♠7', '♦6', '♣J', '♥Q', '♠5', '♦Q', '♠Q']
# natasja plays ♣J from hand.
# natasja can play a double card (J).
# natasja plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       []
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠10', '♥6']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠10', '♥6']
# busse plays ♥6 from hand.
#
# tim's turn
# Top of stack:   ♥6
# Hand:       ['♦8', '♠8', '♣Q', '♦K']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♦8', '♠8', '♣Q', '♦K', 'take']
# tim plays ♣Q from hand.
#
# natasja's turn
# Top of stack:   ♣Q
# Hand:       ['♦5', '♠4', '♥7', '♠7', '♦6', '♥Q', '♠5', '♦Q', '♠Q']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♥Q', '♦Q', '♠Q', 'take']
# natasja plays ♥Q from hand.
# natasja can play a double card (Q).
# natasja plays ♦Q from hand.
# natasja can play a double card (Q).
# natasja plays ♠Q from hand.
# Four of a kind detected - Stack cleared!
# natasja can play a double card (7).
# natasja plays ♠7 from hand.
#
# jasper's turn
# Top of stack:   ♠7
# Hand:       ['♣J', '♥J']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠10']
# Displayed:  ['♥10', '♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠10']
# busse plays ♠10 from hand.
# busse can play a double card (10).
# busse plays ♥10 from displayed.
#
# tim's turn
# Top of stack:   ♥10
# Hand:       ['♦8', '♠8', '♦K']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♦8', '♠8', '♦K', 'take']
# tim plays ♠8 from hand.
# tim can play a double card (8).
# tim plays ♦8 from hand.
#
# natasja's turn
# Top of stack:   ♦8
# Hand:       ['♦5', '♠4', '♦6', '♠5']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣J', '♥J', '♥7', '♠7']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♣J', '♥J', '♥7', '♠7']
# jasper plays ♥J from hand.
# jasper can play a double card (J).
# jasper plays ♣J from hand.
#
# busse's turn
# Top of stack:   ♣J
# Hand:       []
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦K']
# Displayed:  ['♠A', '♠K', '♥K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♦K']
# tim plays ♦K from hand.
# tim can play a double card (K).
# tim plays ♥K from displayed.
# tim can play a double card (K).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥K
# Hand:       ['♦5', '♠4', '♦6', '♠5', '♠10', '♥10', '♠8', '♦8']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♠10', '♥10', 'take']
# natasja plays ♥10 from hand.
# natasja can play a double card (10).
# natasja plays ♠10 from hand.
#
# jasper's turn
# Top of stack:   ♠10
# Hand:       ['♥7', '♠7']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♣J']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', '♣J']
# busse plays ♥J from hand.
# busse can play a double card (J).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♥J
# Hand:       []
# Displayed:  ['♠A', '♠K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♠A', '♠K', 'take']
# tim plays ♠A from displayed.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♦5', '♠4', '♦6', '♠5', '♠8', '♦8']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♠7', '♦K', '♥K', '♥10', '♠10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥7', '♠7', '♦K', '♥K', '♥10', '♠10']
# jasper plays ♥K from hand.
# jasper can play a double card (K).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♥K
# Hand:       ['♣J']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♠K']
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♠K']
# tim plays ♠K from displayed.
#
# natasja's turn
# Top of stack:   ♠K
# Hand:       ['♦5', '♠4', '♦6', '♠5', '♠8', '♦8', '♥J', '♠A']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♠A', 'take']
# natasja plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♥7', '♠7', '♦K', '♥10', '♠10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥10', '♠10', 'take']
# jasper plays ♠10 from hand.
# jasper can play a double card (10).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♠10
# Hand:       ['♣J', '♥K']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦7', '♣K', '♣10']
#
# Playable cards: ['♣10']
# tim plays ♣10 from hidden.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♦5', '♠4', '♦6', '♠5', '♠8', '♦8', '♥J']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦5', '♠4', '♦6', '♠5', '♠8', '♦8', '♥J', 'take']
# natasja plays ♠4 from hand.
#
# jasper's turn
# Top of stack:   ♠4
# Hand:       ['♥7', '♠7', '♦K', '♥10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥7', '♠7', '♦K', '♥10', 'take']
# jasper plays ♦K from hand.
#
# busse's turn
# Top of stack:   ♦K
# Hand:       ['♣J', '♥K', '♠K', '♠A', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥K', '♠K', '♠A', '♠10', 'take']
# busse plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       []
# Displayed:  []
# Hidden:     ['♦7', '♣K']
#
# Playable cards: ['take']
# tim takes the stack (4 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♦6', '♠5', '♠8', '♦8', '♥J']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦5', '♦6', '♠5', '♠8', '♦8', '♥J']
# natasja plays ♦6 from hand.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♥7', '♠7', '♥10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥7', '♠7', '♥10', 'take']
# jasper plays ♥7 from hand.
# jasper can play a double card (7).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♥7
# Hand:       ['♣J', '♥K', '♠K', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠10', 'take']
# busse plays ♠10 from hand.
#
# tim's turn
# Top of stack:   ♠10
# Hand:       ['♣10', '♠4', '♦K', '♠A']
# Displayed:  []
# Hidden:     ['♦7', '♣K']
#
# Playable cards: ['♣10', '♠4', 'take']
# tim plays ♠4 from hand.
#
# natasja's turn
# Top of stack:   ♠4
# Hand:       ['♦5', '♠5', '♠8', '♦8', '♥J']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦5', '♠5', '♠8', '♦8', '♥J', 'take']
# natasja plays ♦5 from hand.
# natasja can play a double card (5).
# natasja plays ♠5 from hand.
#
# jasper's turn
# Top of stack:   ♠5
# Hand:       ['♠7', '♥10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠7', '♥10', 'take']
# jasper plays ♠7 from hand.
#
# busse's turn
# Top of stack:   ♠7
# Hand:       ['♣J', '♥K', '♠K']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (7 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣10', '♦K', '♠A']
# Displayed:  []
# Hidden:     ['♦7', '♣K']
#
# Playable cards: ['♣10', '♦K', '♠A']
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♠8', '♦8', '♥J']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (1 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥10']
# jasper plays ♥10 from hand.
#
# busse's turn
# Top of stack:   ♥10
# Hand:       ['♣J', '♥K', '♠K', '♦6', '♥7', '♠10', '♠4', '♦5', '♠5', '♠7']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣J', '♥K', '♠K', '♦6', '♥7', '♠10', '♠4', '♦5', '♠5', '♠7', 'take']
# busse plays ♠5 from hand.
# busse can play a double card (5).
# busse plays ♦5 from hand.
#
# tim's turn
# Top of stack:   ♦5
# Hand:       ['♣10', '♠A']
# Displayed:  []
# Hidden:     ['♦7', '♣K']
#
# Playable cards: ['♣10', '♠A', 'take']
# tim plays ♣10 from hand.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♠8', '♦8', '♥J', '♦K']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♠8', '♦8', '♥J', '♦K', 'take']
# natasja plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       []
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♣J', '♥K', '♠K', '♦6', '♥7', '♠10', '♠4', '♠7']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣J', '♥K', '♠K', '♦6', '♥7', '♠10', '♠4', '♠7']
# busse plays ♠10 from hand.
#
# tim's turn
# Top of stack:   ♠10
# Hand:       ['♠A']
# Displayed:  []
# Hidden:     ['♦7', '♣K']
#
# Playable cards: ['♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♠8', '♦8', '♦K']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥10', '♠5', '♦5', '♣10', '♥J']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥10', '♠5', '♦5', '♣10', '♥J']
# jasper plays ♣10 from hand.
# jasper can play a double card (10).
# jasper plays ♥10 from hand.
#
# busse's turn
# Top of stack:   ♥10
# Hand:       ['♣J', '♥K', '♠K', '♦6', '♥7', '♠4', '♠7']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣J', '♥K', '♠K', '♦6', '♥7', '♠4', '♠7', 'take']
# busse plays ♦6 from hand.
#
# tim's turn
# Top of stack:   ♦6
# Hand:       []
# Displayed:  []
# Hidden:     ['♦7', '♣K']
#
# Playable cards: ['♣K', 'take']
# tim plays ♣K from hidden.
#
# natasja's turn
# Top of stack:   ♣K
# Hand:       ['♠8', '♦8', '♦K', '♠10', '♠A']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦K', '♠10', '♠A', 'take']
# natasja plays ♠10 from hand.
#
# jasper's turn
# Top of stack:   ♠10
# Hand:       ['♠5', '♦5', '♥J']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♣J', '♥K', '♠K', '♥7', '♠4', '♠7']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣J', '♥K', '♠K', '♥7', '♠4', '♠7']
# busse plays ♥7 from hand.
# busse can play a double card (7).
# busse plays ♠7 from hand.
#
# tim's turn
# Top of stack:   ♠7
# Hand:       []
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠8', '♦8', '♦K', '♠A']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♠8', '♦8', '♦K', '♠A']
# natasja plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♠5', '♦5', '♥J', '♣10', '♥10', '♦6', '♣K', '♠10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♣10', '♥10', '♠10', 'take']
# jasper plays ♠10 from hand.
# jasper can play a double card (10).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♠10
# Hand:       ['♣J', '♥K', '♠K', '♠4']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♠7']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♥7', '♠7']
# tim plays ♥7 from hand.
# tim can play a double card (7).
# tim plays ♠7 from hand.
#
# natasja's turn
# Top of stack:   ♠7
# Hand:       ['♠8', '♦8', '♦K']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦5', '♥J', '♣10', '♥10', '♦6', '♣K']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠5', '♦5', '♥J', '♣10', '♥10', '♦6', '♣K']
# jasper plays ♠5 from hand.
# jasper can play a double card (5).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♠5
# Hand:       ['♣J', '♥K', '♠K', '♠4', '♠A', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣J', '♥K', '♠K', '♠A', '♠10', 'take']
# busse plays ♠K from hand.
# busse can play a double card (K).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♠K
# Hand:       []
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠8', '♦8', '♦K', '♥7', '♠7']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♠8', '♦8', '♦K', '♥7', '♠7']
# natasja plays ♦8 from hand.
# natasja can play a double card (8).
# natasja plays ♠8 from hand.
#
# jasper's turn
# Top of stack:   ♠8
# Hand:       ['♦5', '♥J', '♣10', '♥10', '♦6', '♣K']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥J', '♣10', '♥10', '♣K', 'take']
# jasper plays ♣10 from hand.
# jasper can play a double card (10).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣10
# Hand:       ['♣J', '♥K', '♠4', '♠A', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣J', '♥K', '♠A', '♠10', 'take']
# busse plays ♠10 from hand.
#
# tim's turn
# Top of stack:   ♠10
# Hand:       ['♠5', '♠K']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠K', 'take']
# tim plays ♠K from hand.
#
# natasja's turn
# Top of stack:   ♠K
# Hand:       ['♦K', '♥7', '♠7']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦K', 'take']
# natasja plays ♦K from hand.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       ['♦5', '♥J', '♥10', '♦6', '♣K']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥10', '♣K', 'take']
# jasper plays ♣K from hand.
#
# busse's turn
# Top of stack:   ♣K
# Hand:       ['♣J', '♥K', '♠4', '♠A']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥K', '♠A', 'take']
# busse plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♠5']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['take']
# tim takes the stack (8 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♠7']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♥7', '♠7']
# natasja plays ♠7 from hand.
# natasja can play a double card (7).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♠7
# Hand:       ['♦5', '♥J', '♥10', '♦6']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦5', '♥10', '♦6', 'take']
# jasper plays ♦6 from hand.
#
# busse's turn
# Top of stack:   ♦6
# Hand:       ['♣J', '♥K', '♠4']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣J', '♥K', 'take']
# busse plays ♣J from hand.
#
# tim's turn
# Top of stack:   ♣J
# Hand:       ['♠5', '♦8', '♠8', '♣10', '♠10', '♠K', '♦K', '♣K', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♣10', '♠10', '♠K', '♦K', '♣K', '♠A', 'take']
# tim plays ♣K from hand.
# tim can play a double card (K).
# tim plays ♠K from hand.
# tim can play a double card (K).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠K
# Hand:       ['♥7']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥J', '♥10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦5', '♥J', '♥10']
# jasper plays ♥J from hand.
#
# busse's turn
# Top of stack:   ♥J
# Hand:       ['♥K', '♠4']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥K', 'take']
# busse plays ♥K from hand.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♠5', '♦8', '♠8', '♣10', '♠10', '♦K', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♣10', '♠10', '♦K', '♠A', 'take']
# tim plays ♣10 from hand.
# tim can play a double card (10).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♥7', '♠7', '♦6', '♣J', '♣K', '♠K']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣K', '♠K', 'take']
# natasja plays ♠K from hand.
# natasja can play a double card (K).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♠K
# Hand:       ['♦5', '♥10']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥10', 'take']
# jasper plays ♥10 from hand.
#
# busse's turn
# Top of stack:   ♥10
# Hand:       ['♠4']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (5 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦8', '♠8', '♠10', '♦K', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠5', '♦8', '♠8', '♠10', '♦K', '♠A']
# tim plays ♦8 from hand.
# tim can play a double card (8).
# tim plays ♠8 from hand.
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       ['♥7', '♠7', '♦6', '♣J', '♣K']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣J', '♣K', 'take']
# natasja plays ♣J from hand.
#
# jasper's turn
# Top of stack:   ♣J
# Hand:       ['♦5']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♥J', '♥K', '♣10', '♠K', '♥10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠4', '♥J', '♥K', '♣10', '♠K', '♥10']
# busse plays ♣10 from hand.
# busse can play a double card (10).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♣10
# Hand:       ['♠5', '♠10', '♦K', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠5', '♠10', '♦K', '♠A', 'take']
# tim plays ♠10 from hand.
#
# natasja's turn
# Top of stack:   ♠10
# Hand:       ['♥7', '♠7', '♦6', '♣K']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♥7', '♠7', '♦6', '♣K', 'take']
# natasja plays ♠7 from hand.
# natasja can play a double card (7).
# natasja plays ♥7 from hand.
#
# jasper's turn
# Top of stack:   ♥7
# Hand:       ['♦5', '♦8', '♠8', '♣J']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦5', 'take']
# jasper plays ♦5 from hand.
#
# busse's turn
# Top of stack:   ♦5
# Hand:       ['♠4', '♥J', '♥K', '♠K', '♥10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', '♥K', '♠K', '♥10', 'take']
# busse plays ♥K from hand.
# busse can play a double card (K).
# busse plays ♠K from hand.
#
# tim's turn
# Top of stack:   ♠K
# Hand:       ['♠5', '♦K', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦K', '♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♦6', '♣K']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (8 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♠8', '♣J']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦8', '♠8', '♣J']
# jasper plays ♣J from hand.
#
# busse's turn
# Top of stack:   ♣J
# Hand:       ['♠4', '♥J', '♥10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', '♥10', 'take']
# busse plays ♥10 from hand.
#
# tim's turn
# Top of stack:   ♥10
# Hand:       ['♠5', '♦K']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦K', 'take']
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♦6', '♣K', '♣10', '♠10', '♠7', '♥7', '♦5', '♥K', '♠K', '♠A']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣K', '♣10', '♠10', '♥K', '♠K', '♠A', 'take']
# natasja plays ♣K from hand.
# natasja can play a double card (K).
# natasja plays ♥K from hand.
# natasja can play a double card (K).
# natasja plays ♠K from hand.
# Four of a kind detected - Stack cleared!
# natasja can play a double card (10).
# natasja plays ♠10 from hand.
#
# jasper's turn
# Top of stack:   ♠10
# Hand:       ['♦8', '♠8']
# Displayed:  ['♠6', '♥5', '♥8']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦8', '♠8', 'take']
# jasper plays ♦8 from hand.
# jasper can play a double card (8).
# jasper plays ♠8 from hand.
# jasper can play a double card (8).
# jasper plays ♥8 from displayed.
#
# busse's turn
# Top of stack:   ♥8
# Hand:       ['♠4', '♥J']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', 'take']
# busse plays ♥J from hand.
#
# tim's turn
# Top of stack:   ♥J
# Hand:       ['♠5']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♠7', '♥7', '♦5', '♠A']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦6', '♠7', '♥7', '♦5', '♠A']
# natasja plays ♥7 from hand.
# natasja can play a double card (7).
# natasja plays ♠7 from hand.
#
# jasper's turn
# Top of stack:   ♠7
# Hand:       []
# Displayed:  ['♠6', '♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠6', '♥5', 'take']
# jasper plays ♠6 from displayed.
#
# busse's turn
# Top of stack:   ♠6
# Hand:       ['♠4']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♣10', '♠10', '♦8', '♠8', '♥8', '♥J']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠5', '♣10', '♠10', '♦8', '♠8', '♥8', '♥J']
# tim plays ♠10 from hand.
# tim can play a double card (10).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠10
# Hand:       ['♦6', '♦5', '♠A']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦6', '♦5', '♠A', 'take']
# natasja plays ♦6 from hand.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       []
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♥7', '♠7', '♠6']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠4', '♥7', '♠7', '♠6']
# busse plays ♠6 from hand.
#
# tim's turn
# Top of stack:   ♠6
# Hand:       ['♠5', '♣10', '♦8', '♠8', '♥8', '♥J']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♣10', '♦8', '♠8', '♥8', '♥J', 'take']
# tim plays ♥J from hand.
#
# natasja's turn
# Top of stack:   ♥J
# Hand:       ['♦5', '♠A']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♠A', 'take']
# natasja plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♠10', '♦6']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠10', 'take']
# jasper plays ♠10 from hand.
#
# busse's turn
# Top of stack:   ♠10
# Hand:       ['♠4', '♥7', '♠7']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♣10', '♦8', '♠8', '♥8']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠5', '♣10', '♦8', '♠8', '♥8']
# tim plays ♣10 from hand.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♦5']
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦5', 'take']
# natasja plays ♦5 from hand.
#
# jasper's turn
# Top of stack:   ♦5
# Hand:       ['♦6']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦6', 'take']
# jasper plays ♦6 from hand.
#
# busse's turn
# Top of stack:   ♦6
# Hand:       ['♠4', '♥7', '♠7', '♠6', '♥J', '♠A', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥7', '♠7', '♠6', '♥J', '♠A', '♠10', 'take']
# busse plays ♥7 from hand.
# busse can play a double card (7).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♥7
# Hand:       ['♠5', '♦8', '♠8', '♥8']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠5', 'take']
# tim plays ♠5 from hand.
#
# natasja's turn
# Top of stack:   ♠5
# Hand:       []
# Displayed:  ['♣9', '♣6', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣9', '♣6', '♣7', 'take']
# natasja plays ♣6 from displayed.
#
# jasper's turn
# Top of stack:   ♣6
# Hand:       []
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (6 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♠7', '♠6', '♥J', '♠A', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠4', '♠7', '♠6', '♥J', '♠A', '♠10']
# busse plays ♠6 from hand.
#
# tim's turn
# Top of stack:   ♠6
# Hand:       ['♦8', '♠8', '♥8']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦8', '♠8', '♥8', 'take']
# tim plays ♥8 from hand.
# tim can play a double card (8).
# tim plays ♠8 from hand.
# tim can play a double card (8).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       []
# Displayed:  ['♣9', '♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣9', 'take']
# natasja plays ♣9 from displayed.
#
# jasper's turn
# Top of stack:   ♣9
# Hand:       ['♣10', '♦5', '♦6', '♥7', '♠5', '♣6']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♣10', 'take']
# jasper plays ♣10 from hand.
#
# busse's turn
# Top of stack:   ♣10
# Hand:       ['♠4', '♠7', '♥J', '♠A', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', '♠A', '♠10', 'take']
# busse plays ♥J from hand.
#
# tim's turn
# Top of stack:   ♥J
# Hand:       ['♦8']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♣7']
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣7']
# natasja plays ♣7 from displayed.
#
# jasper's turn
# Top of stack:   ♣7
# Hand:       ['♦5', '♦6', '♥7', '♠5', '♣6']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦5', '♦6', '♠5', '♣6', 'take']
# jasper plays ♦6 from hand.
# jasper can play a double card (6).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦6
# Hand:       ['♠4', '♠7', '♠A', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠7', '♠A', '♠10', 'take']
# busse plays ♠7 from hand.
#
# tim's turn
# Top of stack:   ♠7
# Hand:       ['♦8', '♠6', '♥8', '♠8', '♣9', '♣10', '♥J']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠6', '♣10', 'take']
# tim plays ♣10 from hand.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       []
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥7', '♠5', '♣6']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦5', '♥7', '♠5', '♣6']
# jasper plays ♥7 from hand.
#
# busse's turn
# Top of stack:   ♥7
# Hand:       ['♠4', '♠A', '♠10']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠4', '♠10', 'take']
# busse plays ♠10 from hand.
#
# tim's turn
# Top of stack:   ♠10
# Hand:       ['♦8', '♠6', '♥8', '♠8', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠6', 'take']
# tim plays ♠6 from hand.
#
# natasja's turn
# Top of stack:   ♠6
# Hand:       ['♣7', '♦6', '♠7', '♣10']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣7', '♦6', '♠7', '♣10', 'take']
# natasja plays ♣7 from hand.
# natasja can play a double card (7).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣7
# Hand:       ['♦5', '♠5', '♣6']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♦5', '♠5', '♣6', 'take']
# jasper plays ♦5 from hand.
# jasper can play a double card (5).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦5
# Hand:       ['♠4', '♠A']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠A', 'take']
# busse plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♦8', '♥8', '♠8', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♠7', '♣10']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦6', '♠7', '♣10']
# natasja plays ♠7 from hand.
#
# jasper's turn
# Top of stack:   ♠7
# Hand:       ['♠5', '♣6']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠5', '♣6', 'take']
# jasper plays ♣6 from hand.
#
# busse's turn
# Top of stack:   ♣6
# Hand:       ['♠4']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♥8', '♠8', '♣9', '♥J', '♥7', '♠10', '♠6', '♣7', '♦5', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦8', '♥8', '♠8', '♣9', '♥J', '♥7', '♠10', '♠6', '♣7', '♦5', '♠A']
# tim plays ♠8 from hand.
# tim can play a double card (8).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       ['♦6', '♣10']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣10', 'take']
# natasja plays ♣10 from hand.
#
# jasper's turn
# Top of stack:   ♣10
# Hand:       ['♠5']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♠7', '♣6']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠4', '♠7', '♣6']
# busse plays ♠4 from hand.
#
# tim's turn
# Top of stack:   ♠4
# Hand:       ['♦8', '♥8', '♣9', '♥J', '♥7', '♠10', '♠6', '♣7', '♦5', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦8', '♥8', '♣9', '♥J', '♥7', '♠10', '♠6', '♣7', '♦5', '♠A', 'take']
# tim plays ♦5 from hand.
#
# natasja's turn
# Top of stack:   ♦5
# Hand:       ['♦6']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦6', 'take']
# natasja plays ♦6 from hand.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♠5', '♠8', '♣10']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠8', '♣10', 'take']
# jasper plays ♠8 from hand.
#
# busse's turn
# Top of stack:   ♠8
# Hand:       ['♠7', '♣6']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♥8', '♣9', '♥J', '♥7', '♠10', '♠6', '♣7', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦8', '♥8', '♣9', '♥J', '♥7', '♠10', '♠6', '♣7', '♠A']
# tim plays ♣7 from hand.
# tim can play a double card (7).
# tim plays ♥7 from hand.
#
# natasja's turn
# Top of stack:   ♥7
# Hand:       []
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♣10']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♠5', '♣10']
# jasper plays ♠5 from hand.
#
# busse's turn
# Top of stack:   ♠5
# Hand:       ['♠7', '♣6', '♠4', '♦5', '♦6', '♠8']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠7', '♣6', '♦5', '♦6', '♠8', 'take']
# busse plays ♣6 from hand.
# busse can play a double card (6).
# busse plays ♦6 from hand.
#
# tim's turn
# Top of stack:   ♦6
# Hand:       ['♦8', '♥8', '♣9', '♥J', '♠10', '♠6', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦8', '♥8', '♣9', '♥J', '♠10', '♠6', '♠A', 'take']
# tim plays ♣9 from hand.
#
# natasja's turn
# Top of stack:   ♣9
# Hand:       ['♣7', '♥7']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣10']
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♣10']
# jasper plays ♣10 from hand.
#
# busse's turn
# Top of stack:   ♣10
# Hand:       ['♠7', '♠4', '♦5', '♠8']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠7', '♠4', '♦5', '♠8', 'take']
# busse plays ♠8 from hand.
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♦8', '♥8', '♥J', '♠10', '♠6', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦8', '♥8', '♥J', '♠10', '♠A', 'take']
# tim plays ♥J from hand.
#
# natasja's turn
# Top of stack:   ♥J
# Hand:       ['♣7', '♥7', '♠5', '♣6', '♦6', '♣9']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥5']
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥5']
# jasper plays ♥5 from displayed.
#
# busse's turn
# Top of stack:   ♥5
# Hand:       ['♠7', '♠4', '♦5']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠7', '♦5', 'take']
# busse plays ♠7 from hand.
#
# tim's turn
# Top of stack:   ♠7
# Hand:       ['♦8', '♥8', '♠10', '♠6', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠10', '♠6', 'take']
# tim plays ♠6 from hand.
#
# natasja's turn
# Top of stack:   ♠6
# Hand:       ['♣7', '♥7', '♠5', '♣6', '♦6', '♣9', '♣10', '♠8', '♥J']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣7', '♥7', '♣6', '♦6', '♣9', '♣10', '♠8', '♥J', 'take']
# natasja plays ♠8 from hand.
#
# jasper's turn
# Top of stack:   ♠8
# Hand:       []
# Displayed:  []
# Hidden:     ['♣A', '♥A', '♥9']
#
# Playable cards: ['♥9', 'take']
# jasper plays ♥9 from hidden.
#
# busse's turn
# Top of stack:   ♥9
# Hand:       ['♠4', '♦5']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (5 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♥8', '♠10', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦8', '♥8', '♠10', '♠A']
# tim plays ♦8 from hand.
# tim can play a double card (8).
# tim plays ♥8 from hand.
#
# natasja's turn
# Top of stack:   ♥8
# Hand:       ['♣7', '♥7', '♠5', '♣6', '♦6', '♣9', '♣10', '♥J']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣9', '♣10', '♥J', 'take']
# natasja plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       []
# Displayed:  []
# Hidden:     ['♣A', '♥A']
#
# Playable cards: ['♥A', 'take']
# jasper plays ♥A from hidden.
#
# busse's turn
# Top of stack:   ♥A
# Hand:       ['♠4', '♦5', '♥5', '♠7', '♠6', '♠8', '♥9']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠10', '♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠10', '♠A']
# tim plays ♠10 from hand.
#
# natasja's turn
# Top of stack:   ♠10
# Hand:       ['♣7', '♥7', '♠5', '♣6', '♦6', '♣9', '♣10']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣7', '♥7', '♠5', '♣6', '♦6', '♣9', '♣10', 'take']
# natasja plays ♣7 from hand.
# natasja can play a double card (7).
# natasja plays ♥7 from hand.
#
# jasper's turn
# Top of stack:   ♥7
# Hand:       []
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦5', '♥5', '♠7', '♠6', '♠8', '♥9', '♦8', '♥8', '♥J', '♥A']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠4', '♦5', '♥5', '♠7', '♠6', '♠8', '♥9', '♦8', '♥8', '♥J', '♥A']
# busse plays ♦5 from hand.
# busse can play a double card (5).
# busse plays ♥5 from hand.
#
# tim's turn
# Top of stack:   ♥5
# Hand:       ['♠A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠A', 'take']
# tim plays ♠A from hand.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♠5', '♣6', '♦6', '♣9', '♣10']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣10', 'take']
# natasja plays ♣10 from hand.
#
# jasper's turn
# Top of stack:   ♣10
# Hand:       ['♠10', '♣7', '♥7']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♠10', 'take']
# jasper plays ♠10 from hand.
#
# busse's turn
# Top of stack:   ♠10
# Hand:       ['♠4', '♠7', '♠6', '♠8', '♥9', '♦8', '♥8', '♥J', '♥A']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥A', 'take']
# busse plays ♥A from hand.
#
# tim's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♣6', '♦6', '♣9']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♠5', '♣6', '♦6', '♣9']
# natasja plays ♠5 from hand.
#
# jasper's turn
# Top of stack:   ♠5
# Hand:       ['♣7', '♥7']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♣7', '♥7', 'take']
# jasper plays ♥7 from hand.
# jasper can play a double card (7).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♥7
# Hand:       ['♠4', '♠7', '♠6', '♠8', '♥9', '♦8', '♥8', '♥J']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠4', '♠6', 'take']
# busse plays ♠4 from hand.
#
# tim's turn
# Top of stack:   ♠4
# Hand:       ['♦5', '♥5', '♠A', '♣10', '♠10', '♥A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦5', '♥5', '♠A', '♣10', '♠10', '♥A', 'take']
# tim plays ♥5 from hand.
# tim can play a double card (5).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥5
# Hand:       ['♣6', '♦6', '♣9']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣6', '♦6', '♣9', 'take']
# natasja plays ♣9 from hand.
#
# jasper's turn
# Top of stack:   ♣9
# Hand:       ['♣7']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠7', '♠6', '♠8', '♥9', '♦8', '♥8', '♥J']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠7', '♠6', '♠8', '♥9', '♦8', '♥8', '♥J']
# busse plays ♦8 from hand.
# busse can play a double card (8).
# busse plays ♠8 from hand.
# busse can play a double card (8).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♦5', '♠A', '♣10', '♠10', '♥A']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠A', '♣10', '♠10', '♥A', 'take']
# tim plays ♥A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥A
# Hand:       ['♣6', '♦6']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣7', '♠5', '♥7', '♠4', '♥5', '♣9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♣7', '♠5', '♥7', '♠4', '♥5', '♣9']
# jasper plays ♣9 from hand.
#
# busse's turn
# Top of stack:   ♣9
# Hand:       ['♠7', '♠6', '♥9', '♥8', '♥J']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥9', '♥J', 'take']
# busse plays ♥J from hand.
#
# tim's turn
# Top of stack:   ♥J
# Hand:       ['♦5', '♠A', '♣10', '♠10']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♠A', '♣10', '♠10', 'take']
# tim plays ♣10 from hand.
# tim can play a double card (10).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♣6', '♦6', '♦8', '♠8', '♥A']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♥A', 'take']
# natasja plays ♥A from hand.
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       ['♣7', '♠5', '♥7', '♠4', '♥5']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠7', '♠6', '♥9', '♥8']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠7', '♠6', '♥9', '♥8']
# busse plays ♠7 from hand.
#
# tim's turn
# Top of stack:   ♠7
# Hand:       ['♦5', '♠A', '♠10']
# Displayed:  []
# Hidden:     ['♦7']
#
# Playable cards: ['♦5', '♠10', 'take']
# tim plays ♠10 from hand.
#
# natasja's turn
# Top of stack:   ♠10
# Hand:       ['♣6', '♦6', '♦8', '♠8']
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♣6', '♦6', 'take']
# natasja plays ♣6 from hand.
# natasja can play a double card (6).
# natasja plays ♦6 from hand.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♣7', '♠5', '♥7', '♠4', '♥5', '♣9', '♥J', '♣10', '♥A']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♣7', '♥7', '♣9', '♥J', '♣10', '♥A', 'take']
# jasper plays ♥7 from hand.
# jasper can play a double card (7).
# jasper plays ♣7 from hand.
#
# busse's turn
# Top of stack:   ♣7
# Hand:       ['♠6', '♥9', '♥8']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# ...
# jasper plays ♥9 from hand.
# jasper can play a double card (9).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♥9
# Hand:       ['♦6', '♠6', '♥8', '♠4', '♣7', '♥J', '♥A']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', '♥A', 'take']
# busse plays ♥A from hand.
#
# natasja's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  []
# Hidden:     ['♠3', '♠9', '♦3']
#
# Playable cards: ['♦3', 'take']
# natasja plays ♦3 from hidden.
# natasja played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♠9']
#
# jasper's turn
# Top of stack:   ♠9
# Hand:       ['♠8', '♥7', '♦8', '♦7', '♥5', '♦5', '♣9', '♠A']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♣9', '♠A', 'take']
# jasper plays ♠A from hand.
#
# busse's turn
# Top of stack:   ♠A
# Hand:       ['♦6', '♠6', '♥8', '♠4', '♣7', '♥J']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♠3']
#
# Playable cards: ['♠3']
# natasja plays ♠3 from hidden.
# natasja has won the game!
#
# jasper's turn
# Top of stack:   ♠3
# Hand:       ['♠8', '♥7', '♦8', '♦7', '♥5', '♦5', '♣9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♠6', '♥8', '♠4', '♣7', '♥J', '♠9', '♠A']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦6', '♠6', '♥8', '♠4', '♣7', '♥J', '♠9', '♠A']
# busse plays ♦6 from hand.
# busse can play a double card (6).
# busse plays ♠6 from hand.
#
# jasper's turn
# Top of stack:   ♠6
# Hand:       ['♠8', '♥7', '♦8', '♦7', '♥5', '♦5', '♣9', '♠3']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♠8', '♥7', '♦8', '♦7', '♣9', '♠3', 'take']
# jasper plays ♠8 from hand.
# jasper can play a double card (8).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♠8
# Hand:       ['♥8', '♠4', '♣7', '♥J', '♠9', '♠A']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥8', '♥J', '♠9', '♠A', 'take']
# busse plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♥7', '♦8', '♦7', '♥5', '♦5', '♣9', '♠3']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♠3', 'take']
# jasper plays ♠3 from hand.
# jasper played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♥7', '♦8', '♦7', '♥5', '♦5', '♣9']
# jasper can play a double card (7).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♥7
# Hand:       ['♥8', '♠4', '♣7', '♥J', '♠9']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠4', 'take']
# busse plays ♠4 from hand.
#
# jasper's turn
# Top of stack:   ♠4
# Hand:       ['♦8', '♦7', '♥5', '♦5', '♣9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♦7', '♥5', '♦5', '♣9', 'take']
# jasper plays ♥5 from hand.
# jasper can play a double card (5).
# jasper plays ♦5 from hand.
#
# busse's turn
# Top of stack:   ♦5
# Hand:       ['♥8', '♣7', '♥J', '♠9']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥8', '♣7', '♥J', '♠9', 'take']
# busse plays ♣7 from hand.
#
# jasper's turn
# Top of stack:   ♣7
# Hand:       ['♦8', '♦7', '♣9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥8', '♥J', '♠9']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥8', '♥J', '♠9']
# busse plays ♥8 from hand.
#
# jasper's turn
# Top of stack:   ♥8
# Hand:       ['♦8', '♦7', '♣9', '♥7', '♠4', '♥5', '♦5', '♣7']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♣9', 'take']
# jasper plays ♣9 from hand.
#
# busse's turn
# Top of stack:   ♣9
# Hand:       ['♥J', '♠9']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', '♠9', 'take']
# busse plays ♠9 from hand.
#
# jasper's turn
# Top of stack:   ♠9
# Hand:       ['♦8', '♦7', '♥7', '♠4', '♥5', '♦5', '♣7']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥J']
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J']
# busse plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       ['♦8', '♦7', '♥7', '♠4', '♥5', '♦5', '♣7', '♥8', '♣9', '♠9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♦4', '♥4']
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦4', '♥4']
# busse plays ♦4 from displayed.
# busse can play a double card (4).
# busse plays ♥4 from displayed.
#
# jasper's turn
# Top of stack:   ♥4
# Hand:       ['♦8', '♦7', '♥7', '♠4', '♥5', '♦5', '♣7', '♥8', '♣9', '♠9', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♦7', '♥7', '♠4', '♥5', '♦5', '♣7', '♥8', '♣9', '♠9', '♥J', 'take']
# jasper plays ♣9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       []
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♦7', '♥7', '♠4', '♥5', '♦5', '♣7', '♥8', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♦7', '♥7', '♠4', '♥5', '♦5', '♣7', '♥8', '♥J']
# jasper plays ♥5 from hand.
# jasper can play a double card (5).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♥5
# Hand:       ['♦4', '♥4', '♣9', '♠9']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣9', '♠9', 'take']
# busse plays ♣9 from hand.
# busse can play a double card (9).
# busse skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣9
# Hand:       ['♦8', '♦7', '♥7', '♠4', '♦5', '♣7', '♥8', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♥J', 'take']
# jasper plays ♥J from hand.
#
# busse's turn
# Top of stack:   ♥J
# Hand:       ['♦4', '♥4', '♠9']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♦7', '♥7', '♠4', '♦5', '♣7', '♥8']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♦7', '♥7', '♠4', '♦5', '♣7', '♥8']
# jasper plays ♥7 from hand.
# jasper can play a double card (7).
# jasper plays ♣7 from hand.
# jasper can play a double card (7).
# jasper plays ♦7 from hand.
#
# busse's turn
# Top of stack:   ♦7
# Hand:       ['♦4', '♥4', '♠9', '♥5', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦4', '♥4', '♥5', 'take']
# busse plays ♥4 from hand.
# busse can play a double card (4).
# busse skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥4
# Hand:       ['♦8', '♠4', '♦5', '♥8']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♠4', '♦5', '♥8', 'take']
# jasper plays ♠4 from hand.
#
# busse's turn
# Top of stack:   ♠4
# Hand:       ['♦4', '♠9', '♥5', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦4', '♠9', '♥5', '♣9', '♥J', 'take']
# busse plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       ['♦8', '♦5', '♥8']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (6 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦4', '♠9', '♥5', '♣9']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦4', '♠9', '♥5', '♣9']
# busse plays ♠9 from hand.
# busse can play a double card (9).
# busse plays ♣9 from hand.
#
# jasper's turn
# Top of stack:   ♣9
# Hand:       ['♦8', '♦5', '♥8', '♥7', '♣7', '♦7', '♥4', '♠4', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♥J', 'take']
# jasper plays ♥J from hand.
#
# busse's turn
# Top of stack:   ♥J
# Hand:       ['♦4', '♥5']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♦5', '♥8', '♥7', '♣7', '♦7', '♥4', '♠4']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♦5', '♥8', '♥7', '♣7', '♦7', '♥4', '♠4']
# jasper plays ♥7 from hand.
# jasper can play a double card (7).
# jasper plays ♦7 from hand.
# jasper can play a double card (7).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦7
# Hand:       ['♦4', '♥5', '♠9', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♦4', '♥5', 'take']
# busse plays ♦4 from hand.
#
# jasper's turn
# Top of stack:   ♦4
# Hand:       ['♦8', '♦5', '♥8', '♣7', '♥4', '♠4']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♦5', '♥8', '♣7', '♥4', '♠4', 'take']
# jasper plays ♥8 from hand.
# jasper can play a double card (8).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♥8
# Hand:       ['♥5', '♠9', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♠9', '♣9', '♥J', 'take']
# busse plays ♠9 from hand.
# busse can play a double card (9).
# busse skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♠9
# Hand:       ['♦8', '♦5', '♣7', '♥4', '♠4']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥5', '♣9', '♥J']
# busse plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       ['♦8', '♦5', '♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♠9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♣9']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥5', '♣9']
# busse plays ♥5 from hand.
#
# jasper's turn
# Top of stack:   ♥5
# Hand:       ['♦8', '♦5', '♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♠9', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♦5', '♣7', '♥7', '♦7', '♥8', '♠9', '♥J', 'take']
# jasper plays ♥J from hand.
#
# busse's turn
# Top of stack:   ♥J
# Hand:       ['♣9']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♦5', '♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♠9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦8', '♦5', '♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♠9']
# jasper plays ♥8 from hand.
# jasper can play a double card (8).
# jasper plays ♦8 from hand.
#
# busse's turn
# Top of stack:   ♦8
# Hand:       ['♣9', '♥5', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣9', '♥J', 'take']
# busse plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       ['♦5', '♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♠9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♣9', '♥5']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣9', '♥5']
# busse plays ♣9 from hand.
#
# jasper's turn
# Top of stack:   ♣9
# Hand:       ['♦5', '♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♠9', '♥8', '♦8', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♠9', '♥J', 'take']
# jasper plays ♥J from hand.
#
# busse's turn
# Top of stack:   ♥J
# Hand:       ['♥5']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♠9', '♥8', '♦8']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦5', '♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♠9', '♥8', '♦8']
# jasper plays ♦5 from hand.
#
# busse's turn
# Top of stack:   ♦5
# Hand:       ['♥5', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥5', '♣9', '♥J', 'take']
# busse plays ♣9 from hand.
#
# jasper's turn
# Top of stack:   ♣9
# Hand:       ['♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♠9', '♥8', '♦8']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♠9', 'take']
# jasper plays ♠9 from hand.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       ['♥5', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', 'take']
# busse plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       ['♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♦8']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥5']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥5']
# busse plays ♥5 from hand.
#
# jasper's turn
# Top of stack:   ♥5
# Hand:       ['♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♦8', '♦5', '♣9', '♠9', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♣7', '♥7', '♦7', '♥8', '♦8', '♦5', '♣9', '♠9', '♥J', 'take']
# jasper plays ♥J from hand.
#
# busse's turn
# Top of stack:   ♥J
# Hand:       []
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♦8', '♦5', '♣9', '♠9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♦8', '♦5', '♣9', '♠9']
# jasper plays ♣9 from hand.
# jasper can play a double card (9).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣9
# Hand:       ['♥5', '♥J']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥J', 'take']
# busse plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       ['♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♦8', '♦5', '♠9']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥5']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥5']
# busse plays ♥5 from hand.
#
# jasper's turn
# Top of stack:   ♥5
# Hand:       ['♣7', '♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♦8', '♦5', '♠9', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♣7', '♥7', '♦7', '♥8', '♦8', '♦5', '♠9', '♣9', '♥J', 'take']
# jasper plays ♣7 from hand.
# jasper can play a double card (7).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣7
# Hand:       []
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♦8', '♦5', '♠9', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♥4', '♠4', '♥7', '♦7', '♦4', '♥8', '♦8', '♦5', '♠9', '♣9', '♥J']
# jasper plays ♠4 from hand.
# jasper can play a double card (4).
# jasper plays ♦4 from hand.
# jasper can play a double card (4).
# jasper plays ♥4 from hand.
#
# busse's turn
# Top of stack:   ♥4
# Hand:       ['♥5', '♣7']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥5', '♣7', 'take']
# busse plays ♣7 from hand.
#
# jasper's turn
# Top of stack:   ♣7
# Hand:       ['♥7', '♦7', '♥8', '♦8', '♦5', '♠9', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♦5', 'take']
# jasper plays ♦5 from hand.
#
# busse's turn
# Top of stack:   ♦5
# Hand:       ['♥5']
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♥5', 'take']
# busse plays ♥5 from hand.
#
# jasper's turn
# Top of stack:   ♥5
# Hand:       ['♥7', '♦7', '♥8', '♦8', '♠9', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♥7', '♦7', '♥8', '♦8', '♠9', '♣9', '♥J', 'take']
# jasper plays ♦8 from hand.
# jasper can play a double card (8).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦8
# Hand:       []
# Displayed:  []
# Hidden:     ['♣4', '♥3', '♣8']
#
# Playable cards: ['♣8', 'take']
# busse plays ♣8 from hidden.
#
# jasper's turn
# Top of stack:   ♣8
# Hand:       ['♥7', '♦7', '♥8', '♠9', '♣9', '♥J']
# Displayed:  []
# Hidden:     ['♣A']
#
# Playable cards: ['♥8', '♠9', '♣9', '♥J', 'take']
# jasper plays ♣9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       []
# Displayed:  []
# Hidden:     ['♣4', '♥3']
#
# Playable cards: ['♥3', 'take']
# busse plays ♥3 from hidden.
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♣4']
# busse has won the game!
#
# Game over! Winners in order: ['tim', 'natasja', 'busse']

# %% [markdown]
# Laat zien bij hoeveel rondes van het spel de spelers de eerste plaats (goud), de tweede plaats (zilver) of de derde plaats (brons) hebben behaald.

# %%
game.simulate_games(10)

# %%
game.deck
# Out:
# []

# %%
game.medals
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 game.medals
#
# AttributeError: 'ZweedsPesten' object has no attribute 'medals'

# %%
game.points
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 game.points
#
# AttributeError: 'ZweedsPesten' object has no attribute 'points'

# %%
game.placements
# Out:
# {}

# %%
game.players
# Out:
# [<main.Player at 0x25c0e716570>,
#  <main.Player at 0x25c0e9a7560>,
#  <main.Player at 0x25c0e9a7770>,
#  <main.Player at 0x25c0e9a78c0>]

# %% [markdown]
# Laat de winnaars van het spel zien.

# %%
game.winners
# Out:
# ['jasper', 'busse', 'natasja']
