# %% [markdown]
# # **Zweeds Pesten**

# %% [markdown]
# Importeer de benodigde libraries en importeer de class ZweedsPesten

# %%
import sys
import os

# Ophalen path van de src folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Voeg de folder to aan path
if src_path not in sys.path:
    sys.path.append(src_path)

# Importeren van src is nu mogelijk
from utils import ZweedsPesten

# %% [markdown]
# Maakt variabele player_names aan, definieert en initialiseert een ZweedsPesten object genaamd game met de namen van de spelers.
# Bepaalt een winnaar door de game_loop method door te lopen van het ZweedsPesten-object.

# %%
# Lijst met spelers
player_names = ["jasper", "busse", "tim", "natasja", "low", "justice_and_terror", "low_noon", "random_go"]

# Opstarten spel met speler lijst
game = ZweedsPesten(player_names)

# Simuleren van een enkele game
winners = game.game_loop(verbose=2)
# Out:
# ------------ Starting Game ------------
# jasper:
# Hand:       ['♦9', '♣J', '♥8']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
# -----------------------------------------
# busse:
# Hand:       ['♥4', '♣Q', '♠6']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
# -----------------------------------------
# tim:
# Hand:       ['♦J', '♣4', '♣10']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
# -----------------------------------------
# natasja:
# Hand:       ['♣5', '♥6', '♣7']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
# -----------------------------------------
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦9', '♣J', '♥8']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♦9', '♣J', '♥8']
# jasper plays ♥8 from hand.
# jasper draws a card: ♠5
#
# busse's turn
# Top of stack:   ♥8
# Hand:       ['♥4', '♣Q', '♠6']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♣Q', 'take']
# busse plays ♣Q from hand.
# busse draws a card: ♥5
#
# tim's turn
# Top of stack:   ♣Q
# Hand:       ['♦J', '♣4', '♣10']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣10', 'take']
# tim plays ♣10 from hand.
# tim draws a card: ♦2
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♣5', '♥6', '♣7']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦9', '♣J', '♠5']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♦9', '♣J', '♠5']
# jasper plays ♠5 from hand.
# jasper draws a card: ♠2
#
# busse's turn
# Top of stack:   ♠5
# Hand:       ['♥4', '♠6', '♥5']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♠6', '♥5', 'take']
# busse plays ♥5 from hand.
# busse draws a card: ♦6
#
# tim's turn
# Top of stack:   ♥5
# Hand:       ['♦J', '♣4', '♦2']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♦J', '♦2', 'take']
# tim plays ♦J from hand.
# tim draws a card: ♠7
#
# natasja's turn
# Top of stack:   ♦J
# Hand:       ['♣5', '♥6', '♣7', '♥8', '♣Q', '♣10']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♣Q', '♣10', 'take']
# natasja plays ♣Q from hand.
#
# jasper's turn
# Top of stack:   ♣Q
# Hand:       ['♦9', '♣J', '♠2']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♠2', 'take']
# jasper plays ♠2 from hand.
# jasper draws a card: ♠10
#
# busse's turn
# Top of stack:   ♠2
# Hand:       ['♥4', '♠6', '♦6']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♥4', '♠6', '♦6', 'take']
# busse plays ♥4 from hand.
# busse draws a card: ♣9
#
# tim's turn
# Top of stack:   ♥4
# Hand:       ['♣4', '♦2', '♠7']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣4', '♦2', '♠7', 'take']
# tim plays ♣4 from hand.
# tim draws a card: ♦4
#
# natasja's turn
# Top of stack:   ♣4
# Hand:       ['♣5', '♥6', '♣7', '♥8', '♣10']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♣5', '♥6', '♣7', '♥8', '♣10', 'take']
# natasja plays ♣10 from hand.
#
# jasper's turn
# Top of stack:   ♣10
# Hand:       ['♦9', '♣J', '♠10']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♦9', '♣J', '♠10', 'take']
# jasper plays ♦9 from hand.
# jasper draws a card: ♥9
#
# busse's turn
# Top of stack:   ♦9
# Hand:       ['♠6', '♦6', '♣9']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♣9', 'take']
# busse plays ♣9 from hand.
# busse draws a card: ♠4
#
# tim's turn
# Top of stack:   ♣9
# Hand:       ['♦2', '♠7', '♦4']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♦2', 'take']
# tim plays ♦2 from hand.
# tim draws a card: ♦A
#
# natasja's turn
# Top of stack:   ♦2
# Hand:       ['♣5', '♥6', '♣7', '♥8']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♣5', '♥6', '♣7', '♥8', 'take']
# natasja plays ♣5 from hand.
#
# jasper's turn
# Top of stack:   ♣5
# Hand:       ['♣J', '♠10', '♥9']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♣J', '♠10', '♥9', 'take']
# jasper plays ♥9 from hand.
# jasper draws a card: ♣8
#
# busse's turn
# Top of stack:   ♥9
# Hand:       ['♠6', '♦6', '♠4']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['take']
# busse takes the stack (13 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠7', '♦4', '♦A']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♠7', '♦4', '♦A']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥6', '♣7', '♥8']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♥6', '♣7', '♥8']
# natasja plays ♥6 from hand.
# natasja draws a card: ♥7
#
# jasper's turn
# Top of stack:   ♥6
# Hand:       ['♣J', '♠10', '♣8']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♣J', '♠10', '♣8', 'take']
# jasper plays ♣8 from hand.
# jasper draws a card: ♠J
#
# busse's turn
# Top of stack:   ♣8
# Hand:       ['♠6', '♦6', '♠4', '♠5', '♥5', '♦J', '♣Q', '♠2', '♥4', '♣4', '♣10', '♦9', '♣9', '♦2', '♣5', '♥9']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♦J', '♣Q', '♠2', '♣10', '♦9', '♣9', '♦2', '♥9', 'take']
# busse plays ♦9 from hand.
# busse can play a double card (9).
# busse plays ♣9 from hand.
# busse can play a double card (9).
# busse plays ♥9 from hand.
#
# tim's turn
# Top of stack:   ♥9
# Hand:       ['♠7', '♦4', '♦A']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♦A', 'take']
# tim plays ♦A from hand.
# tim draws a card: ♦7
#
# natasja's turn
# Top of stack:   ♦A
# Hand:       ['♣7', '♥8', '♥7']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['take']
# natasja takes the stack (6 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣J', '♠10', '♠J']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♣J', '♠10', '♠J']
# jasper plays ♣J from hand.
# jasper can play a double card (J).
# jasper plays ♠J from hand.
#
# busse's turn
# Top of stack:   ♠J
# Hand:       ['♠6', '♦6', '♠4', '♠5', '♥5', '♦J', '♣Q', '♠2', '♥4', '♣4', '♣10', '♦2', '♣5']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♦J', '♣Q', '♠2', '♣10', '♦2', 'take']
# busse plays ♦J from hand.
#
# tim's turn
# Top of stack:   ♦J
# Hand:       ['♠7', '♦4', '♦7']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣7', '♥8', '♥7', '♥6', '♣8', '♦9', '♣9', '♥9', '♦A']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♣7', '♥8', '♥7', '♥6', '♣8', '♦9', '♣9', '♥9', '♦A']
# natasja plays ♥6 from hand.
#
# jasper's turn
# Top of stack:   ♥6
# Hand:       ['♠10']
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♠10', 'take']
# jasper plays ♠10 from hand.
#
# busse's turn
# Top of stack:   ♠10
# Hand:       ['♠6', '♦6', '♠4', '♠5', '♥5', '♣Q', '♠2', '♥4', '♣4', '♣10', '♦2', '♣5']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♠6', '♦6', '♣Q', '♠2', '♣10', '♦2', 'take']
# busse plays ♠6 from hand.
# busse can play a double card (6).
# busse plays ♦6 from hand.
#
# tim's turn
# Top of stack:   ♦6
# Hand:       ['♠7', '♦4', '♦7', '♣J', '♠J', '♦J']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♠7', '♦7', '♣J', '♠J', '♦J', 'take']
# tim plays ♠7 from hand.
# tim can play a double card (7).
# tim plays ♦7 from hand.
#
# natasja's turn
# Top of stack:   ♦7
# Hand:       ['♣7', '♥8', '♥7', '♣8', '♦9', '♣9', '♥9', '♦A']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['take']
# natasja takes the stack (6 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥A', '♠K', '♥J']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♥A', '♠K', '♥J']
# jasper plays ♥J from displayed.
#
# busse's turn
# Top of stack:   ♥J
# Hand:       ['♠4', '♠5', '♥5', '♣Q', '♠2', '♥4', '♣4', '♣10', '♦2', '♣5']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♣Q', '♠2', '♣10', '♦2', 'take']
# busse plays ♣Q from hand.
#
# tim's turn
# Top of stack:   ♣Q
# Hand:       ['♦4', '♣J', '♠J', '♦J']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣7', '♥8', '♥7', '♣8', '♦9', '♣9', '♥9', '♦A', '♥6', '♠10', '♠6', '♦6', '♠7', '♦7']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♣7', '♥8', '♥7', '♣8', '♦9', '♣9', '♥9', '♦A', '♥6', '♠10', '♠6', '♦6', '♠7', '♦7']
# natasja plays ♠10 from hand.
#
# jasper's turn
# Top of stack:   ♠10
# Hand:       []
# Displayed:  ['♥A', '♠K']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♥A', '♠K', 'take']
# jasper plays ♠K from displayed.
#
# busse's turn
# Top of stack:   ♠K
# Hand:       ['♠4', '♠5', '♥5', '♠2', '♥4', '♣4', '♣10', '♦2', '♣5']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♠2', '♣10', '♦2', 'take']
# busse plays ♣10 from hand.
#
# tim's turn
# Top of stack:   ♣10
# Hand:       ['♦4', '♣J', '♠J', '♦J', '♥J', '♣Q']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣7', '♥8', '♥7', '♣8', '♦9', '♣9', '♥9', '♦A', '♥6', '♠6', '♦6', '♠7', '♦7']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♣7', '♥8', '♥7', '♣8', '♦9', '♣9', '♥9', '♦A', '♥6', '♠6', '♦6', '♠7', '♦7']
# natasja plays ♥6 from hand.
# natasja can play a double card (6).
# natasja plays ♠6 from hand.
# natasja can play a double card (6).
# natasja plays ♦6 from hand.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       []
# Displayed:  ['♥A']
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♥A', 'take']
# jasper plays ♥A from displayed.
#
# busse's turn
# Top of stack:   ♥A
# Hand:       ['♠4', '♠5', '♥5', '♠2', '♥4', '♣4', '♦2', '♣5']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♠2', '♦2', 'take']
# busse plays ♠2 from hand.
# busse can play a double card (2).
# busse plays ♦2 from hand.
#
# tim's turn
# Top of stack:   ♦2
# Hand:       ['♦4', '♣J', '♠J', '♦J', '♥J', '♣Q', '♠10', '♠K', '♣10']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♦4', '♣J', '♠J', '♦J', '♥J', '♣Q', '♠10', '♠K', '♣10', 'take']
# tim plays ♦4 from hand.
#
# natasja's turn
# Top of stack:   ♦4
# Hand:       ['♣7', '♥8', '♥7', '♣8', '♦9', '♣9', '♥9', '♦A', '♠7', '♦7']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♣7', '♥8', '♥7', '♣8', '♦9', '♣9', '♥9', '♦A', '♠7', '♦7', 'take']
# natasja plays ♣7 from hand.
# natasja can play a double card (7).
# natasja plays ♥7 from hand.
# natasja can play a double card (7).
# natasja plays ♠7 from hand.
# natasja can play a double card (7).
# natasja plays ♦7 from hand.
# Four of a kind detected - Stack cleared!
# natasja can play a double card (8).
# natasja plays ♣8 from hand.
#
# jasper's turn
# Top of stack:   ♣8
# Hand:       []
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♠5', '♥5', '♥4', '♣4', '♣5']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♠4', '♠5', '♥5', '♥4', '♣4', '♣5']
# busse plays ♠4 from hand.
# busse can play a double card (4).
# busse plays ♥4 from hand.
# busse can play a double card (4).
# busse plays ♣4 from hand.
#
# tim's turn
# Top of stack:   ♣4
# Hand:       ['♣J', '♠J', '♦J', '♥J', '♣Q', '♠10', '♠K', '♣10']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣J', '♠J', '♦J', '♥J', '♣Q', '♠10', '♠K', '♣10', 'take']
# tim plays ♠10 from hand.
# tim can play a double card (10).
# tim plays ♣10 from hand.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♦9', '♣9', '♥9', '♦A']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♦9', '♣9', '♥9', '♦A', 'take']
# natasja plays ♦9 from hand.
# natasja can play a double card (9).
# natasja plays ♣9 from hand.
# natasja can play a double card (9).
# natasja plays ♥9 from hand.
#
# jasper's turn
# Top of stack:   ♥9
# Hand:       ['♥8', '♣8']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['take']
# jasper takes the stack (8 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♥5', '♣5']
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♠5', '♥5', '♣5']
# busse plays ♠5 from hand.
# busse can play a double card (5).
# busse plays ♥5 from hand.
# busse can play a double card (5).
# busse plays ♣5 from hand.
#
# tim's turn
# Top of stack:   ♣5
# Hand:       ['♣J', '♠J', '♦J', '♥J', '♣Q', '♠K']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣J', '♠J', '♦J', '♥J', '♣Q', '♠K', 'take']
# tim plays ♣J from hand.
# tim can play a double card (J).
# tim plays ♥J from hand.
# tim can play a double card (J).
# tim plays ♦J from hand.
# tim can play a double card (J).
# tim plays ♠J from hand.
# Four of a kind detected - Stack cleared!
#
# natasja's turn
# Top of stack:   ♣Q
# Hand:       ['♦A']
# Displayed:  ['♣A', '♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♦A', 'take']
# natasja plays ♦A from hand.
# natasja can play a double card (A).
# natasja plays ♣A from displayed.
#
# jasper's turn
# Top of stack:   ♣A
# Hand:       ['♥8', '♣8', '♠4', '♥4', '♣4', '♠10', '♣10', '♦9', '♣9', '♥9']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♠10', '♣10', 'take']
# jasper plays ♠10 from hand.
# jasper can play a double card (10).
# jasper plays ♣10 from hand.
#
# busse's turn
# Top of stack:   ♣10
# Hand:       []
# Displayed:  ['♠3', '♦10', '♥10']
# Hidden:     ['♦8', '♣2', '♠9']
#
# Playable cards: ['♠3', '♦10', '♥10', 'take']
# busse plays ♦10 from displayed.
# busse can play a double card (10).
# busse plays ♥10 from displayed.
# Four of a kind detected - Stack cleared!
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♠9']
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♠K']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♠K', 'take']
# tim plays ♠K from hand.
#
# natasja's turn
# Top of stack:   ♠K
# Hand:       []
# Displayed:  ['♣K', '♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♣K', 'take']
# natasja plays ♣K from displayed.
#
# jasper's turn
# Top of stack:   ♣K
# Hand:       ['♥8', '♣8', '♠4', '♥4', '♣4', '♦9', '♣9', '♥9']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8', '♣2']
#
# Playable cards: ['♣2']
# busse plays ♣2 from hidden.
#
# tim's turn
# Top of stack:   ♣2
# Hand:       []
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♥3', '♦3', '♥2', 'take']
# tim takes the stack (1 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥Q']
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♥Q']
# natasja plays ♥Q from displayed.
#
# jasper's turn
# Top of stack:   ♥Q
# Hand:       ['♥8', '♣8', '♠4', '♥4', '♣4', '♦9', '♣9', '♥9', '♠9', '♠K', '♣K']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♠K', '♣K', 'take']
# jasper plays ♠K from hand.
# jasper can play a double card (K).
# jasper plays ♣K from hand.
#
# busse's turn
# Top of stack:   ♣K
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣2']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣2']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♣3', '♦Q', '♥K']
#
# Playable cards: ['♥K']
# natasja plays ♥K from hidden.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       ['♥8', '♣8', '♠4', '♥4', '♣4', '♦9', '♣9', '♥9', '♠9']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♠K', '♣K']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♥Q', '♠K', '♣K']
# busse plays ♥Q from hand.
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       ['♣2']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣2', 'take']
# tim plays ♣2 from hand.
# tim can play a double card (2).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♣2
# Hand:       []
# Displayed:  []
# Hidden:     ['♣3', '♦Q']
#
# Playable cards: ['♦Q', 'take']
# natasja plays ♦Q from hidden.
#
# jasper's turn
# Top of stack:   ♦Q
# Hand:       ['♥8', '♣8', '♠4', '♥4', '♣4', '♦9', '♣9', '♥9', '♠9', '♥K']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♥K', 'take']
# jasper plays ♥K from hand.
#
# busse's turn
# Top of stack:   ♥K
# Hand:       ['♠K', '♣K']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♠K', '♣K', 'take']
# busse plays ♠K from hand.
# busse can play a double card (K).
# busse plays ♣K from hand.
#
# tim's turn
# Top of stack:   ♣K
# Hand:       []
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♥3', '♦3', '♥2', 'take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♣3']
#
# Playable cards: ['♣3']
# natasja plays ♣3 from hidden.
# natasja has won the game!
#
# jasper's turn
# Top of stack:   ♣3
# Hand:       ['♥8', '♣8', '♠4', '♥4', '♣4', '♦9', '♣9', '♥9', '♠9']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# busse plays ♦8 from hidden.
# busse has won the game!
#
# tim's turn
# Top of stack:   ♦8
# Hand:       ['♥Q', '♣2', '♦Q', '♥K', '♠K', '♣K']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♥Q', '♣2', '♦Q', '♥K', '♠K', '♣K', 'take']
# tim plays ♥Q from hand.
# tim can play a double card (Q).
# tim plays ♦Q from hand.
#
# jasper's turn
# Top of stack:   ♦Q
# Hand:       ['♥8', '♣8', '♠4', '♥4', '♣4', '♦9', '♣9', '♥9', '♠9', '♣3']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♣3', 'take']
# jasper plays ♣3 from hand.
# jasper played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♥8', '♣8', '♠4', '♥4', '♣4', '♦9', '♣9', '♥9', '♠9']
# jasper can play a double card (4).
# jasper plays ♥4 from hand.
# jasper can play a double card (4).
# jasper plays ♣4 from hand.
#
# tim's turn
# Top of stack:   ♣4
# Hand:       ['♣2', '♥K', '♠K', '♣K']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣2', '♥K', '♠K', '♣K', 'take']
# tim plays ♥K from hand.
# tim can play a double card (K).
# tim plays ♣K from hand.
# tim can play a double card (K).
# tim plays ♠K from hand.
#
# jasper's turn
# Top of stack:   ♠K
# Hand:       ['♥8', '♣8', '♦9', '♣9', '♥9', '♠9']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['take']
# jasper takes the stack (6 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣2']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣2']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥8', '♣8', '♦9', '♣9', '♥9', '♠9', '♠4', '♥4', '♣4', '♥K', '♣K', '♠K']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♥8', '♣8', '♦9', '♣9', '♥9', '♠9', '♠4', '♥4', '♣4', '♥K', '♣K', '♠K']
# jasper plays ♠4 from hand.
# jasper can play a double card (4).
# jasper plays ♥4 from hand.
# jasper can play a double card (4).
# jasper plays ♣4 from hand.
#
# tim's turn
# Top of stack:   ♣4
# Hand:       ['♣2']
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♣2', 'take']
# tim plays ♣2 from hand.
# tim can play a double card (2).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣2
# Hand:       ['♥8', '♣8', '♦9', '♣9', '♥9', '♠9', '♥K', '♣K', '♠K']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♥8', '♣8', '♦9', '♣9', '♥9', '♠9', '♥K', '♣K', '♠K', 'take']
# jasper plays ♥8 from hand.
# jasper can play a double card (8).
# jasper plays ♣8 from hand.
#
# tim's turn
# Top of stack:   ♣8
# Hand:       []
# Displayed:  ['♥3', '♦3', '♥2']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♥3', '♦3', '♥2', 'take']
# tim plays ♥2 from displayed.
#
# jasper's turn
# Top of stack:   ♥2
# Hand:       ['♦9', '♣9', '♥9', '♠9', '♥K', '♣K', '♠K']
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♦9', '♣9', '♥9', '♠9', '♥K', '♣K', '♠K', 'take']
# jasper plays ♦9 from hand.
# jasper can play a double card (9).
# jasper plays ♣9 from hand.
# jasper can play a double card (9).
# jasper plays ♥9 from hand.
# jasper can play a double card (9).
# jasper plays ♠9 from hand.
# Four of a kind detected - Stack cleared!
# jasper can play a double card (K).
# jasper plays ♣K from hand.
# jasper can play a double card (K).
# jasper plays ♠K from hand.
#
# tim's turn
# Top of stack:   ♠K
# Hand:       []
# Displayed:  ['♥3', '♦3']
# Hidden:     ['♠A', '♠8', '♦5']
#
# Playable cards: ['♥3', '♦3', 'take']
# tim plays ♥3 from displayed.
# tim played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♦3']
# tim played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♦5']
#
# jasper's turn
# Top of stack:   ♦5
# Hand:       []
# Displayed:  []
# Hidden:     ['♠Q', '♦K', '♣6']
#
# Playable cards: ['♣6', 'take']
# jasper plays ♣6 from hidden.
#
# tim's turn
# Top of stack:   ♣6
# Hand:       []
# Displayed:  []
# Hidden:     ['♠A', '♠8']
#
# Playable cards: ['♠8', 'take']
# tim plays ♠8 from hidden.
#
# jasper's turn
# Top of stack:   ♠8
# Hand:       []
# Displayed:  []
# Hidden:     ['♠Q', '♦K']
#
# Playable cards: ['♦K', 'take']
# jasper plays ♦K from hidden.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       []
# Displayed:  []
# Hidden:     ['♠A']
#
# Playable cards: ['♠A', 'take']
# tim plays ♠A from hidden.
# tim has won the game!
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# jasper is the last remaining player. No further turns needed.
#
# Game over! Winners in order: ['natasja', 'busse', 'tim']

# %% [markdown]
# Laat zien bij hoeveel rondes van het spel de spelers de eerste plaats (goud), de tweede plaats (zilver) of de derde plaats (brons) hebben behaald.

# %%
# Het simuleren van 10000 games
game.simulate_games(10)
# Out:
# Algemene performance in nummers:
#                     Aantal Games  Aantal Punten   1st   2nd   3rd   DNF  \
# jasper                      8400          12335  2067  2196  1742  2395
# busse                       8400          17303  3589  2528  1480   803
# tim                         8400           6270   848  1079  1568  4905
# natasja                     8400          13521  2175  2431  2134  1660
# low                         8400          12435  2131  2157  1728  2384
# justice_and_terror          8400          12128  1938  2198  1918  2346
# low_noon                    8400          14908  2796  2309  1902  1393
# random_go                   8400           7910  1193  1354  1623  4230
#
#                    1st Ratio 2nd Ratio 3rd Ratio DNF Ratio  Gem Eindpositie  \
# jasper                24.61%    26.14%    20.74%    28.51%             2.53
# busse                 42.73%     30.1%    17.62%     9.56%             1.94
# tim                    10.1%    12.85%    18.67%    58.39%             3.25
# natasja               25.89%    28.94%     25.4%    19.76%             2.39
# low                   25.37%    25.68%    20.57%    28.38%             2.52
# justice_and_terror    23.07%    26.17%    22.83%    27.93%             2.56
# low_noon              33.29%    27.49%    22.64%    16.58%             2.23
# random_go              14.2%    16.12%    19.32%    50.36%             3.06
#
#                     Gem punten per game
# jasper                             1.47
# busse                              2.06
# tim                                0.75
# natasja                            1.61
# low                                1.48
# justice_and_terror                 1.44
# low_noon                           1.77
# random_go                          0.94
# Overwinningen vanaf verschillende startplekken:
# Punten en Podium verdeling:
# Performance per speler per combinatie van spelers:
