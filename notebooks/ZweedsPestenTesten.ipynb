# %% [markdown]
# # **Zweeds Pesten**

# %%
import sys
import os

# Ophalen path van de src folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Voeg de folder to aan path
if src_path not in sys.path:
    sys.path.append(src_path)

# Importeren van src is nu mogelijk
from utils import ZweedsPesten

# %%
player_names = ["jasper", "busse", "tim", "natasja"]

game = ZweedsPesten(player_names)

winners = game.game_loop(verbose=2)
# Out:
# ------------ Starting Game ------------
# jasper:
# Hand:       ['♥4', '♥9', '♣Q']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
# -----------------------------------------
# busse:
# Hand:       ['♠2', '♠10', '♥A']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
# -----------------------------------------
# tim:
# Hand:       ['♦Q', '♠4', '♣K']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
# -----------------------------------------
# natasja:
# Hand:       ['♦5', '♦8', '♥10']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
# -----------------------------------------
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥4', '♥9', '♣Q']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♥4', '♥9', '♣Q']
# jasper plays ♥4 from hand.
# jasper draws a card: ♥3
#
# busse's turn
# Top of stack:   ♥4
# Hand:       ['♠2', '♠10', '♥A']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♠2', '♠10', '♥A', 'take']
# busse plays ♠2 from hand.
# busse draws a card: ♥Q
#
# tim's turn
# Top of stack:   ♠2
# Hand:       ['♦Q', '♠4', '♣K']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♦Q', '♠4', '♣K', 'take']
# tim plays ♦Q from hand.
# tim draws a card: ♠K
#
# natasja's turn
# Top of stack:   ♦Q
# Hand:       ['♦5', '♦8', '♥10']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥10', 'take']
# natasja plays ♥10 from hand.
# natasja draws a card: ♣5
#
# jasper's turn
# Top of stack:   ♥10
# Hand:       ['♥9', '♣Q', '♥3']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♣Q', '♥3', 'take']
# jasper plays ♣Q from hand.
# jasper draws a card: ♣J
#
# busse's turn
# Top of stack:   ♣Q
# Hand:       ['♠10', '♥A', '♥Q']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♠10', '♥A', '♥Q', 'take']
# busse plays ♠10 from hand.
# busse draws a card: ♥2
#
# tim's turn
# Top of stack:   ♠10
# Hand:       ['♠4', '♣K', '♠K']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♣K', '♠K', 'take']
# tim plays ♣K from hand.
# tim can play a double card (K).
# tim skipped playing a double card.
# tim draws a card: ♠Q
#
# natasja's turn
# Top of stack:   ♣K
# Hand:       ['♦5', '♦8', '♣5']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (7 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥9', '♥3', '♣J']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♥9', '♥3', '♣J']
# jasper plays ♥9 from hand.
# jasper draws a card: ♠8
#
# busse's turn
# Top of stack:   ♥9
# Hand:       ['♥A', '♥Q', '♥2']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♥A', '♥Q', '♥2', 'take']
# busse plays ♥A from hand.
# busse draws a card: ♠3
#
# tim's turn
# Top of stack:   ♥A
# Hand:       ['♠4', '♠K', '♠Q']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♦8', '♣5', '♥4', '♠2', '♦Q', '♥10', '♣Q', '♠10', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♦8', '♣5', '♥4', '♠2', '♦Q', '♥10', '♣Q', '♠10', '♣K']
# natasja plays ♣5 from hand.
# natasja can play a double card (5).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣5
# Hand:       ['♥3', '♣J', '♠8']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♥3', '♣J', '♠8', 'take']
# jasper plays ♠8 from hand.
# jasper draws a card: ♥8
#
# busse's turn
# Top of stack:   ♠8
# Hand:       ['♥Q', '♥2', '♠3']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♥Q', '♥2', '♠3', 'take']
# busse plays ♥2 from hand.
# busse draws a card: ♠J
#
# tim's turn
# Top of stack:   ♥2
# Hand:       ['♠4', '♠K', '♠Q', '♥9', '♥A']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♠K', '♠Q', '♥9', '♥A', 'take']
# tim plays ♥9 from hand.
#
# natasja's turn
# Top of stack:   ♥9
# Hand:       ['♦5', '♦8', '♥4', '♠2', '♦Q', '♥10', '♣Q', '♠10', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠2', '♦Q', '♥10', '♣Q', '♠10', '♣K', 'take']
# natasja plays ♠10 from hand.
# natasja can play a double card (10).
# natasja plays ♥10 from hand.
#
# jasper's turn
# Top of stack:   ♥10
# Hand:       ['♥3', '♣J', '♥8']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♥3', '♣J', 'take']
# jasper plays ♣J from hand.
# jasper draws a card: ♦J
#
# busse's turn
# Top of stack:   ♣J
# Hand:       ['♥Q', '♠3', '♠J']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♥Q', '♠3', '♠J', 'take']
# busse plays ♠3 from hand.
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♥Q', '♠J']
# busse draws a card: ♦6
# busse draws a card: ♦A
#
# tim's turn
# Top of stack:   ♠J
# Hand:       ['♠4', '♠K', '♠Q', '♥A']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠K', '♠Q', '♥A', 'take']
# tim plays ♥A from hand.
#
# natasja's turn
# Top of stack:   ♥A
# Hand:       ['♦5', '♦8', '♥4', '♠2', '♦Q', '♣Q', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠2', 'take']
# natasja plays ♠2 from hand.
#
# jasper's turn
# Top of stack:   ♠2
# Hand:       ['♥3', '♥8', '♦J']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♥3', '♥8', '♦J', 'take']
# jasper plays ♥8 from hand.
# jasper draws a card: ♣6
#
# busse's turn
# Top of stack:   ♥8
# Hand:       ['♥Q', '♦6', '♦A']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♥Q', '♦A', 'take']
# busse plays ♦A from hand.
# busse draws a card: ♥5
#
# tim's turn
# Top of stack:   ♦A
# Hand:       ['♠4', '♠K', '♠Q']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['take']
# tim takes the stack (5 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♦8', '♥4', '♦Q', '♣Q', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♦8', '♥4', '♦Q', '♣Q', '♣K']
# natasja plays ♦Q from hand.
# natasja can play a double card (Q).
# natasja plays ♣Q from hand.
#
# jasper's turn
# Top of stack:   ♣Q
# Hand:       ['♥3', '♦J', '♣6']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♥3', 'take']
# jasper plays ♥3 from hand.
# jasper played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♦J', '♣6']
#
# busse's turn
# Top of stack:   ♣6
# Hand:       ['♥Q', '♦6', '♥5']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♥Q', '♦6', 'take']
# busse plays ♥Q from hand.
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       ['♠4', '♠K', '♠Q', '♠J', '♥A', '♠2', '♥8', '♦A']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠K', '♠Q', '♥A', '♠2', '♦A', 'take']
# tim plays ♠K from hand.
#
# natasja's turn
# Top of stack:   ♠K
# Hand:       ['♦5', '♦8', '♥4', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♣K', 'take']
# natasja plays ♣K from hand.
#
# jasper's turn
# Top of stack:   ♣K
# Hand:       ['♦J']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♥5']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦6', '♥5']
# busse plays ♥5 from hand.
#
# tim's turn
# Top of stack:   ♥5
# Hand:       ['♠4', '♠Q', '♠J', '♥A', '♠2', '♥8', '♦A']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠Q', '♠J', '♥A', '♠2', '♥8', '♦A', 'take']
# tim plays ♦A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦A
# Hand:       ['♦5', '♦8', '♥4']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦J', '♣6', '♥Q', '♠K', '♣K']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♦J', '♣6', '♥Q', '♠K', '♣K']
# jasper plays ♦J from hand.
#
# busse's turn
# Top of stack:   ♦J
# Hand:       ['♦6']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♠Q', '♠J', '♥A', '♠2', '♥8']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♠Q', '♠J', '♥A', '♠2', '♥8']
# tim plays ♠J from hand.
#
# natasja's turn
# Top of stack:   ♠J
# Hand:       ['♦5', '♦8', '♥4', '♥5', '♦A']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦A', 'take']
# natasja plays ♦A from hand.
#
# jasper's turn
# Top of stack:   ♦A
# Hand:       ['♣6', '♥Q', '♠K', '♣K']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♦J']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦6', '♦J']
# busse plays ♦6 from hand.
#
# tim's turn
# Top of stack:   ♦6
# Hand:       ['♠4', '♠Q', '♥A', '♠2', '♥8']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠Q', '♥A', '♠2', '♥8', 'take']
# tim plays ♠Q from hand.
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♦5', '♦8', '♥4', '♥5']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣6', '♥Q', '♠K', '♣K', '♠J', '♦A']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♣6', '♥Q', '♠K', '♣K', '♠J', '♦A']
# jasper plays ♣6 from hand.
#
# busse's turn
# Top of stack:   ♣6
# Hand:       ['♦J']
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦J', 'take']
# busse plays ♦J from hand.
#
# tim's turn
# Top of stack:   ♦J
# Hand:       ['♠4', '♥A', '♠2', '♥8']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♥A', '♠2', 'take']
# tim plays ♥A from hand.
#
# natasja's turn
# Top of stack:   ♥A
# Hand:       ['♦5', '♦8', '♥4', '♥5', '♦6', '♠Q']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♠K', '♣K', '♠J', '♦A']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♥Q', '♠K', '♣K', '♠J', '♦A']
# jasper plays ♥Q from hand.
#
# busse's turn
# Top of stack:   ♥Q
# Hand:       []
# Displayed:  ['♦9', '♦4', '♦K']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦K', 'take']
# busse plays ♦K from displayed.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♠4', '♠2', '♥8']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠2', 'take']
# tim plays ♠2 from hand.
#
# natasja's turn
# Top of stack:   ♠2
# Hand:       ['♦5', '♦8', '♥4', '♥5', '♦6', '♠Q', '♣6', '♦J', '♥A']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♦8', '♥4', '♥5', '♦6', '♠Q', '♣6', '♦J', '♥A', 'take']
# natasja plays ♦8 from hand.
#
# jasper's turn
# Top of stack:   ♦8
# Hand:       ['♠K', '♣K', '♠J', '♦A']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠K', '♣K', '♠J', '♦A', 'take']
# jasper plays ♣K from hand.
# jasper can play a double card (K).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣K
# Hand:       []
# Displayed:  ['♦9', '♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['take']
# busse takes the stack (5 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♥8']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♥8']
# tim plays ♥8 from hand.
#
# natasja's turn
# Top of stack:   ♥8
# Hand:       ['♦5', '♥4', '♥5', '♦6', '♠Q', '♣6', '♦J', '♥A']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠Q', '♦J', '♥A', 'take']
# natasja plays ♠Q from hand.
#
# jasper's turn
# Top of stack:   ♠Q
# Hand:       ['♠K', '♠J', '♦A']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠K', '♦A', 'take']
# jasper plays ♦A from hand.
#
# busse's turn
# Top of stack:   ♦A
# Hand:       ['♥Q', '♦K', '♠2', '♦8', '♣K']
# Displayed:  ['♦9', '♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♠2', 'take']
# busse plays ♠2 from hand.
#
# tim's turn
# Top of stack:   ♠2
# Hand:       ['♠4']
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', 'take']
# tim plays ♠4 from hand.
#
# natasja's turn
# Top of stack:   ♠4
# Hand:       ['♦5', '♥4', '♥5', '♦6', '♣6', '♦J', '♥A']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♥4', '♥5', '♦6', '♣6', '♦J', '♥A', 'take']
# natasja plays ♦6 from hand.
# natasja can play a double card (6).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♠K', '♠J']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠K', '♠J', 'take']
# jasper plays ♠J from hand.
#
# busse's turn
# Top of stack:   ♠J
# Hand:       ['♥Q', '♦K', '♦8', '♣K']
# Displayed:  ['♦9', '♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♥Q', '♦K', '♣K', 'take']
# busse plays ♥Q from hand.
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       []
# Displayed:  ['♠A', '♥7', '♣A']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠A', '♣A', 'take']
# tim plays ♣A from displayed.
# tim can play a double card (A).
# tim plays ♠A from displayed.
#
# natasja's turn
# Top of stack:   ♠A
# Hand:       ['♦5', '♥4', '♥5', '♣6', '♦J', '♥A']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥A', 'take']
# natasja plays ♥A from hand.
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       ['♠K']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['take']
# jasper takes the stack (11 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦K', '♦8', '♣K']
# Displayed:  ['♦9', '♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦K', '♦8', '♣K']
# busse plays ♦K from hand.
# busse can play a double card (K).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       []
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['take']
# tim takes the stack (1 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥4', '♥5', '♣6', '♦J']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♥4', '♥5', '♣6', '♦J']
# natasja plays ♦J from hand.
#
# jasper's turn
# Top of stack:   ♦J
# Hand:       ['♠K', '♥8', '♠Q', '♦A', '♠2', '♠4', '♦6', '♠J', '♥Q', '♣A', '♠A', '♥A']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠K', '♠Q', '♦A', '♠2', '♠J', '♥Q', '♣A', '♠A', '♥A', 'take']
# jasper plays ♠2 from hand.
#
# busse's turn
# Top of stack:   ♠2
# Hand:       ['♦8', '♣K']
# Displayed:  ['♦9', '♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦8', '♣K', 'take']
# busse plays ♣K from hand.
#
# tim's turn
# Top of stack:   ♣K
# Hand:       ['♦K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♦K', 'take']
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♦5', '♥4', '♥5', '♣6']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠K', '♥8', '♠Q', '♦A', '♠4', '♦6', '♠J', '♥Q', '♣A', '♠A', '♥A']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠K', '♥8', '♠Q', '♦A', '♠4', '♦6', '♠J', '♥Q', '♣A', '♠A', '♥A']
# jasper plays ♠4 from hand.
#
# busse's turn
# Top of stack:   ♠4
# Hand:       ['♦8']
# Displayed:  ['♦9', '♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦8', 'take']
# busse plays ♦8 from hand.
#
# tim's turn
# Top of stack:   ♦8
# Hand:       []
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥4', '♥5', '♣6', '♦J', '♠2', '♣K', '♦K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♥4', '♥5', '♣6', '♦J', '♠2', '♣K', '♦K']
# natasja plays ♠2 from hand.
#
# jasper's turn
# Top of stack:   ♠2
# Hand:       ['♠K', '♥8', '♠Q', '♦A', '♦6', '♠J', '♥Q', '♣A', '♠A', '♥A']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠K', '♥8', '♠Q', '♦A', '♦6', '♠J', '♥Q', '♣A', '♠A', '♥A', 'take']
# jasper plays ♥A from hand.
# jasper can play a double card (A).
# jasper plays ♠A from hand.
# jasper can play a double card (A).
# jasper plays ♣A from hand.
# jasper can play a double card (A).
# jasper plays ♦A from hand.
# Four of a kind detected - Stack cleared!
#
# busse's turn
# Top of stack:   ♥8
# Hand:       []
# Displayed:  ['♦9', '♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦9', 'take']
# busse plays ♦9 from displayed.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♠4', '♦8']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥4', '♥5', '♣6', '♦J', '♣K', '♦K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♥4', '♥5', '♣6', '♦J', '♣K', '♦K']
# natasja plays ♦K from hand.
# natasja can play a double card (K).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       ['♠K', '♠Q', '♦6', '♠J', '♥Q']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠K', 'take']
# jasper plays ♠K from hand.
#
# busse's turn
# Top of stack:   ♠K
# Hand:       []
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦8', '♥8', '♦9']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♦8', '♥8', '♦9']
# tim plays ♥8 from hand.
# tim can play a double card (8).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥8
# Hand:       ['♦5', '♥4', '♥5', '♣6', '♦J', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦J', '♣K', 'take']
# natasja plays ♦J from hand.
#
# jasper's turn
# Top of stack:   ♦J
# Hand:       ['♠Q', '♦6', '♠J', '♥Q']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠Q', '♠J', '♥Q', 'take']
# jasper plays ♠J from hand.
#
# busse's turn
# Top of stack:   ♠J
# Hand:       ['♦K', '♠K']
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦K', '♠K', 'take']
# busse plays ♠K from hand.
# busse can play a double card (K).
# busse plays ♦K from hand.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♠4', '♦8', '♦9']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['take']
# tim takes the stack (5 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥4', '♥5', '♣6', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♥4', '♥5', '♣6', '♣K']
# natasja plays ♣6 from hand.
#
# jasper's turn
# Top of stack:   ♣6
# Hand:       ['♠Q', '♦6', '♥Q']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠Q', '♦6', '♥Q', 'take']
# jasper plays ♦6 from hand.
#
# busse's turn
# Top of stack:   ♦6
# Hand:       []
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦8', '♦9', '♥8', '♦J', '♠J', '♠K', '♦K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♦8', '♦9', '♥8', '♦J', '♠J', '♠K', '♦K']
# tim plays ♦J from hand.
# tim can play a double card (J).
# tim plays ♠J from hand.
#
# natasja's turn
# Top of stack:   ♠J
# Hand:       ['♦5', '♥4', '♥5', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♣K', 'take']
# natasja plays ♣K from hand.
#
# jasper's turn
# Top of stack:   ♣K
# Hand:       ['♠Q', '♥Q']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♣6', '♦6']
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♣6', '♦6']
# busse plays ♦6 from hand.
# busse can play a double card (6).
# busse plays ♣6 from hand.
#
# tim's turn
# Top of stack:   ♣6
# Hand:       ['♠4', '♦8', '♦9', '♥8', '♠K', '♦K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♦8', '♦9', '♥8', '♠K', '♦K', 'take']
# tim plays ♦K from hand.
# tim can play a double card (K).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♦5', '♥4', '♥5']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠Q', '♥Q', '♦J', '♠J', '♣K']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠Q', '♥Q', '♦J', '♠J', '♣K']
# jasper plays ♥Q from hand.
# jasper can play a double card (Q).
# jasper plays ♠Q from hand.
#
# busse's turn
# Top of stack:   ♠Q
# Hand:       []
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦8', '♦9', '♥8', '♠K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♦8', '♦9', '♥8', '♠K']
# tim plays ♦9 from hand.
#
# natasja's turn
# Top of stack:   ♦9
# Hand:       ['♦5', '♥4', '♥5', '♦6', '♣6', '♦K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦K', 'take']
# natasja plays ♦K from hand.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       ['♦J', '♠J', '♣K']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♣K', 'take']
# jasper plays ♣K from hand.
#
# busse's turn
# Top of stack:   ♣K
# Hand:       ['♥Q', '♠Q']
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦8', '♥8', '♠K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♦8', '♥8', '♠K']
# tim plays ♥8 from hand.
# tim can play a double card (8).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥8
# Hand:       ['♦5', '♥4', '♥5', '♦6', '♣6']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (1 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦J', '♠J']
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♦J', '♠J']
# jasper plays ♦J from hand.
# jasper can play a double card (J).
# jasper plays ♠J from hand.
#
# busse's turn
# Top of stack:   ♠J
# Hand:       ['♥Q', '♠Q', '♦9', '♦K', '♣K']
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♥Q', '♠Q', '♦K', '♣K', 'take']
# busse plays ♦K from hand.
# busse can play a double card (K).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♠4', '♦8', '♠K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠K', 'take']
# tim plays ♠K from hand.
#
# natasja's turn
# Top of stack:   ♠K
# Hand:       ['♦5', '♥4', '♥5', '♦6', '♣6', '♥8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♣4', '♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♣4', '♦2', '♣2']
# jasper plays ♣4 from displayed.
#
# busse's turn
# Top of stack:   ♣4
# Hand:       ['♥Q', '♠Q', '♦9', '♣K']
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♥Q', '♠Q', '♦9', '♣K', 'take']
# busse plays ♠Q from hand.
# busse can play a double card (Q).
# busse plays ♥Q from hand.
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       ['♠4', '♦8']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥4', '♥5', '♦6', '♣6', '♥8', '♦J', '♠J', '♦K', '♠K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♥4', '♥5', '♦6', '♣6', '♥8', '♦J', '♠J', '♦K', '♠K']
# natasja plays ♦J from hand.
# natasja can play a double card (J).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦J
# Hand:       []
# Displayed:  ['♦2', '♣2']
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♦2', '♣2', 'take']
# jasper plays ♣2 from displayed.
# jasper can play a double card (2).
# jasper plays ♦2 from displayed.
#
# busse's turn
# Top of stack:   ♦2
# Hand:       ['♦9', '♣K']
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦9', '♣K', 'take']
# busse plays ♣K from hand.
#
# tim's turn
# Top of stack:   ♣K
# Hand:       ['♠4', '♦8', '♣4', '♠Q', '♥Q']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['take']
# tim takes the stack (4 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥4', '♥5', '♦6', '♣6', '♥8', '♠J', '♦K', '♠K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♥4', '♥5', '♦6', '♣6', '♥8', '♠J', '♦K', '♠K']
# natasja plays ♦5 from hand.
# natasja can play a double card (5).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦5
# Hand:       []
# Displayed:  []
# Hidden:     ['♣10', '♠7', '♠5']
#
# Playable cards: ['♠5', 'take']
# jasper plays ♠5 from hidden.
#
# busse's turn
# Top of stack:   ♠5
# Hand:       ['♦9']
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦9', 'take']
# busse plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♠4', '♦8', '♣4', '♠Q', '♥Q', '♦J', '♣2', '♦2', '♣K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠Q', '♥Q', '♦J', '♣2', '♦2', '♣K', 'take']
# tim plays ♦J from hand.
#
# natasja's turn
# Top of stack:   ♦J
# Hand:       ['♥4', '♥5', '♦6', '♣6', '♥8', '♠J', '♦K', '♠K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠J', '♦K', '♠K', 'take']
# natasja plays ♠K from hand.
# natasja can play a double card (K).
# natasja plays ♦K from hand.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       []
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (6 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♦4']
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦4']
# busse plays ♦4 from displayed.
#
# tim's turn
# Top of stack:   ♦4
# Hand:       ['♠4', '♦8', '♣4', '♠Q', '♥Q', '♣2', '♦2', '♣K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♦8', '♣4', '♠Q', '♥Q', '♣2', '♦2', '♣K', 'take']
# tim plays ♠Q from hand.
# tim can play a double card (Q).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠Q
# Hand:       ['♥4', '♥5', '♦6', '♣6', '♥8', '♠J']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♠5', '♦9', '♦J', '♠K', '♦K']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦5', '♠5', '♦9', '♦J', '♠K', '♦K']
# jasper plays ♦5 from hand.
# jasper can play a double card (5).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦5
# Hand:       []
# Displayed:  []
# Hidden:     ['♠6', '♣8', '♦10']
#
# Playable cards: ['♦10', 'take']
# busse plays ♦10 from hidden.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♠4', '♦8', '♣4', '♥Q', '♣2', '♦2', '♣K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♦8', '♥Q', '♣2', '♦2', '♣K', 'take']
# tim plays ♣2 from hand.
# tim can play a double card (2).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♣2
# Hand:       ['♥4', '♥5', '♦6', '♣6', '♥8', '♠J', '♦4', '♠Q']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥4', '♥5', '♦6', '♣6', '♥8', '♠J', '♦4', '♠Q', 'take']
# natasja plays ♠Q from hand.
#
# jasper's turn
# Top of stack:   ♠Q
# Hand:       ['♠5', '♦9', '♦J', '♠K', '♦K']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♠K', '♦K', 'take']
# jasper plays ♠K from hand.
# jasper can play a double card (K).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♠K
# Hand:       []
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (5 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦8', '♣4', '♥Q', '♦2', '♣K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♠4', '♦8', '♣4', '♥Q', '♦2', '♣K']
# tim plays ♣4 from hand.
# tim can play a double card (4).
# tim plays ♠4 from hand.
#
# natasja's turn
# Top of stack:   ♠4
# Hand:       ['♥4', '♥5', '♦6', '♣6', '♥8', '♠J', '♦4']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥4', '♥5', '♦6', '♣6', '♥8', '♠J', '♦4', 'take']
# natasja plays ♣6 from hand.
# natasja can play a double card (6).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣6
# Hand:       ['♠5', '♦9', '♦J', '♦K']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♦J', '♦K', 'take']
# jasper plays ♦J from hand.
#
# busse's turn
# Top of stack:   ♦J
# Hand:       ['♦5', '♦10', '♣2', '♠Q', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦10', '♣2', '♠Q', '♠K', 'take']
# busse plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♦8', '♥Q', '♦2', '♣K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♥Q', '♦2', '♣K', 'take']
# tim plays ♥Q from hand.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♥4', '♥5', '♦6', '♥8', '♠J', '♦4']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (6 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦9', '♦K']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♠5', '♦9', '♦K']
# jasper plays ♦K from hand.
#
# busse's turn
# Top of stack:   ♦K
# Hand:       ['♦5', '♣2', '♠Q', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣2', '♠K', 'take']
# busse plays ♣2 from hand.
#
# tim's turn
# Top of stack:   ♣2
# Hand:       ['♦8', '♦2', '♣K']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♦8', '♦2', '♣K', 'take']
# tim plays ♣K from hand.
#
# natasja's turn
# Top of stack:   ♣K
# Hand:       ['♥4', '♥5', '♦6', '♥8', '♠J', '♦4', '♣4', '♠4', '♣6', '♦J', '♦10', '♥Q']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦10', 'take']
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       ['♠5', '♦9']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♠Q', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦5', '♠Q', '♠K']
# busse plays ♦5 from hand.
#
# tim's turn
# Top of stack:   ♦5
# Hand:       ['♦8', '♦2']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♦8', '♦2', 'take']
# tim plays ♦8 from hand.
#
# natasja's turn
# Top of stack:   ♦8
# Hand:       ['♥4', '♥5', '♦6', '♥8', '♠J', '♦4', '♣4', '♠4', '♣6', '♦J', '♥Q']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥8', '♠J', '♦J', '♥Q', 'take']
# natasja plays ♥8 from hand.
#
# jasper's turn
# Top of stack:   ♥8
# Hand:       ['♠5', '♦9', '♦K', '♣2', '♣K', '♦10']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♦K', '♣2', '♣K', '♦10', 'take']
# jasper plays ♣K from hand.
# jasper can play a double card (K).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣K
# Hand:       ['♠Q', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♠K', 'take']
# busse plays ♠K from hand.
#
# tim's turn
# Top of stack:   ♠K
# Hand:       ['♦2']
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♦2', 'take']
# tim plays ♦2 from hand.
#
# natasja's turn
# Top of stack:   ♦2
# Hand:       ['♥4', '♥5', '♦6', '♠J', '♦4', '♣4', '♠4', '♣6', '♦J', '♥Q']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥4', '♥5', '♦6', '♠J', '♦4', '♣4', '♠4', '♣6', '♦J', '♥Q', 'take']
# natasja plays ♥Q from hand.
#
# jasper's turn
# Top of stack:   ♥Q
# Hand:       ['♠5', '♦9', '♦K', '♣2', '♦10']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦K', '♣2', '♦10', 'take']
# jasper plays ♦K from hand.
#
# busse's turn
# Top of stack:   ♦K
# Hand:       ['♠Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (8 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥7']
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♥7']
# tim plays ♥7 from displayed.
#
# natasja's turn
# Top of stack:   ♥7
# Hand:       ['♥4', '♥5', '♦6', '♠J', '♦4', '♣4', '♠4', '♣6', '♦J']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥4', '♥5', '♦6', '♦4', '♣4', '♠4', '♣6', 'take']
# natasja plays ♥4 from hand.
# natasja can play a double card (4).
# natasja plays ♠4 from hand.
# natasja can play a double card (4).
# natasja plays ♦4 from hand.
# natasja can play a double card (4).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦4
# Hand:       ['♠5', '♦9', '♣2', '♦10']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♠5', '♦9', '♣2', '♦10', 'take']
# jasper plays ♠5 from hand.
#
# busse's turn
# Top of stack:   ♠5
# Hand:       ['♠Q', '♦5', '♦8', '♥8', '♣K', '♠K', '♦2', '♥Q', '♦K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♠Q', '♦5', '♦8', '♥8', '♣K', '♠K', '♦2', '♥Q', '♦K', 'take']
# busse plays ♠Q from hand.
# busse can play a double card (Q).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♠Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♣9', '♦7', '♦3']
#
# Playable cards: ['♦3', 'take']
# tim plays ♦3 from hidden.
# tim played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♦7']
#
# natasja's turn
# Top of stack:   ♦7
# Hand:       ['♥5', '♦6', '♠J', '♣4', '♣6', '♦J']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥5', '♦6', '♣4', '♣6', 'take']
# natasja plays ♦6 from hand.
# natasja can play a double card (6).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♦9', '♣2', '♦10']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♣2', '♦10', 'take']
# jasper plays ♣2 from hand.
#
# busse's turn
# Top of stack:   ♣2
# Hand:       ['♦5', '♦8', '♥8', '♣K', '♠K', '♦2', '♥Q', '♦K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦5', '♦8', '♥8', '♣K', '♠K', '♦2', '♥Q', '♦K', 'take']
# busse plays ♦K from hand.
# busse can play a double card (K).
# busse plays ♣K from hand.
# busse can play a double card (K).
# busse skipped playing a double card.
#
# tim's turn
# Top of stack:   ♣K
# Hand:       []
# Displayed:  []
# Hidden:     ['♣9']
#
# Playable cards: ['take']
# tim takes the stack (5 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♠J', '♣4', '♣6', '♦J']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥5', '♠J', '♣4', '♣6', '♦J']
# natasja plays ♣4 from hand.
#
# jasper's turn
# Top of stack:   ♣4
# Hand:       ['♦9', '♦10']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♦10', 'take']
# jasper plays ♦10 from hand.
#
# busse's turn
# Top of stack:   ♦10
# Hand:       ['♦5', '♦8', '♥8', '♠K', '♦2', '♥Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦5', '♦8', '♥8', '♠K', '♦2', '♥Q', 'take']
# busse plays ♥8 from hand.
# busse can play a double card (8).
# busse plays ♦8 from hand.
#
# tim's turn
# Top of stack:   ♦8
# Hand:       ['♦7', '♦6', '♣2', '♦K', '♣K']
# Displayed:  []
# Hidden:     ['♣9']
#
# Playable cards: ['♣2', '♦K', '♣K', 'take']
# tim plays ♣K from hand.
# tim can play a double card (K).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♣K
# Hand:       ['♥5', '♠J', '♣6', '♦J']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦9']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9']
# jasper plays ♦9 from hand.
#
# busse's turn
# Top of stack:   ♦9
# Hand:       ['♦5', '♠K', '♦2', '♥Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♠K', '♦2', '♥Q', 'take']
# busse plays ♠K from hand.
#
# tim's turn
# Top of stack:   ♠K
# Hand:       ['♦7', '♦6', '♣2', '♦K']
# Displayed:  []
# Hidden:     ['♣9']
#
# Playable cards: ['♣2', '♦K', 'take']
# tim plays ♣2 from hand.
#
# natasja's turn
# Top of stack:   ♣2
# Hand:       ['♥5', '♠J', '♣6', '♦J', '♣4', '♦10', '♥8', '♦8', '♣K']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥5', '♠J', '♣6', '♦J', '♣4', '♦10', '♥8', '♦8', '♣K', 'take']
# natasja plays ♣K from hand.
#
# jasper's turn
# Top of stack:   ♣K
# Hand:       []
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♦2', '♥Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦5', '♦2', '♥Q']
# busse plays ♥Q from hand.
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       ['♦7', '♦6', '♦K']
# Displayed:  []
# Hidden:     ['♣9']
#
# Playable cards: ['♦K', 'take']
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♥5', '♠J', '♣6', '♦J', '♣4', '♦10', '♥8', '♦8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦10', 'take']
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       ['♦9', '♠K', '♣2', '♣K']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♠K', '♣2', '♣K', 'take']
# jasper plays ♣K from hand.
# jasper can play a double card (K).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣K
# Hand:       ['♦5', '♦2']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦2', 'take']
# busse plays ♦2 from hand.
#
# tim's turn
# Top of stack:   ♦2
# Hand:       ['♦7', '♦6']
# Displayed:  []
# Hidden:     ['♣9']
#
# Playable cards: ['♦7', '♦6', 'take']
# tim plays ♦7 from hand.
#
# natasja's turn
# Top of stack:   ♦7
# Hand:       ['♥5', '♠J', '♣6', '♦J', '♣4', '♥8', '♦8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥5', '♣6', '♣4', 'take']
# natasja plays ♣4 from hand.
#
# jasper's turn
# Top of stack:   ♣4
# Hand:       ['♦9', '♠K', '♣2']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♠K', '♣2', 'take']
# jasper plays ♣2 from hand.
#
# busse's turn
# Top of stack:   ♣2
# Hand:       ['♦5']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦5', 'take']
# busse plays ♦5 from hand.
#
# tim's turn
# Top of stack:   ♦5
# Hand:       ['♦6']
# Displayed:  []
# Hidden:     ['♣9']
#
# Playable cards: ['♦6', 'take']
# tim plays ♦6 from hand.
#
# natasja's turn
# Top of stack:   ♦6
# Hand:       ['♥5', '♠J', '♣6', '♦J', '♥8', '♦8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠J', '♣6', '♦J', '♥8', '♦8', 'take']
# natasja plays ♣6 from hand.
#
# jasper's turn
# Top of stack:   ♣6
# Hand:       ['♦9', '♠K']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♠K', 'take']
# jasper plays ♠K from hand.
#
# busse's turn
# Top of stack:   ♠K
# Hand:       []
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (12 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♣9']
#
# Playable cards: ['♣9']
# tim plays ♣9 from hidden.
# tim has won the game!
#
# natasja's turn
# Top of stack:   ♣9
# Hand:       ['♥5', '♠J', '♦J', '♥8', '♦8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠J', '♦J', 'take']
# natasja plays ♦J from hand.
# natasja can play a double card (J).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦J
# Hand:       ['♦9']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦K', '♦10', '♣K', '♦2', '♦7', '♣4', '♣2', '♦5', '♦6', '♣6', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥Q', '♦K', '♦10', '♣K', '♦2', '♦7', '♣4', '♣2', '♦5', '♦6', '♣6', '♠K']
# busse plays ♣4 from hand.
#
# natasja's turn
# Top of stack:   ♣4
# Hand:       ['♥5', '♠J', '♥8', '♦8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥5', '♠J', '♥8', '♦8', 'take']
# natasja plays ♥5 from hand.
#
# jasper's turn
# Top of stack:   ♥5
# Hand:       ['♦9', '♣9', '♦J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♣9', '♦J', 'take']
# jasper plays ♦J from hand.
#
# busse's turn
# Top of stack:   ♦J
# Hand:       ['♥Q', '♦K', '♦10', '♣K', '♦2', '♦7', '♣2', '♦5', '♦6', '♣6', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥Q', '♦K', '♦10', '♣K', '♦2', '♣2', '♠K', 'take']
# busse plays ♦2 from hand.
# busse can play a double card (2).
# busse skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦2
# Hand:       ['♠J', '♥8', '♦8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠J', '♥8', '♦8', 'take']
# natasja plays ♥8 from hand.
# natasja can play a double card (8).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♥8
# Hand:       ['♦9', '♣9']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♣9', 'take']
# jasper plays ♣9 from hand.
# jasper can play a double card (9).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣9
# Hand:       ['♥Q', '♦K', '♦10', '♣K', '♦7', '♣2', '♦5', '♦6', '♣6', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥Q', '♦K', '♦10', '♣K', '♣2', '♠K', 'take']
# busse plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♠J', '♦8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠J', 'take']
# natasja plays ♠J from hand.
#
# jasper's turn
# Top of stack:   ♠J
# Hand:       ['♦9']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (8 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♦K', '♣K', '♦7', '♣2', '♦5', '♦6', '♣6', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥Q', '♦K', '♣K', '♦7', '♣2', '♦5', '♦6', '♣6', '♠K']
# busse plays ♣6 from hand.
# busse can play a double card (6).
# busse plays ♦6 from hand.
#
# natasja's turn
# Top of stack:   ♦6
# Hand:       ['♦8']
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦8', 'take']
# natasja plays ♦8 from hand.
#
# jasper's turn
# Top of stack:   ♦8
# Hand:       ['♦9', '♣4', '♥5', '♦J', '♦2', '♥8', '♣9', '♦10', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦9', '♦J', '♦2', '♥8', '♣9', '♦10', '♠J', 'take']
# jasper plays ♦9 from hand.
# jasper can play a double card (9).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦9
# Hand:       ['♥Q', '♦K', '♣K', '♦7', '♣2', '♦5', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥Q', '♦K', '♣K', '♣2', '♠K', 'take']
# busse plays ♥Q from hand.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       []
# Displayed:  ['♠9', '♣7', '♥K']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥K', 'take']
# natasja plays ♥K from displayed.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       ['♣4', '♥5', '♦J', '♦2', '♥8', '♣9', '♦10', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦2', '♦10', 'take']
# jasper plays ♦2 from hand.
#
# busse's turn
# Top of stack:   ♦2
# Hand:       ['♦K', '♣K', '♦7', '♣2', '♦5', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦K', '♣K', '♦7', '♣2', '♦5', '♠K', 'take']
# busse plays ♦7 from hand.
#
# natasja's turn
# Top of stack:   ♦7
# Hand:       []
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (8 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣4', '♥5', '♦J', '♥8', '♣9', '♦10', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♣4', '♥5', '♦J', '♥8', '♣9', '♦10', '♠J']
# jasper plays ♥5 from hand.
#
# busse's turn
# Top of stack:   ♥5
# Hand:       ['♦K', '♣K', '♣2', '♦5', '♠K']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦K', '♣K', '♣2', '♦5', '♠K', 'take']
# busse plays ♣K from hand.
# busse can play a double card (K).
# busse plays ♠K from hand.
# busse can play a double card (K).
# busse skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♠K
# Hand:       ['♣6', '♦6', '♦8', '♦9', '♥Q', '♥K', '♦2', '♦7']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♥K', '♦2', 'take']
# natasja plays ♥K from hand.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       ['♣4', '♦J', '♥8', '♣9', '♦10', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦10', 'take']
# jasper plays ♦10 from hand.
#
# busse's turn
# Top of stack:   ♦10
# Hand:       ['♦K', '♣2', '♦5']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦K', '♣2', 'take']
# busse plays ♣2 from hand.
#
# natasja's turn
# Top of stack:   ♣2
# Hand:       ['♣6', '♦6', '♦8', '♦9', '♥Q', '♦2', '♦7']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♣6', '♦6', '♦8', '♦9', '♥Q', '♦2', '♦7', 'take']
# natasja plays ♣6 from hand.
# natasja can play a double card (6).
# natasja plays ♦6 from hand.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♣4', '♦J', '♥8', '♣9', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦J', '♥8', '♣9', '♠J', 'take']
# jasper plays ♣9 from hand.
#
# busse's turn
# Top of stack:   ♣9
# Hand:       ['♦K', '♦5']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦K', 'take']
# busse plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♦8', '♦9', '♥Q', '♦2', '♦7']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦2', 'take']
# natasja plays ♦2 from hand.
#
# jasper's turn
# Top of stack:   ♦2
# Hand:       ['♣4', '♦J', '♥8', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♣4', '♦J', '♥8', '♠J', 'take']
# jasper plays ♥8 from hand.
#
# busse's turn
# Top of stack:   ♥8
# Hand:       ['♦5']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (12 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♦9', '♥Q', '♦7']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦8', '♦9', '♥Q', '♦7']
# natasja plays ♥Q from hand.
#
# jasper's turn
# Top of stack:   ♥Q
# Hand:       ['♣4', '♦J', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦5', '♥5', '♣K', '♠K', '♥K', '♦10', '♣2', '♣6', '♦6', '♣9', '♦K', '♦2', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦5', '♥5', '♣K', '♠K', '♥K', '♦10', '♣2', '♣6', '♦6', '♣9', '♦K', '♦2', '♥8']
# busse plays ♦K from hand.
# busse can play a double card (K).
# busse plays ♣K from hand.
# busse can play a double card (K).
# busse plays ♥K from hand.
# busse can play a double card (K).
# busse plays ♠K from hand.
# Four of a kind detected - Stack cleared!
# busse can play a double card (5).
# busse skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦5
# Hand:       ['♦8', '♦9', '♦7']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦8', '♦9', '♦7', 'take']
# natasja plays ♦7 from hand.
#
# jasper's turn
# Top of stack:   ♦7
# Hand:       ['♣4', '♦J', '♠J', '♥Q']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♣4', 'take']
# jasper plays ♣4 from hand.
#
# busse's turn
# Top of stack:   ♣4
# Hand:       ['♥5', '♦10', '♣2', '♣6', '♦6', '♣9', '♦2', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥5', '♦10', '♣2', '♣6', '♦6', '♣9', '♦2', '♥8', 'take']
# busse plays ♦2 from hand.
# busse can play a double card (2).
# busse plays ♣2 from hand.
#
# natasja's turn
# Top of stack:   ♣2
# Hand:       ['♦8', '♦9']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦8', '♦9', 'take']
# natasja plays ♦9 from hand.
#
# jasper's turn
# Top of stack:   ♦9
# Hand:       ['♦J', '♠J', '♥Q']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦J', '♠J', '♥Q', 'take']
# jasper plays ♠J from hand.
# jasper can play a double card (J).
# jasper plays ♦J from hand.
#
# busse's turn
# Top of stack:   ♦J
# Hand:       ['♥5', '♦10', '♣6', '♦6', '♣9', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦10', 'take']
# busse plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♦8']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (9 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♥Q']
# jasper plays ♥Q from hand.
#
# busse's turn
# Top of stack:   ♥Q
# Hand:       ['♥5', '♣6', '♦6', '♣9', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♦5', '♦7', '♣4', '♦2', '♣2', '♦9', '♠J', '♦J', '♦10']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦8', '♦5', '♦7', '♣4', '♦2', '♣2', '♦9', '♠J', '♦J', '♦10']
# natasja plays ♦8 from hand.
#
# jasper's turn
# Top of stack:   ♦8
# Hand:       []
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♣6', '♦6', '♣9', '♥8', '♥Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥5', '♣6', '♦6', '♣9', '♥8', '♥Q']
# busse plays ♥8 from hand.
#
# natasja's turn
# Top of stack:   ♥8
# Hand:       ['♦5', '♦7', '♣4', '♦2', '♣2', '♦9', '♠J', '♦J', '♦10']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦2', '♣2', '♦9', '♠J', '♦J', '♦10', 'take']
# natasja plays ♦J from hand.
# natasja can play a double card (J).
# natasja plays ♠J from hand.
#
# jasper's turn
# Top of stack:   ♠J
# Hand:       ['♦8']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥5', '♣6', '♦6', '♣9', '♥Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥5', '♣6', '♦6', '♣9', '♥Q']
# busse plays ♥5 from hand.
#
# natasja's turn
# Top of stack:   ♥5
# Hand:       ['♦5', '♦7', '♣4', '♦2', '♣2', '♦9', '♦10']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦5', '♦7', '♦2', '♣2', '♦9', '♦10', 'take']
# natasja plays ♦5 from hand.
#
# jasper's turn
# Top of stack:   ♦5
# Hand:       ['♦8', '♥8', '♦J', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦8', '♥8', '♦J', '♠J', 'take']
# jasper plays ♦8 from hand.
# jasper can play a double card (8).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦8
# Hand:       ['♣6', '♦6', '♣9', '♥Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣9', '♥Q', 'take']
# busse plays ♣9 from hand.
#
# natasja's turn
# Top of stack:   ♣9
# Hand:       ['♦7', '♣4', '♦2', '♣2', '♦9', '♦10']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦2', '♣2', '♦9', '♦10', 'take']
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       ['♥8', '♦J', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦J', '♠J', 'take']
# jasper plays ♦J from hand.
# jasper can play a double card (J).
# jasper skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦J
# Hand:       ['♣6', '♦6', '♥Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♥Q', 'take']
# busse plays ♥Q from hand.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♦7', '♣4', '♦2', '♣2', '♦9']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦2', '♣2', 'take']
# natasja plays ♣2 from hand.
# natasja can play a double card (2).
# natasja skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♣2
# Hand:       ['♥8', '♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♥8', '♠J', 'take']
# jasper plays ♥8 from hand.
#
# busse's turn
# Top of stack:   ♥8
# Hand:       ['♣6', '♦6']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (9 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦7', '♣4', '♦2', '♦9']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦7', '♣4', '♦2', '♦9']
# natasja plays ♦7 from hand.
#
# jasper's turn
# Top of stack:   ♦7
# Hand:       ['♠J']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♣6', '♦6', '♥5', '♦5', '♦8', '♣9', '♦10', '♦J', '♥Q', '♣2', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣6', '♦6', '♥5', '♦5', '♦8', '♣9', '♦10', '♦J', '♥Q', '♣2', '♥8']
# busse plays ♦6 from hand.
# busse can play a double card (6).
# busse skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦6
# Hand:       ['♣4', '♦2', '♦9']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦2', '♦9', 'take']
# natasja plays ♦9 from hand.
#
# jasper's turn
# Top of stack:   ♦9
# Hand:       ['♠J', '♦7']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♠J', 'take']
# jasper plays ♠J from hand.
#
# busse's turn
# Top of stack:   ♠J
# Hand:       ['♣6', '♥5', '♦5', '♦8', '♣9', '♦10', '♦J', '♥Q', '♣2', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦10', '♦J', '♥Q', '♣2', 'take']
# busse plays ♣2 from hand.
#
# natasja's turn
# Top of stack:   ♣2
# Hand:       ['♣4', '♦2']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♣4', '♦2', 'take']
# natasja plays ♣4 from hand.
#
# jasper's turn
# Top of stack:   ♣4
# Hand:       ['♦7']
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♦7', 'take']
# jasper plays ♦7 from hand.
#
# busse's turn
# Top of stack:   ♦7
# Hand:       ['♣6', '♥5', '♦5', '♦8', '♣9', '♦10', '♦J', '♥Q', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣6', '♥5', '♦5', '♦10', 'take']
# busse plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♦2']
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦2', 'take']
# natasja plays ♦2 from hand.
#
# jasper's turn
# Top of stack:   ♦2
# Hand:       []
# Displayed:  []
# Hidden:     ['♣10', '♠7']
#
# Playable cards: ['♠7', 'take']
# jasper plays ♠7 from hidden.
#
# busse's turn
# Top of stack:   ♠7
# Hand:       ['♣6', '♥5', '♦5', '♦8', '♣9', '♦J', '♥Q', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣6', '♥5', '♦5', 'take']
# busse plays ♦5 from hand.
# busse can play a double card (5).
# busse skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♦5
# Hand:       []
# Displayed:  ['♠9', '♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♠9', '♣7', 'take']
# natasja plays ♠9 from displayed.
#
# jasper's turn
# Top of stack:   ♠9
# Hand:       []
# Displayed:  []
# Hidden:     ['♣10']
#
# Playable cards: ['♣10', 'take']
# jasper plays ♣10 from hidden.
# jasper has won the game!
#
# busse's turn
# Top of stack:   ♣10
# Hand:       ['♣6', '♥5', '♦8', '♣9', '♦J', '♥Q', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣9', '♦J', '♥Q', 'take']
# busse plays ♣9 from hand.
#
# natasja's turn
# Top of stack:   ♣9
# Hand:       []
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (13 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♣6', '♥5', '♦8', '♦J', '♥Q', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣6', '♥5', '♦8', '♦J', '♥Q', '♥8']
# busse plays ♥Q from hand.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♦6', '♦9', '♠J', '♣2', '♣4', '♦7', '♦10', '♦2', '♠7', '♦5', '♠9', '♣10', '♣9']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♣2', '♦10', '♦2', '♣10', 'take']
# natasja plays ♦10 from hand.
# natasja can play a double card (10).
# natasja plays ♣10 from hand.
#
# busse's turn
# Top of stack:   ♣10
# Hand:       ['♣6', '♥5', '♦8', '♦J', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♦9', '♠J', '♣2', '♣4', '♦7', '♦2', '♠7', '♦5', '♠9', '♣9']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦6', '♦9', '♠J', '♣2', '♣4', '♦7', '♦2', '♠7', '♦5', '♠9', '♣9']
# natasja plays ♣9 from hand.
# natasja can play a double card (9).
# natasja plays ♠9 from hand.
# natasja can play a double card (9).
# natasja skipped playing a double card.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       ['♣6', '♥5', '♦8', '♦J', '♥8', '♥Q', '♦10', '♣10']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦J', '♥Q', '♦10', '♣10', 'take']
# busse plays ♦10 from hand.
# busse can play a double card (10).
# busse plays ♣10 from hand.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♦6', '♦9', '♠J', '♣2', '♣4', '♦7', '♦2', '♠7', '♦5']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦9', '♠J', '♣2', '♦2', 'take']
# natasja plays ♦9 from hand.
#
# busse's turn
# Top of stack:   ♦9
# Hand:       ['♣6', '♥5', '♦8', '♦J', '♥8', '♥Q']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦J', '♥Q', 'take']
# busse plays ♥Q from hand.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♦6', '♠J', '♣2', '♣4', '♦7', '♦2', '♠7', '♦5']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♣2', '♦2', 'take']
# natasja plays ♣2 from hand.
# natasja can play a double card (2).
# natasja skipped playing a double card.
#
# busse's turn
# Top of stack:   ♣2
# Hand:       ['♣6', '♥5', '♦8', '♦J', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣6', '♥5', '♦8', '♦J', '♥8', 'take']
# busse plays ♥5 from hand.
#
# natasja's turn
# Top of stack:   ♥5
# Hand:       ['♦6', '♠J', '♣4', '♦7', '♦2', '♠7', '♦5']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦6', '♠J', '♦7', '♦2', '♠7', '♦5', 'take']
# natasja plays ♦7 from hand.
# natasja can play a double card (7).
# natasja skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦7
# Hand:       ['♣6', '♦8', '♦J', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣6', 'take']
# busse plays ♣6 from hand.
#
# natasja's turn
# Top of stack:   ♣6
# Hand:       ['♦6', '♠J', '♣4', '♦2', '♠7', '♦5']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦6', '♠J', '♦2', '♠7', 'take']
# natasja plays ♠J from hand.
#
# busse's turn
# Top of stack:   ♠J
# Hand:       ['♦8', '♦J', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦J', 'take']
# busse plays ♦J from hand.
#
# natasja's turn
# Top of stack:   ♦J
# Hand:       ['♦6', '♣4', '♦2', '♠7', '♦5']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦2', 'take']
# natasja plays ♦2 from hand.
#
# busse's turn
# Top of stack:   ♦2
# Hand:       ['♦8', '♥8']
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♦8', '♥8', 'take']
# busse plays ♥8 from hand.
# busse can play a double card (8).
# busse plays ♦8 from hand.
#
# natasja's turn
# Top of stack:   ♦8
# Hand:       ['♦6', '♣4', '♠7', '♦5']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['take']
# natasja takes the stack (15 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♠6', '♣8']
#
# Playable cards: ['♣8']
# busse plays ♣8 from hidden.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♦6', '♣4', '♠7', '♦5', '♣9', '♠9', '♦10', '♣10', '♦9', '♥Q', '♣2', '♥5', '♦7', '♣6', '♠J', '♦J', '♦2', '♥8', '♦8']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♣9', '♠9', '♦10', '♣10', '♦9', '♥Q', '♣2', '♠J', '♦J', '♦2', '♥8', '♦8', 'take']
# natasja plays ♥Q from hand.
#
# busse's turn
# Top of stack:   ♥Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♠6']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♣4', '♠7', '♦5', '♣9', '♠9', '♦10', '♣10', '♦9', '♣2', '♥5', '♦7', '♣6', '♠J', '♦J', '♦2', '♥8', '♦8']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦6', '♣4', '♠7', '♦5', '♣9', '♠9', '♦10', '♣10', '♦9', '♣2', '♥5', '♦7', '♣6', '♠J', '♦J', '♦2', '♥8', '♦8']
# natasja plays ♦5 from hand.
# natasja can play a double card (5).
# natasja skipped playing a double card.
#
# busse's turn
# Top of stack:   ♦5
# Hand:       ['♣8', '♥Q']
# Displayed:  []
# Hidden:     ['♠6']
#
# Playable cards: ['♣8', '♥Q', 'take']
# busse plays ♣8 from hand.
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♦6', '♣4', '♠7', '♣9', '♠9', '♦10', '♣10', '♦9', '♣2', '♥5', '♦7', '♣6', '♠J', '♦J', '♦2', '♥8', '♦8']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♣9', '♠9', '♦10', '♣10', '♦9', '♣2', '♠J', '♦J', '♦2', '♥8', '♦8', 'take']
# natasja plays ♦9 from hand.
# natasja can play a double card (9).
# natasja plays ♠9 from hand.
# natasja can play a double card (9).
# natasja skipped playing a double card.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       ['♥Q']
# Displayed:  []
# Hidden:     ['♠6']
#
# Playable cards: ['♥Q', 'take']
# busse plays ♥Q from hand.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       ['♦6', '♣4', '♠7', '♣9', '♦10', '♣10', '♣2', '♥5', '♦7', '♣6', '♠J', '♦J', '♦2', '♥8', '♦8']
# Displayed:  ['♣7']
# Hidden:     ['♥6', '♥J', '♣3']
#
# Playable cards: ['♦10', '♣10', '♣2', '♦2', 'take']
# natasja plays ♣2 from hand.
# natasja can play a double card (2).
# natasja plays ♦2 from hand.
#
# busse's turn
# Top of stack:   ♦2
# Hand:       []
# Displayed:  []
# Hidden:     ['♠6']
#
# Playable cards: ['♠6', 'take']
# busse plays ♠6 from hidden.
# busse has won the game!
#
# natasja is the last remaining player. No further turns needed.
#
# Game over! Winners in order: ['tim', 'jasper', 'busse']

# %%
game.simulate_games(10)

# %%
game.deck
# Out:
# []

# %%
game.medals
# Out:
#          1st  2nd  3rd
# busse      1    4  3.0
# jasper     1    3  4.0
# natasja    4    2  0.0
# tim        4    1  3.0

# %%
game.points
# Out:
# tim        17
# natasja    16
# busse      14
# jasper     13
# dtype: int64

# %%
game.placements
# Out:
# {'Game 1': ['tim', 'jasper', 'busse'],
#  'Game 2': ['natasja', 'busse', 'jasper'],
#  'Game 3': ['natasja', 'busse', 'jasper'],
#  'Game 4': ['natasja', 'busse', 'tim'],
#  'Game 5': ['tim', 'jasper', 'busse'],
#  'Game 6': ['jasper', 'natasja', 'tim'],
#  'Game 7': ['tim', 'natasja', 'busse'],
#  'Game 8': ['natasja', 'tim', 'jasper'],
#  'Game 9': ['busse', 'jasper', 'tim'],
#  'Game 10': ['tim', 'busse', 'jasper']}

# %%
game.players
# Out:
# [<Zweeds_Pesten.Player at 0x12cb97aab40>,
#  <Zweeds_Pesten.Player at 0x12cffa46420>,
#  <Zweeds_Pesten.Player at 0x12cffa46750>,
#  <Zweeds_Pesten.Player at 0x12cffa47320>]

# %%
game.winners
# Out:
# ['tim', 'busse', 'jasper']
