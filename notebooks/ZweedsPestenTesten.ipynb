# %% [markdown]
# # **Zweeds Pesten**

# %% [markdown]
# Importeer de benodigde libraries en importeer de class ZweedsPesten

# %%
import sys
import os

# Ophalen path van de src folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Voeg de folder to aan path
if src_path not in sys.path:
    sys.path.append(src_path)

# Importeren van src is nu mogelijk
from utils import ZweedsPesten

# %% [markdown]
# Maakt variabele player_names aan, definieert en initialiseert een ZweedsPesten object genaamd game met de namen van de spelers.
# Bepaalt een winnaar door de game_loop method door te lopen van het ZweedsPesten-object.

# %%
# Lijst met spelers
player_names = ["jasper", "busse", "tim", "natasja", "low", "justice_and_terror", "low_noon", "random_go"]

# Opstarten spel met speler lijst
game = ZweedsPesten(player_names)

# Simuleren van een enkele game
winners = game.game_loop(verbose=2)
# Out:
# ------------ Starting Game ------------
# jasper:
# Hand:       ['♣7', '♣5', '♥6']
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
# -----------------------------------------
# busse:
# Hand:       ['♥9', '♦6', '♠9']
# Displayed:  ['♠Q', '♠J', '♥J']
# Hidden:     ['♠K', '♠A', '♣8']
# -----------------------------------------
# tim:
# Hand:       ['♥4', '♠8', '♦5']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
# -----------------------------------------
# natasja:
# Hand:       ['♣J', '♠4', '♦4']
# Displayed:  ['♥10', '♠2', '♥A']
# Hidden:     ['♠3', '♦K', '♥7']
# -----------------------------------------
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣7', '♣5', '♥6']
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♣7', '♣5', '♥6']
# jasper plays ♣5 from hand.
# jasper draws a card: ♥Q
#
# busse's turn
# Top of stack:   ♣5
# Hand:       ['♥9', '♦6', '♠9']
# Displayed:  ['♠Q', '♠J', '♥J']
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♥9', '♦6', '♠9', 'take']
# busse plays ♦6 from hand.
# busse draws a card: ♥K
#
# tim's turn
# Top of stack:   ♦6
# Hand:       ['♥4', '♠8', '♦5']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠8', 'take']
# tim plays ♠8 from hand.
# tim draws a card: ♣Q
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       ['♣J', '♠4', '♦4']
# Displayed:  ['♥10', '♠2', '♥A']
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♣J', 'take']
# natasja plays ♣J from hand.
# natasja draws a card: ♣4
#
# jasper's turn
# Top of stack:   ♣J
# Hand:       ['♣7', '♥6', '♥Q']
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♥Q', 'take']
# jasper plays ♥Q from hand.
# jasper draws a card: ♦10
#
# busse's turn
# Top of stack:   ♥Q
# Hand:       ['♥9', '♠9', '♥K']
# Displayed:  ['♠Q', '♠J', '♥J']
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♥K', 'take']
# busse plays ♥K from hand.
# busse draws a card: ♠6
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♥4', '♦5', '♣Q']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠4', '♦4', '♣4']
# Displayed:  ['♥10', '♠2', '♥A']
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♠4', '♦4', '♣4']
# natasja plays ♠4 from hand.
# natasja can play a double card (4).
# natasja plays ♦4 from hand.
# natasja can play a double card (4).
# natasja plays ♣4 from hand.
# natasja draws a card: ♠5
# natasja draws a card: ♣3
# natasja draws a card: ♠10
#
# jasper's turn
# Top of stack:   ♣4
# Hand:       ['♣7', '♥6', '♦10']
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♣7', '♥6', '♦10', 'take']
# jasper plays ♥6 from hand.
# jasper draws a card: ♣6
#
# busse's turn
# Top of stack:   ♥6
# Hand:       ['♥9', '♠9', '♠6']
# Displayed:  ['♠Q', '♠J', '♥J']
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♥9', '♠9', '♠6', 'take']
# busse plays ♠6 from hand.
# busse draws a card: ♥5
#
# tim's turn
# Top of stack:   ♠6
# Hand:       ['♥4', '♦5', '♣Q', '♣5', '♦6', '♠8', '♣J', '♥Q', '♥K']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♣Q', '♦6', '♠8', '♣J', '♥Q', '♥K', 'take']
# tim plays ♦6 from hand.
#
# natasja's turn
# Top of stack:   ♦6
# Hand:       ['♠5', '♣3', '♠10']
# Displayed:  ['♥10', '♠2', '♥A']
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♣3', '♠10', 'take']
# natasja plays ♠10 from hand.
# natasja draws a card: ♣10
#
# jasper's turn
# Top of stack:   ♠10
# Hand:       ['♣7', '♦10', '♣6']
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♣7', '♦10', '♣6', 'take']
# jasper plays ♣6 from hand.
# Four of a kind detected - Stack cleared!
# jasper draws a card: ♣9
# jasper draws a card: ♦7
# jasper can play a double card (7).
# jasper plays ♦7 from hand.
# jasper draws a card: ♦2
#
# busse's turn
# Top of stack:   ♦7
# Hand:       ['♥9', '♠9', '♥5']
# Displayed:  ['♠Q', '♠J', '♥J']
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♥5', 'take']
# busse plays ♥5 from hand.
# busse draws a card: ♦A
#
# tim's turn
# Top of stack:   ♥5
# Hand:       ['♥4', '♦5', '♣Q', '♣5', '♠8', '♣J', '♥Q', '♥K']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦5', '♣Q', '♣5', '♠8', '♣J', '♥Q', '♥K', 'take']
# tim plays ♦5 from hand.
# tim can play a double card (5).
# tim plays ♣5 from hand.
#
# natasja's turn
# Top of stack:   ♣5
# Hand:       ['♠5', '♣3', '♣10']
# Displayed:  ['♥10', '♠2', '♥A']
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♠5', '♣3', '♣10', 'take']
# natasja plays ♣10 from hand.
#
# jasper's turn
# Top of stack:   ♣10
# Hand:       ['♦10', '♣9', '♦2']
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♦10', '♣9', '♦2', 'take']
# jasper plays ♣9 from hand.
#
# busse's turn
# Top of stack:   ♣9
# Hand:       ['♥9', '♠9', '♦A']
# Displayed:  ['♠Q', '♠J', '♥J']
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♥9', '♠9', '♦A', 'take']
# busse plays ♥9 from hand.
# busse can play a double card (9).
# busse plays ♠9 from hand.
#
# tim's turn
# Top of stack:   ♠9
# Hand:       ['♥4', '♣Q', '♠8', '♣J', '♥Q', '♥K']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♣Q', '♣J', '♥Q', '♥K', 'take']
# tim plays ♣J from hand.
#
# natasja's turn
# Top of stack:   ♣J
# Hand:       ['♠5', '♣3']
# Displayed:  ['♥10', '♠2', '♥A']
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♣3', 'take']
# natasja plays ♣3 from hand.
# natasja played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♠5']
#
# jasper's turn
# Top of stack:   ♠5
# Hand:       ['♦10', '♦2']
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♦10', '♦2', 'take']
# jasper plays ♦2 from hand.
#
# busse's turn
# Top of stack:   ♦2
# Hand:       ['♦A']
# Displayed:  ['♠Q', '♠J', '♥J']
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♦A', 'take']
# busse plays ♦A from hand.
#
# tim's turn
# Top of stack:   ♦A
# Hand:       ['♥4', '♣Q', '♠8', '♥Q', '♥K']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥10', '♠2', '♥A']
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♥10', '♠2', '♥A']
# natasja plays ♠2 from displayed.
#
# jasper's turn
# Top of stack:   ♠2
# Hand:       ['♦10']
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♦10', 'take']
# jasper plays ♦10 from hand.
#
# busse's turn
# Top of stack:   ♦10
# Hand:       []
# Displayed:  ['♠Q', '♠J', '♥J']
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♠Q', '♠J', '♥J', 'take']
# busse plays ♠J from displayed.
# busse can play a double card (J).
# busse plays ♥J from displayed.
#
# tim's turn
# Top of stack:   ♥J
# Hand:       ['♥4', '♣Q', '♠8', '♥Q', '♥K', '♠5', '♦2', '♦A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♣Q', '♥Q', '♥K', '♦2', '♦A', 'take']
# tim takes the stack (4 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥10', '♥A']
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♥10', '♥A']
# natasja plays ♥10 from displayed.
#
# jasper's turn
# Top of stack:   ♥10
# Hand:       []
# Displayed:  ['♥3', '♦Q', '♦J']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♥3', '♦Q', '♦J', 'take']
# jasper plays ♦J from displayed.
#
# busse's turn
# Top of stack:   ♦J
# Hand:       []
# Displayed:  ['♠Q']
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♠Q', 'take']
# busse plays ♠Q from displayed.
#
# tim's turn
# Top of stack:   ♠Q
# Hand:       ['♥4', '♣Q', '♠8', '♥Q', '♥K', '♠5', '♦2', '♦A', '♠2', '♦10', '♠J', '♥J']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♣Q', '♥Q', '♥K', '♦2', '♦A', '♠2', '♦10', 'take']
# tim plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       []
# Displayed:  ['♥A']
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♥A', 'take']
# natasja plays ♥A from displayed.
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  ['♥3', '♦Q']
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♥3', 'take']
# jasper plays ♥3 from displayed.
# jasper played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♦Q']
#
# busse's turn
# Top of stack:   ♦Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥4', '♣Q', '♠8', '♥Q', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♥4', '♣Q', '♠8', '♥Q', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♠3', '♦K', '♥7']
#
# Playable cards: ['♥7']
# natasja plays ♥7 from hidden.
#
# jasper's turn
# Top of stack:   ♥7
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦Q']
# Displayed:  []
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♦Q']
# busse plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♥4', '♣Q', '♠8', '♥Q', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♣Q', '♥Q', '♥K', '♦2', '♦A', '♠2', 'take']
# tim plays ♣Q from hand.
# tim can play a double card (Q).
# tim plays ♥Q from hand.
#
# natasja's turn
# Top of stack:   ♥Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♠3', '♦K']
#
# Playable cards: ['♦K', 'take']
# natasja plays ♦K from hidden.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       ['♥7']
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♠K', '♠A', '♣8']
#
# Playable cards: ['♣8']
# busse plays ♣8 from hidden.
#
# tim's turn
# Top of stack:   ♣8
# Hand:       ['♥4', '♠8', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠8', '♥K', '♦2', '♦A', '♠2', '♠J', '♥J', 'take']
# tim plays ♠8 from hand.
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       []
# Displayed:  []
# Hidden:     ['♠3']
#
# Playable cards: ['♠3', 'take']
# natasja plays ♠3 from hidden.
# natasja has won the game!
#
# jasper's turn
# Top of stack:   ♠3
# Hand:       ['♥7', '♦Q', '♣Q', '♥Q', '♦K']
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♠K', '♠A']
#
# Playable cards: ['♠A']
# busse plays ♠A from hidden.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♦A', '♠2', 'take']
# tim takes the stack (1 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♦Q', '♣Q', '♥Q', '♦K', '♣8', '♠8', '♠3']
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♥7', '♦Q', '♣Q', '♥Q', '♦K', '♣8', '♠8', '♠3']
# jasper plays ♥7 from hand.
#
# busse's turn
# Top of stack:   ♥7
# Hand:       []
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦Q', '♣Q', '♥Q', '♦K', '♣8', '♠8', '♠3']
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♦Q', '♣Q', '♥Q', '♦K', '♣8', '♠8', '♠3']
# jasper plays ♣8 from hand.
# jasper can play a double card (8).
# jasper plays ♠8 from hand.
#
# busse's turn
# Top of stack:   ♠8
# Hand:       ['♥7']
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['take']
# busse takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦Q', '♣Q', '♥Q', '♦K', '♠3']
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♦Q', '♣Q', '♥Q', '♦K', '♠3']
# jasper plays ♦Q from hand.
# jasper can play a double card (Q).
# jasper plays ♣Q from hand.
# jasper can play a double card (Q).
# jasper plays ♥Q from hand.
#
# busse's turn
# Top of stack:   ♥Q
# Hand:       ['♥7', '♣8', '♠8']
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['take']
# busse takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦K', '♠3']
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♦K', '♠3']
# jasper plays ♦K from hand.
#
# busse's turn
# Top of stack:   ♦K
# Hand:       ['♥7', '♣8', '♠8', '♦Q', '♣Q', '♥Q']
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠3']
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♠3']
# jasper takes the stack (0 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♥7', '♣8', '♠8', '♦Q', '♣Q', '♥Q', '♦K']
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['♥7', '♣8', '♠8', '♦Q', '♣Q', '♥Q', '♦K']
# busse plays ♥7 from hand.
#
# tim's turn
# Top of stack:   ♥7
# Hand:       ['♥4', '♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♥4', '♠5', '♦2', '♠2', 'take']
# tim plays ♥4 from hand.
#
# jasper's turn
# Top of stack:   ♥4
# Hand:       ['♠3']
# Displayed:  []
# Hidden:     ['♦8', '♣K', '♥8']
#
# Playable cards: ['♠3', 'take']
# jasper plays ♠3 from hand.
# jasper played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♥8']
#
# busse's turn
# Top of stack:   ♥8
# Hand:       ['♣8', '♠8', '♦Q', '♣Q', '♥Q', '♦K']
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['♣8', '♠8', '♦Q', '♣Q', '♥Q', '♦K', 'take']
# busse plays ♣8 from hand.
# busse can play a double card (8).
# busse plays ♠8 from hand.
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♥K', '♠5', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♥K', '♦2', '♦A', '♠2', '♠J', '♥J', '♠A', 'take']
# tim plays ♠J from hand.
# tim can play a double card (J).
# tim plays ♥J from hand.
#
# jasper's turn
# Top of stack:   ♥J
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8', '♣K']
#
# Playable cards: ['♣K', 'take']
# jasper plays ♣K from hidden.
#
# busse's turn
# Top of stack:   ♣K
# Hand:       ['♦Q', '♣Q', '♥Q', '♦K']
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['♦K', 'take']
# busse plays ♦K from hand.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♥K', '♠5', '♦2', '♦A', '♠2', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♥K', '♦2', '♦A', '♠2', '♠A', 'take']
# tim plays ♥K from hand.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['take']
# jasper takes the stack (8 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦Q', '♣Q', '♥Q']
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['♦Q', '♣Q', '♥Q']
# busse plays ♦Q from hand.
# busse can play a double card (Q).
# busse plays ♣Q from hand.
# busse can play a double card (Q).
# busse plays ♥Q from hand.
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       ['♠5', '♦2', '♦A', '♠2', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♦A', '♠2', '♠A', 'take']
# tim plays ♦A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♦A
# Hand:       ['♥8', '♣8', '♠8', '♠J', '♥J', '♣K', '♦K', '♥K']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♠K']
#
# Playable cards: ['♠K']
# busse plays ♠K from hidden.
# busse has won the game!
#
# tim's turn
# Top of stack:   ♠K
# Hand:       ['♠5', '♦2', '♠2', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♠2', '♠A', 'take']
# tim takes the stack (1 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥8', '♣8', '♠8', '♠J', '♥J', '♣K', '♦K', '♥K', '♦Q', '♣Q', '♥Q', '♦A']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♥8', '♣8', '♠8', '♠J', '♥J', '♣K', '♦K', '♥K', '♦Q', '♣Q', '♥Q', '♦A']
# jasper plays ♥8 from hand.
# jasper can play a double card (8).
# jasper plays ♣8 from hand.
# jasper can play a double card (8).
# jasper plays ♠8 from hand.
#
# tim's turn
# Top of stack:   ♠8
# Hand:       ['♠5', '♦2', '♠2', '♠A', '♠K']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♠2', '♠A', '♠K', 'take']
# tim plays ♠K from hand.
#
# jasper's turn
# Top of stack:   ♠K
# Hand:       ['♠J', '♥J', '♣K', '♦K', '♥K', '♦Q', '♣Q', '♥Q', '♦A']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♣K', '♦K', '♥K', '♦A', 'take']
# jasper plays ♣K from hand.
# jasper can play a double card (K).
# jasper plays ♦K from hand.
# jasper can play a double card (K).
# jasper plays ♥K from hand.
# Four of a kind detected - Stack cleared!
# jasper can play a double card (J).
# jasper plays ♥J from hand.
#
# tim's turn
# Top of stack:   ♥J
# Hand:       ['♠5', '♦2', '♠2', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♠2', '♠A', 'take']
# tim plays ♠A from hand.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       ['♦Q', '♣Q', '♥Q', '♦A']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦A', 'take']
# jasper plays ♦A from hand.
#
# tim's turn
# Top of stack:   ♦A
# Hand:       ['♠5', '♦2', '♠2']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♠2', 'take']
# tim takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦Q', '♣Q', '♥Q']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦Q', '♣Q', '♥Q']
# jasper plays ♦Q from hand.
# jasper can play a double card (Q).
# jasper plays ♣Q from hand.
# jasper can play a double card (Q).
# jasper plays ♥Q from hand.
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♠A', '♦A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♠2', '♠A', '♦A', 'take']
# tim plays ♠A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# jasper's turn
# Top of stack:   ♠A
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦Q', '♣Q', '♥Q', '♠A']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦Q', '♣Q', '♥Q', '♠A']
# jasper plays ♦Q from hand.
# jasper can play a double card (Q).
# jasper plays ♣Q from hand.
# jasper can play a double card (Q).
# jasper plays ♥Q from hand.
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♠2', '♦A', 'take']
# tim plays ♦A from hand.
#
# jasper's turn
# Top of stack:   ♦A
# Hand:       ['♠A']
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♠A', 'take']
# jasper plays ♠A from hand.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♦2', '♠2', 'take']
# tim takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# ...
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♦8']
#
# Playable cards: ['♦8']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# Displayed:  ['♥2', '♣2', '♣A']
# Hidden:     ['♠7', '♦3', '♦9']
#
# Playable cards: ['♠5', '♦2', '♠2', '♠J', '♥J', '♦Q', '♣Q', '♥Q', '♦A', '♠A']
# tim takes the stack (0 cards).
#
# Game over! Winners in order: ['natasja', 'busse', None]

# %% [markdown]
# Laat zien bij hoeveel rondes van het spel de spelers de eerste plaats (goud), de tweede plaats (zilver) of de derde plaats (brons) hebben behaald.

# %%
# Het simuleren van 10000 games
game.simulate_games(100)
# Out:
# Algemene performance in nummers:
#                     Aantal Games  Aantal Punten    1st    2nd    3rd    DNF  \
# jasper                     84000         124858  20997  22288  17291  23424
# busse                      84000         172809  35902  25032  15039   8027
# tim                        84000          63325   8527  10654  16436  48383
# natasja                    84000         135237  21764  24134  21677  16425
# low                        84000         124797  21014  22231  17293  23462
# justice_and_terror         84000         121563  19733  21752  18860  23655
# low_noon                   84000         149846  27993  23481  18905  13621
# random_go                  84000          77846  11548  13418  16366  42668
#
#                    1st Ratio 2nd Ratio 3rd Ratio DNF Ratio  Gem Eindpositie  \
# jasper                 25.0%    26.53%    20.58%    27.89%             2.51
# busse                 42.74%     29.8%     17.9%     9.56%             1.94
# tim                   10.15%    12.68%    19.57%     57.6%             3.25
# natasja               25.91%    28.73%    25.81%    19.55%             2.39
# low                   25.02%    26.47%    20.59%    27.93%             2.51
# justice_and_terror    23.49%     25.9%    22.45%    28.16%             2.55
# low_noon              33.32%    27.95%    22.51%    16.22%             2.22
# random_go             13.75%    15.97%    19.48%     50.8%             3.07
#
#                     Gem punten per game
# jasper                             1.49
# busse                              2.06
# tim                                0.75
# natasja                            1.61
# low                                1.49
# justice_and_terror                 1.45
# low_noon                           1.78
# random_go                          0.93
# Overwinningen vanaf verschillende startplekken:
# Punten en Podium verdeling:
# Performance per speler per combinatie van spelers:
