# %% [markdown]
# # **Zweeds Pesten**

# %% [markdown]
# Importeer de benodigde libraries en importeer de class ZweedsPesten

# %%
import sys
import os

# Ophalen path van de src folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Voeg de folder to aan path
if src_path not in sys.path:
    sys.path.append(src_path)

# Importeren van src is nu mogelijk
from utils import ZweedsPesten

# %% [markdown]
# Maakt variabele player_names aan, definieert en initialiseert een ZweedsPesten object genaamd game met de namen van de spelers.
# Bepaalt een winnaar door de game_loop method door te lopen van het ZweedsPesten-object.

# %%
# Lijst met spelers
player_names = ["jasper", "busse", "tim", "natasja", "low", "justice_and_terror", "low_noon", "random_go"]

# Opstarten spel met speler lijst
game = ZweedsPesten(player_names)

# Simuleren van een enkele game
winners = game.game_loop(verbose=2)
# Out:
# ------------ Starting Game ------------
# jasper:
# Hand:       ['♣5', '♥6', '♠7']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
# -----------------------------------------
# busse:
# Hand:       ['♦9', '♠4', '♣8']
# Displayed:  ['♥3', '♥J', '♠J']
# Hidden:     ['♥Q', '♠A', '♣2']
# -----------------------------------------
# tim:
# Hand:       ['♠8', '♣9', '♦J']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
# -----------------------------------------
# natasja:
# Hand:       ['♦6', '♣J', '♦5']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
# -----------------------------------------
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣5', '♥6', '♠7']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♣5', '♥6', '♠7']
# jasper plays ♣5 from hand.
# jasper draws a card: ♦2
#
# busse's turn
# Top of stack:   ♣5
# Hand:       ['♦9', '♠4', '♣8']
# Displayed:  ['♥3', '♥J', '♠J']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♦9', '♣8', 'take']
# busse plays ♣8 from hand.
# busse draws a card: ♦10
#
# tim's turn
# Top of stack:   ♣8
# Hand:       ['♠8', '♣9', '♦J']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♠8', '♣9', '♦J', 'take']
# tim plays ♠8 from hand.
# tim draws a card: ♥4
#
# natasja's turn
# Top of stack:   ♠8
# Hand:       ['♦6', '♣J', '♦5']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♣J', 'take']
# natasja plays ♣J from hand.
# natasja draws a card: ♠K
#
# jasper's turn
# Top of stack:   ♣J
# Hand:       ['♥6', '♠7', '♦2']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♦2', 'take']
# jasper plays ♦2 from hand.
# jasper draws a card: ♣3
#
# busse's turn
# Top of stack:   ♦2
# Hand:       ['♦9', '♠4', '♦10']
# Displayed:  ['♥3', '♥J', '♠J']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♦9', '♠4', '♦10', 'take']
# busse plays ♠4 from hand.
# busse draws a card: ♠6
#
# tim's turn
# Top of stack:   ♠4
# Hand:       ['♣9', '♦J', '♥4']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣9', '♦J', '♥4', 'take']
# tim plays ♥4 from hand.
# tim draws a card: ♣Q
#
# natasja's turn
# Top of stack:   ♥4
# Hand:       ['♦6', '♦5', '♠K']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♦6', '♦5', '♠K', 'take']
# natasja plays ♠K from hand.
# natasja draws a card: ♣10
#
# jasper's turn
# Top of stack:   ♠K
# Hand:       ['♥6', '♠7', '♣3']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♣3', 'take']
# jasper plays ♣3 from hand.
# jasper played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♥6', '♠7']
# jasper draws a card: ♠5
# jasper draws a card: ♣K
#
# busse's turn
# Top of stack:   ♥6
# Hand:       ['♦9', '♦10', '♠6']
# Displayed:  ['♥3', '♥J', '♠J']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♦9', '♦10', '♠6', 'take']
# busse plays ♠6 from hand.
# busse draws a card: ♣4
#
# tim's turn
# Top of stack:   ♠6
# Hand:       ['♣9', '♦J', '♣Q']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣9', '♦J', '♣Q', 'take']
# tim plays ♣9 from hand.
# tim draws a card: ♣7
#
# natasja's turn
# Top of stack:   ♣9
# Hand:       ['♦6', '♦5', '♣10']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♣10', 'take']
# natasja plays ♣10 from hand.
# natasja draws a card: ♥8
#
# jasper's turn
# Top of stack:   ♣10
# Hand:       ['♠7', '♠5', '♣K']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♣K', 'take']
# jasper plays ♣K from hand.
# jasper draws a card: ♣6
#
# busse's turn
# Top of stack:   ♣K
# Hand:       ['♦9', '♦10', '♣4']
# Displayed:  ['♥3', '♥J', '♠J']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♦10', 'take']
# busse plays ♦10 from hand.
# busse draws a card: ♠3
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♦J', '♣Q', '♣7']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['take']
# tim takes the stack (6 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦6', '♦5', '♥8']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♦6', '♦5', '♥8']
# natasja plays ♦5 from hand.
# natasja draws a card: ♥K
#
# jasper's turn
# Top of stack:   ♦5
# Hand:       ['♠7', '♠5', '♣6']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♠7', '♠5', '♣6', 'take']
# jasper plays ♠5 from hand.
#
# busse's turn
# Top of stack:   ♠5
# Hand:       ['♦9', '♣4', '♠3']
# Displayed:  ['♥3', '♥J', '♠J']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♦9', '♠3', 'take']
# busse plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♦J', '♣Q', '♣7', '♥6', '♠6', '♣9', '♣10', '♣K', '♦10']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♦J', '♣Q', '♣9', '♣10', '♣K', '♦10', 'take']
# tim plays ♣9 from hand.
#
# natasja's turn
# Top of stack:   ♣9
# Hand:       ['♦6', '♥8', '♥K']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥K', 'take']
# natasja plays ♥K from hand.
#
# jasper's turn
# Top of stack:   ♥K
# Hand:       ['♠7', '♣6']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♣4', '♠3']
# Displayed:  ['♥3', '♥J', '♠J']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♣4', '♠3']
# busse plays ♣4 from hand.
#
# tim's turn
# Top of stack:   ♣4
# Hand:       ['♦J', '♣Q', '♣7', '♥6', '♠6', '♣10', '♣K', '♦10']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♦J', '♣Q', '♣7', '♥6', '♠6', '♣10', '♣K', '♦10', 'take']
# tim plays ♥6 from hand.
# tim can play a double card (6).
# tim plays ♠6 from hand.
#
# natasja's turn
# Top of stack:   ♠6
# Hand:       ['♦6', '♥8']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♦6', '♥8', 'take']
# natasja plays ♦6 from hand.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♠7', '♣6', '♦5', '♠5', '♦9', '♣9', '♥K']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♠7', '♣6', '♦9', '♣9', '♥K', 'take']
# jasper plays ♣6 from hand.
# Four of a kind detected - Stack cleared!
# jasper can play a double card (5).
# jasper plays ♠5 from hand.
#
# busse's turn
# Top of stack:   ♠5
# Hand:       ['♠3']
# Displayed:  ['♥3', '♥J', '♠J']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♠3', 'take']
# busse plays ♠3 from hand.
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♥3', '♥J', '♠J']
# busse can play a double card (J).
# busse plays ♠J from displayed.
#
# tim's turn
# Top of stack:   ♠J
# Hand:       ['♦J', '♣Q', '♣7', '♣10', '♣K', '♦10']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♦J', '♣Q', '♣10', '♣K', '♦10', 'take']
# tim plays ♣10 from hand.
# tim can play a double card (10).
# tim plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♥8']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠7', '♦9', '♣9', '♥K']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♠7', '♦9', '♣9', '♥K']
# jasper plays ♠7 from hand.
#
# busse's turn
# Top of stack:   ♠7
# Hand:       []
# Displayed:  ['♥3']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦J', '♣Q', '♣7', '♣K']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♦J', '♣Q', '♣7', '♣K']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥8', '♥J', '♠J', '♣10', '♦10']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥8', '♥J', '♠J', '♣10', '♦10']
# natasja plays ♣10 from hand.
# natasja can play a double card (10).
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       ['♦9', '♣9', '♥K']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♦9', '♣9', '♥K', 'take']
# jasper plays ♦9 from hand.
# jasper can play a double card (9).
# jasper plays ♣9 from hand.
#
# busse's turn
# Top of stack:   ♣9
# Hand:       ['♠7']
# Displayed:  ['♥3']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['take']
# busse takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦J', '♣Q', '♣7', '♣K']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♦J', '♣Q', '♣7', '♣K']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥8', '♥J', '♠J']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥8', '♥J', '♠J']
# natasja plays ♥8 from hand.
#
# jasper's turn
# Top of stack:   ♥8
# Hand:       ['♥K']
# Displayed:  ['♠10', '♥A', '♦K']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♥K', 'take']
# jasper plays ♥K from hand.
# jasper can play a double card (K).
# jasper plays ♦K from displayed.
#
# busse's turn
# Top of stack:   ♦K
# Hand:       ['♠7', '♣10', '♦10', '♦9', '♣9']
# Displayed:  ['♥3']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♣10', '♦10', 'take']
# busse plays ♣10 from hand.
# busse can play a double card (10).
# busse plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♦J', '♣Q', '♣7', '♣K']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣K', 'take']
# tim plays ♣K from hand.
#
# natasja's turn
# Top of stack:   ♣K
# Hand:       ['♥J', '♠J']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['take']
# natasja takes the stack (6 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♠10', '♥A']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♠10', '♥A']
# jasper plays ♥A from displayed.
#
# busse's turn
# Top of stack:   ♥A
# Hand:       ['♠7', '♦9', '♣9']
# Displayed:  ['♥3']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['take']
# busse takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♦J', '♣Q', '♣7']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♦J', '♣Q', '♣7']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♠J', '♥8', '♥K', '♦K', '♣10', '♦10', '♣K']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥J', '♠J', '♥8', '♥K', '♦K', '♣10', '♦10', '♣K']
# natasja plays ♣10 from hand.
# natasja can play a double card (10).
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       []
# Displayed:  ['♠10']
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♠10', 'take']
# jasper plays ♠10 from displayed.
#
# busse's turn
# Top of stack:   ♠10
# Hand:       ['♠7', '♦9', '♣9', '♥A']
# Displayed:  ['♥3']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♠7', '♦9', '♣9', '♥A', 'take']
# busse plays ♠7 from hand.
#
# tim's turn
# Top of stack:   ♠7
# Hand:       ['♦J', '♣Q', '♣7']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['take']
# tim takes the stack (4 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♠J', '♥8', '♥K', '♦K', '♣K']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥J', '♠J', '♥8', '♥K', '♦K', '♣K']
# natasja plays ♥8 from hand.
#
# jasper's turn
# Top of stack:   ♥8
# Hand:       []
# Displayed:  []
# Hidden:     ['♠9', '♥9', '♣A']
#
# Playable cards: ['♣A', 'take']
# jasper plays ♣A from hidden.
#
# busse's turn
# Top of stack:   ♣A
# Hand:       ['♦9', '♣9', '♥A']
# Displayed:  ['♥3']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♥A', 'take']
# busse plays ♥A from hand.
#
# tim's turn
# Top of stack:   ♥A
# Hand:       ['♦J', '♣Q', '♣7', '♣10', '♦10', '♠10', '♠7']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣10', '♦10', '♠10', 'take']
# tim plays ♣10 from hand.
# tim can play a double card (10).
# tim plays ♠10 from hand.
# tim can play a double card (10).
# tim plays ♦10 from hand.
#
# natasja's turn
# Top of stack:   ♦10
# Hand:       ['♥J', '♠J', '♥K', '♦K', '♣K']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['take']
# natasja takes the stack (6 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['♥9']
# jasper takes the stack (0 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       ['♦9', '♣9']
# Displayed:  ['♥3']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♦9', '♣9']
# busse plays ♦9 from hand.
# busse can play a double card (9).
# busse plays ♣9 from hand.
#
# tim's turn
# Top of stack:   ♣9
# Hand:       ['♦J', '♣Q', '♣7', '♠7']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♦J', '♣Q', 'take']
# tim plays ♦J from hand.
#
# natasja's turn
# Top of stack:   ♦J
# Hand:       ['♥J', '♠J', '♥K', '♦K', '♣K', '♥8', '♣A', '♥A', '♣10', '♠10', '♦10']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥J', '♠J', '♥K', '♦K', '♣K', '♣A', '♥A', '♣10', '♠10', '♦10', 'take']
# natasja plays ♣10 from hand.
# natasja can play a double card (10).
# natasja plays ♠10 from hand.
# natasja can play a double card (10).
# natasja plays ♦10 from hand.
#
# jasper's turn
# Top of stack:   ♦10
# Hand:       []
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (6 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥3']
# Hidden:     ['♥Q', '♠A', '♣2']
#
# Playable cards: ['♥3']
# busse plays ♥3 from displayed.
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♣2']
#
# tim's turn
# Top of stack:   ♣2
# Hand:       ['♣Q', '♣7', '♠7']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣Q', '♣7', '♠7', 'take']
# tim takes the stack (1 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♠J', '♥K', '♦K', '♣K', '♥8', '♣A', '♥A']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥J', '♠J', '♥K', '♦K', '♣K', '♥8', '♣A', '♥A']
# natasja plays ♥8 from hand.
#
# jasper's turn
# Top of stack:   ♥8
# Hand:       ['♦9', '♣9', '♦J', '♣10', '♠10', '♦10']
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['♦9', '♣9', '♦J', '♣10', '♠10', '♦10', 'take']
# jasper plays ♦9 from hand.
# jasper can play a double card (9).
# jasper plays ♣9 from hand.
#
# busse's turn
# Top of stack:   ♣9
# Hand:       []
# Displayed:  []
# Hidden:     ['♥Q', '♠A']
#
# Playable cards: ['♠A', 'take']
# busse plays ♠A from hidden.
#
# tim's turn
# Top of stack:   ♠A
# Hand:       ['♣Q', '♣7', '♠7', '♣2']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣2', 'take']
# tim plays ♣2 from hand.
#
# natasja's turn
# Top of stack:   ♣2
# Hand:       ['♥J', '♠J', '♥K', '♦K', '♣K', '♣A', '♥A']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥J', '♠J', '♥K', '♦K', '♣K', '♣A', '♥A', 'take']
# natasja plays ♥J from hand.
# natasja can play a double card (J).
# natasja plays ♠J from hand.
#
# jasper's turn
# Top of stack:   ♠J
# Hand:       ['♦J', '♣10', '♠10', '♦10']
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['♦J', '♣10', '♠10', '♦10', 'take']
# jasper plays ♦J from hand.
#
# busse's turn
# Top of stack:   ♦J
# Hand:       []
# Displayed:  []
# Hidden:     ['♥Q']
#
# Playable cards: ['♥Q', 'take']
# busse plays ♥Q from hidden.
# busse has won the game!
#
# tim's turn
# Top of stack:   ♥Q
# Hand:       ['♣Q', '♣7', '♠7']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣Q', 'take']
# tim plays ♣Q from hand.
#
# natasja's turn
# Top of stack:   ♣Q
# Hand:       ['♥K', '♦K', '♣K', '♣A', '♥A']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥K', '♦K', '♣K', '♣A', '♥A', 'take']
# natasja plays ♥K from hand.
# natasja can play a double card (K).
# natasja plays ♦K from hand.
# natasja can play a double card (K).
# natasja plays ♣K from hand.
#
# jasper's turn
# Top of stack:   ♣K
# Hand:       ['♣10', '♠10', '♦10']
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['♣10', '♠10', '♦10', 'take']
# jasper plays ♣10 from hand.
# jasper can play a double card (10).
# jasper plays ♠10 from hand.
# jasper can play a double card (10).
# jasper plays ♦10 from hand.
#
# tim's turn
# Top of stack:   ♦10
# Hand:       ['♣7', '♠7']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['take']
# tim takes the stack (16 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣A', '♥A']
# Displayed:  ['♦A', '♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♣A', '♥A']
# natasja plays ♣A from hand.
# natasja can play a double card (A).
# natasja plays ♥A from hand.
# natasja can play a double card (A).
# natasja plays ♦A from displayed.
#
# jasper's turn
# Top of stack:   ♦A
# Hand:       []
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (3 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣7', '♠7', '♥8', '♦9', '♣9', '♠A', '♣2', '♥J', '♠J', '♦J', '♥Q', '♣Q', '♥K', '♦K', '♣K', '♣10', '♠10', '♦10']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣7', '♠7', '♥8', '♦9', '♣9', '♠A', '♣2', '♥J', '♠J', '♦J', '♥Q', '♣Q', '♥K', '♦K', '♣K', '♣10', '♠10', '♦10']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♦Q', '♠Q']
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♦Q', '♠Q']
# natasja plays ♦Q from displayed.
# natasja can play a double card (Q).
# natasja plays ♠Q from displayed.
#
# jasper's turn
# Top of stack:   ♠Q
# Hand:       ['♣A', '♥A', '♦A']
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['♣A', '♥A', '♦A', 'take']
# jasper plays ♣A from hand.
# jasper can play a double card (A).
# jasper plays ♥A from hand.
# jasper can play a double card (A).
# jasper plays ♦A from hand.
#
# tim's turn
# Top of stack:   ♦A
# Hand:       ['♣7', '♠7', '♥8', '♦9', '♣9', '♠A', '♣2', '♥J', '♠J', '♦J', '♥Q', '♣Q', '♥K', '♦K', '♣K', '♣10', '♠10', '♦10']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♠A', '♣2', '♣10', '♠10', '♦10', 'take']
# tim takes the stack (5 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♥5', '♥2', '♥7']
#
# Playable cards: ['♥7']
# natasja plays ♥7 from hidden.
#
# jasper's turn
# Top of stack:   ♥7
# Hand:       []
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣7', '♠7', '♥8', '♦9', '♣9', '♠A', '♣2', '♥J', '♠J', '♦J', '♥Q', '♣Q', '♥K', '♦K', '♣K', '♣10', '♠10', '♦10', '♦Q', '♠Q', '♣A', '♥A', '♦A']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣7', '♠7', '♥8', '♦9', '♣9', '♠A', '♣2', '♥J', '♠J', '♦J', '♥Q', '♣Q', '♥K', '♦K', '♣K', '♣10', '♠10', '♦10', '♦Q', '♠Q', '♣A', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♥5', '♥2']
#
# Playable cards: ['♥2']
# natasja plays ♥2 from hidden.
#
# jasper's turn
# Top of stack:   ♥2
# Hand:       ['♥7']
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['♥7', 'take']
# jasper plays ♥7 from hand.
#
# tim's turn
# Top of stack:   ♥7
# Hand:       ['♣7', '♠7', '♥8', '♦9', '♣9', '♠A', '♣2', '♥J', '♠J', '♦J', '♥Q', '♣Q', '♥K', '♦K', '♣K', '♣10', '♠10', '♦10', '♦Q', '♠Q', '♣A', '♥A', '♦A']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♣2', '♣10', '♠10', '♦10', 'take']
# tim plays ♣10 from hand.
# tim can play a double card (10).
# tim plays ♦10 from hand.
# tim can play a double card (10).
# tim plays ♠10 from hand.
#
# natasja's turn
# Top of stack:   ♠10
# Hand:       []
# Displayed:  []
# Hidden:     ['♥5']
#
# Playable cards: ['♥5', 'take']
# natasja plays ♥5 from hidden.
# natasja has won the game!
#
# jasper's turn
# Top of stack:   ♥5
# Hand:       []
# Displayed:  []
# Hidden:     ['♠9', '♥9']
#
# Playable cards: ['♥9', 'take']
# jasper plays ♥9 from hidden.
#
# tim's turn
# Top of stack:   ♥9
# Hand:       ['♣7', '♠7', '♥8', '♦9', '♣9', '♠A', '♣2', '♥J', '♠J', '♦J', '♥Q', '♣Q', '♥K', '♦K', '♣K', '♦Q', '♠Q', '♣A', '♥A', '♦A']
# Displayed:  ['♠2', '♥10', '♦7']
# Hidden:     ['♦3', '♦8', '♦4']
#
# Playable cards: ['♦9', '♣9', '♠A', '♣2', '♥J', '♠J', '♦J', '♥Q', '♣Q', '♥K', '♦K', '♣K', '♦Q', '♠Q', '♣A', '♥A', '♦A', 'take']
# tim plays ♦9 from hand.
# tim can play a double card (9).
# tim plays ♣9 from hand.
#
# jasper's turn
# Top of stack:   ♣9
# Hand:       []
# Displayed:  []
# Hidden:     ['♠9']
#
# Playable cards: ['♠9', 'take']
# jasper plays ♠9 from hidden.
# jasper has won the game!
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# tim is the last remaining player. No further turns needed.
#
# Game over! Winners in order: ['busse', 'natasja', 'jasper']

# %% [markdown]
# Laat zien bij hoeveel rondes van het spel de spelers de eerste plaats (goud), de tweede plaats (zilver) of de derde plaats (brons) hebben behaald.

# %%
# Het simuleren van 10000 games
game.simulate_games(10000)
# Out:
# Algemene performance in nummers:
#                     Aantal Games  Aantal Punten      1st      2nd      3rd  \
# jasper                   8400000       12459995  2090272  2223050  1743079
# busse                    8400000       17294349  3593550  2508941  1495817
# tim                      8400000        6307651   847383  1066116  1633270
# natasja                  8400000       13529837  2186505  2408422  2153478
# low                      8400000       12470276  2092401  2225491  1742091
# justice_and_terror       8400000       12178070  1972637  2192401  1875357
# low_noon                 8400000       14993898  2801623  2349714  1889601
# random_go                8400000        7784878  1162302  1322915  1652142
#
#                         DNF 1st Ratio 2nd Ratio 3rd Ratio DNF Ratio  \
# jasper              2343599    24.88%    26.46%    20.75%     27.9%
# busse                801692    42.78%    29.87%    17.81%     9.54%
# tim                 4853231    10.09%    12.69%    19.44%    57.78%
# natasja             1651595    26.03%    28.67%    25.64%    19.66%
# low                 2340017    24.91%    26.49%    20.74%    27.86%
# justice_and_terror  2359605    23.48%     26.1%    22.33%    28.09%
# low_noon            1359062    33.35%    27.97%     22.5%    16.18%
# random_go           4262641    13.84%    15.75%    19.67%    50.75%
#
#                     Gem Eindpositie  Gem punten per game
# jasper                         2.52                 1.48
# busse                          1.94                 2.06
# tim                            3.25                 0.75
# natasja                        2.39                 1.61
# low                            2.52                 1.48
# justice_and_terror             2.55                 1.45
# low_noon                       2.22                 1.78
# random_go                      3.07                 0.93
# Overwinningen vanaf verschillende startplekken:
# Punten en Podium verdeling:
# Performance per speler per combinatie van spelers:
