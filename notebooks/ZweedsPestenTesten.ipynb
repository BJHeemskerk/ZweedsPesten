# %% [markdown]
# # **Zweeds Pesten**

# %% [markdown]
# Importeer de benodigde libraries en importeer de class ZweedsPesten

# %%
import sys
import os

# Ophalen path van de src folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))

# Voeg de folder to aan path
if src_path not in sys.path:
    sys.path.append(src_path)

# Importeren van src is nu mogelijk
from utils import ZweedsPesten

# %% [markdown]
# Maakt variabele player_names aan, definieert en initialiseert een ZweedsPesten object genaamd game met de namen van de spelers.
# Bepaalt een winnaar door de game_loop method door te lopen van het ZweedsPesten-object.

# %%
# Lijst met spelers
player_names = ["jasper", "busse", "tim", "natasja", "low", "justice_and_terror"]

# Opstarten spel met speler lijst
game = ZweedsPesten(player_names)

# Simuleren van een enkele game
winners = game.game_loop(verbose=2)
# Out:
# ------------ Starting Game ------------
# jasper:
# Hand:       ['♥Q', '♣Q', '♥4']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
# -----------------------------------------
# busse:
# Hand:       ['♥5', '♦9', '♠6']
# Displayed:  ['♣2', '♥A', '♣K']
# Hidden:     ['♣9', '♥K', '♦A']
# -----------------------------------------
# tim:
# Hand:       ['♣8', '♥J', '♠K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
# -----------------------------------------
# natasja:
# Hand:       ['♦4', '♣5', '♠5']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
# -----------------------------------------
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♣Q', '♥4']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥Q', '♣Q', '♥4']
# jasper plays ♥4 from hand.
# jasper draws a card: ♥7
#
# busse's turn
# Top of stack:   ♥4
# Hand:       ['♥5', '♦9', '♠6']
# Displayed:  ['♣2', '♥A', '♣K']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♥5', '♦9', '♠6', 'take']
# busse plays ♥5 from hand.
# busse draws a card: ♣6
#
# tim's turn
# Top of stack:   ♥5
# Hand:       ['♣8', '♥J', '♠K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥J', '♠K', 'take']
# tim plays ♣8 from hand.
# tim draws a card: ♦Q
#
# natasja's turn
# Top of stack:   ♣8
# Hand:       ['♦4', '♣5', '♠5']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♣Q', '♥7']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥Q', '♣Q', '♥7']
# jasper plays ♥7 from hand.
# jasper draws a card: ♣A
#
# busse's turn
# Top of stack:   ♥7
# Hand:       ['♦9', '♠6', '♣6']
# Displayed:  ['♣2', '♥A', '♣K']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♠6', '♣6', 'take']
# busse plays ♠6 from hand.
# busse can play a double card (6).
# busse plays ♣6 from hand.
# busse draws a card: ♦3
# busse draws a card: ♣7
#
# tim's turn
# Top of stack:   ♣6
# Hand:       ['♥J', '♠K', '♦Q']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♥J', '♠K', '♦Q', 'take']
# tim plays ♥J from hand.
# tim draws a card: ♥8
#
# natasja's turn
# Top of stack:   ♥J
# Hand:       ['♦4', '♣5', '♠5', '♥4', '♥5', '♣8']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥Q', '♣Q', '♣A']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥Q', '♣Q', '♣A']
# jasper plays ♥Q from hand.
# jasper can play a double card (Q).
# jasper plays ♣Q from hand.
# jasper draws a card: ♣J
# jasper draws a card: ♠7
#
# busse's turn
# Top of stack:   ♣Q
# Hand:       ['♦9', '♦3', '♣7']
# Displayed:  ['♣2', '♥A', '♣K']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♦3', 'take']
# busse plays ♦3 from hand.
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♦9', '♣7']
# busse draws a card: ♦J
# busse draws a card: ♥6
#
# tim's turn
# Top of stack:   ♣7
# Hand:       ['♠K', '♦Q', '♥8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['take']
# tim takes the stack (1 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦4', '♣5', '♠5', '♥4', '♥5', '♣8', '♥7', '♠6', '♣6', '♥J']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♦4', '♣5', '♠5', '♥4', '♥5', '♣8', '♥7', '♠6', '♣6', '♥J']
# natasja plays ♦4 from hand.
# natasja can play a double card (4).
# natasja plays ♥4 from hand.
#
# jasper's turn
# Top of stack:   ♥4
# Hand:       ['♣A', '♣J', '♠7']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♣A', '♣J', '♠7', 'take']
# jasper plays ♠7 from hand.
# jasper draws a card: ♦5
#
# busse's turn
# Top of stack:   ♠7
# Hand:       ['♦9', '♦J', '♥6']
# Displayed:  ['♣2', '♥A', '♣K']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♥6', 'take']
# busse plays ♥6 from hand.
# busse draws a card: ♠3
#
# tim's turn
# Top of stack:   ♥6
# Hand:       ['♠K', '♦Q', '♥8', '♣7']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠K', '♦Q', '♥8', '♣7', 'take']
# tim plays ♣7 from hand.
#
# natasja's turn
# Top of stack:   ♣7
# Hand:       ['♣5', '♠5', '♥5', '♣8', '♥7', '♠6', '♣6', '♥J']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♣5', '♠5', '♥5', '♠6', '♣6', 'take']
# natasja plays ♣5 from hand.
# natasja can play a double card (5).
# natasja plays ♠5 from hand.
# natasja can play a double card (5).
# natasja plays ♥5 from hand.
#
# jasper's turn
# Top of stack:   ♥5
# Hand:       ['♣A', '♣J', '♦5']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♣A', '♣J', '♦5', 'take']
# jasper plays ♦5 from hand.
# Four of a kind detected - Stack cleared!
# jasper draws a card: ♠J
# jasper draws a card: ♣10
# jasper can play a double card (J).
# jasper plays ♠J from hand.
# jasper draws a card: ♠9
#
# busse's turn
# Top of stack:   ♠J
# Hand:       ['♦9', '♦J', '♠3']
# Displayed:  ['♣2', '♥A', '♣K']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♦J', '♠3', 'take']
# busse plays ♦J from hand.
#
# tim's turn
# Top of stack:   ♦J
# Hand:       ['♠K', '♦Q', '♥8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠K', '♦Q', 'take']
# tim plays ♦Q from hand.
#
# natasja's turn
# Top of stack:   ♦Q
# Hand:       ['♣8', '♥7', '♠6', '♣6', '♥J']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣A', '♣10', '♠9']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♣A', '♣10', '♠9']
# jasper plays ♠9 from hand.
#
# busse's turn
# Top of stack:   ♠9
# Hand:       ['♦9', '♠3']
# Displayed:  ['♣2', '♥A', '♣K']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♦9', '♠3', 'take']
# busse plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♠K', '♥8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠K', 'take']
# tim plays ♠K from hand.
#
# natasja's turn
# Top of stack:   ♠K
# Hand:       ['♣8', '♥7', '♠6', '♣6', '♥J', '♣J', '♠J', '♦J', '♦Q']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['take']
# natasja takes the stack (3 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♣A', '♣10']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♣A', '♣10']
# jasper plays ♣A from hand.
#
# busse's turn
# Top of stack:   ♣A
# Hand:       ['♠3']
# Displayed:  ['♣2', '♥A', '♣K']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♠3', 'take']
# busse plays ♠3 from hand.
# busse played a 3 - Stack cleared!
# Top of stack:   Empty
# Playable cards: ['♣2', '♥A', '♣K']
#
# tim's turn
# Top of stack:   ♣K
# Hand:       ['♥8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['take']
# tim takes the stack (1 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥7', '♠6', '♣6', '♥J', '♣J', '♠J', '♦J', '♦Q', '♠9', '♦9', '♠K']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♣8', '♥7', '♠6', '♣6', '♥J', '♣J', '♠J', '♦J', '♦Q', '♠9', '♦9', '♠K']
# natasja plays ♠6 from hand.
# natasja can play a double card (6).
# natasja plays ♣6 from hand.
#
# jasper's turn
# Top of stack:   ♣6
# Hand:       ['♣10']
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♣10', 'take']
# jasper plays ♣10 from hand.
#
# busse's turn
# Top of stack:   ♣10
# Hand:       []
# Displayed:  ['♣2', '♥A']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♣2', '♥A', 'take']
# busse plays ♥A from displayed.
#
# tim's turn
# Top of stack:   ♥A
# Hand:       ['♥8', '♣K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['take']
# tim takes the stack (4 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥7', '♥J', '♣J', '♠J', '♦J', '♦Q', '♠9', '♦9', '♠K']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♣8', '♥7', '♥J', '♣J', '♠J', '♦J', '♦Q', '♠9', '♦9', '♠K']
# natasja plays ♥7 from hand.
#
# jasper's turn
# Top of stack:   ♥7
# Hand:       []
# Displayed:  ['♥2', '♦2', '♠2']
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥2', '♦2', '♠2', 'take']
# jasper plays ♥2 from displayed.
# jasper can play a double card (2).
# jasper plays ♦2 from displayed.
# jasper can play a double card (2).
# jasper plays ♠2 from displayed.
#
# busse's turn
# Top of stack:   ♠2
# Hand:       []
# Displayed:  ['♣2']
# Hidden:     ['♣9', '♥K', '♦A']
#
# Playable cards: ['♣2', 'take']
# busse plays ♣2 from displayed.
# Four of a kind detected - Stack cleared!
#
# tim's turn
# Top of stack:   ♦A
# Hand:       ['♥8', '♣K', '♠6', '♣6', '♣10', '♥A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣10', '♥A', 'take']
# tim takes the stack (1 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥J', '♣J', '♠J', '♦J', '♦Q', '♠9', '♦9', '♠K']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♣8', '♥J', '♣J', '♠J', '♦J', '♦Q', '♠9', '♦9', '♠K']
# natasja plays ♣8 from hand.
#
# jasper's turn
# Top of stack:   ♣8
# Hand:       []
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♣9', '♥K']
#
# Playable cards: ['♥K']
# busse plays ♥K from hidden.
#
# tim's turn
# Top of stack:   ♥K
# Hand:       ['♥8', '♣K', '♠6', '♣6', '♣10', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣K', '♣10', '♥A', '♦A', 'take']
# tim takes the stack (1 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥J', '♣J', '♠J', '♦J', '♦Q', '♠9', '♦9', '♠K']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♥J', '♣J', '♠J', '♦J', '♦Q', '♠9', '♦9', '♠K']
# natasja plays ♠9 from hand.
# natasja can play a double card (9).
# natasja plays ♦9 from hand.
#
# jasper's turn
# Top of stack:   ♦9
# Hand:       ['♣8']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# busse's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♣9']
#
# Playable cards: ['♣9']
# busse plays ♣9 from hidden.
# busse has won the game!
#
# tim's turn
# Top of stack:   ♣9
# Hand:       ['♥8', '♣K', '♠6', '♣6', '♣10', '♥A', '♦A', '♥K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣K', '♣10', '♥A', '♦A', '♥K', 'take']
# tim plays ♣10 from hand.
#
# natasja's turn
# Top of stack:   ♣10
# Hand:       ['♥J', '♣J', '♠J', '♦J', '♦Q', '♠K']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♥J', '♣J', '♠J', '♦J', '♦Q', '♠K', 'take']
# natasja plays ♥J from hand.
# natasja can play a double card (J).
# natasja plays ♣J from hand.
# natasja can play a double card (J).
# natasja plays ♠J from hand.
# natasja can play a double card (J).
# natasja plays ♦J from hand.
# Four of a kind detected - Stack cleared!
#
# jasper's turn
# Top of stack:   ♦Q
# Hand:       ['♣8', '♠9', '♦9']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥8', '♣K', '♠6', '♣6', '♥A', '♦A', '♥K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♥8', '♣K', '♠6', '♣6', '♥A', '♦A', '♥K']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠K']
# Displayed:  ['♥10', '♦K', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♠K']
# natasja plays ♠K from hand.
# natasja can play a double card (K).
# natasja plays ♦K from displayed.
#
# jasper's turn
# Top of stack:   ♦K
# Hand:       ['♣8', '♠9', '♦9', '♦Q']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♥8', '♣K', '♠6', '♣6', '♥A', '♦A', '♥K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♥8', '♣K', '♠6', '♣6', '♥A', '♦A', '♥K']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  ['♥10', '♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♥10', '♠Q']
# natasja plays ♥10 from displayed.
#
# jasper's turn
# Top of stack:   ♥10
# Hand:       ['♣8', '♠9', '♦9', '♦Q', '♠K', '♦K']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♣8', '♠9', '♦9', '♦Q', '♠K', '♦K', 'take']
# jasper plays ♣8 from hand.
#
# tim's turn
# Top of stack:   ♣8
# Hand:       ['♥8', '♣K', '♠6', '♣6', '♥A', '♦A', '♥K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♥8', '♣K', '♥A', '♦A', '♥K', 'take']
# tim plays ♥8 from hand.
#
# natasja's turn
# Top of stack:   ♥8
# Hand:       []
# Displayed:  ['♠Q']
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♠Q', 'take']
# natasja plays ♠Q from displayed.
#
# jasper's turn
# Top of stack:   ♠Q
# Hand:       ['♠9', '♦9', '♦Q', '♠K', '♦K']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♦Q', '♠K', '♦K', 'take']
# jasper plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♣K', '♠6', '♣6', '♥A', '♦A', '♥K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣K', '♥A', '♦A', '♥K', 'take']
# tim plays ♣K from hand.
# tim can play a double card (K).
# tim plays ♥K from hand.
#
# natasja's turn
# Top of stack:   ♥K
# Hand:       []
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['take']
# natasja takes the stack (7 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠9', '♦9', '♠K', '♦K']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♠9', '♦9', '♠K', '♦K']
# jasper plays ♠9 from hand.
# jasper can play a double card (9).
# jasper plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♠6', '♣6', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♥A', '♦A', 'take']
# tim plays ♥A from hand.
# tim can play a double card (A).
# tim skipped playing a double card.
#
# natasja's turn
# Top of stack:   ♥A
# Hand:       ['♥10', '♣8', '♥8', '♠Q', '♦Q', '♣K', '♥K']
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♥10', 'take']
# natasja plays ♥10 from hand.
#
# jasper's turn
# Top of stack:   ♥10
# Hand:       ['♠K', '♦K']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (4 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠6', '♣6', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠6', '♣6', '♦A']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♠Q', '♦Q', '♣K', '♥K']
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♣8', '♥8', '♠Q', '♦Q', '♣K', '♥K']
# natasja plays ♣8 from hand.
# natasja can play a double card (8).
# natasja plays ♥8 from hand.
#
# jasper's turn
# Top of stack:   ♥8
# Hand:       ['♠K', '♦K', '♠9', '♦9', '♥A', '♥10']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♠K', '♦K', '♠9', '♦9', '♥A', '♥10', 'take']
# jasper plays ♠9 from hand.
# jasper can play a double card (9).
# jasper plays ♦9 from hand.
#
# tim's turn
# Top of stack:   ♦9
# Hand:       ['♠6', '♣6', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♦A', 'take']
# tim plays ♦A from hand.
#
# natasja's turn
# Top of stack:   ♦A
# Hand:       ['♠Q', '♦Q', '♣K', '♥K']
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['take']
# natasja takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♠K', '♦K', '♥A', '♥10']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♠K', '♦K', '♥A', '♥10']
# jasper plays ♠K from hand.
# jasper can play a double card (K).
# jasper plays ♦K from hand.
#
# tim's turn
# Top of stack:   ♦K
# Hand:       ['♠6', '♣6']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠Q', '♦Q', '♣K', '♥K', '♣8', '♥8', '♠9', '♦9', '♦A']
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♠Q', '♦Q', '♣K', '♥K', '♣8', '♥8', '♠9', '♦9', '♦A']
# natasja plays ♣8 from hand.
# natasja can play a double card (8).
# natasja plays ♥8 from hand.
#
# jasper's turn
# Top of stack:   ♥8
# Hand:       ['♥A', '♥10']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥A', '♥10', 'take']
# jasper plays ♥A from hand.
#
# tim's turn
# Top of stack:   ♥A
# Hand:       ['♠6', '♣6', '♠K', '♦K']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['take']
# tim takes the stack (3 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠Q', '♦Q', '♣K', '♥K', '♠9', '♦9', '♦A']
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♠Q', '♦Q', '♣K', '♥K', '♠9', '♦9', '♦A']
# natasja plays ♠9 from hand.
# natasja can play a double card (9).
# natasja plays ♦9 from hand.
#
# jasper's turn
# Top of stack:   ♦9
# Hand:       ['♥10']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥10', 'take']
# jasper plays ♥10 from hand.
#
# tim's turn
# Top of stack:   ♥10
# Hand:       ['♠6', '♣6', '♠K', '♦K', '♣8', '♥8', '♥A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠K', '♦K', '♥A', 'take']
# tim plays ♠K from hand.
# tim can play a double card (K).
# tim plays ♦K from hand.
#
# natasja's turn
# Top of stack:   ♦K
# Hand:       ['♠Q', '♦Q', '♣K', '♥K', '♦A']
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♣K', '♥K', '♦A', 'take']
# natasja plays ♣K from hand.
# natasja can play a double card (K).
# natasja plays ♥K from hand.
# Four of a kind detected - Stack cleared!
# natasja can play a double card (Q).
# natasja plays ♦Q from hand.
#
# jasper's turn
# Top of stack:   ♦Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠6', '♣6', '♣8', '♥8', '♥A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠6', '♣6', '♣8', '♥8', '♥A']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦A']
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♦A']
# natasja plays ♦A from hand.
#
# jasper's turn
# Top of stack:   ♦A
# Hand:       ['♠Q', '♦Q']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠6', '♣6', '♣8', '♥8', '♥A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠6', '♣6', '♣8', '♥8', '♥A']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♥3', '♦6', '♦8']
#
# Playable cards: ['♦8']
# natasja plays ♦8 from hidden.
#
# jasper's turn
# Top of stack:   ♦8
# Hand:       ['♠Q', '♦Q', '♦A']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♠Q', '♦Q', '♦A', 'take']
# jasper plays ♠Q from hand.
# jasper can play a double card (Q).
# jasper plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♠6', '♣6', '♣8', '♥8', '♥A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♥A', 'take']
# tim plays ♥A from hand.
#
# natasja's turn
# Top of stack:   ♥A
# Hand:       []
# Displayed:  []
# Hidden:     ['♥3', '♦6']
#
# Playable cards: ['take']
# natasja takes the stack (4 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♦A']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♦A']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠6', '♣6', '♣8', '♥8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠6', '♣6', '♣8', '♥8']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♦8', '♠Q', '♦Q', '♥A']
# Displayed:  []
# Hidden:     ['♥3', '♦6']
#
# Playable cards: ['♦8', '♠Q', '♦Q', '♥A']
# natasja plays ♦8 from hand.
#
# jasper's turn
# Top of stack:   ♦8
# Hand:       ['♦A']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♦A', 'take']
# jasper plays ♦A from hand.
#
# tim's turn
# Top of stack:   ♦A
# Hand:       ['♠6', '♣6', '♣8', '♥8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♠Q', '♦Q', '♥A']
# Displayed:  []
# Hidden:     ['♥3', '♦6']
#
# Playable cards: ['♠Q', '♦Q', '♥A']
# natasja plays ♠Q from hand.
# natasja can play a double card (Q).
# natasja plays ♦Q from hand.
#
# jasper's turn
# Top of stack:   ♦Q
# Hand:       []
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (2 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠6', '♣6', '♣8', '♥8', '♦8', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠6', '♣6', '♣8', '♥8', '♦8', '♦A']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       ['♥A']
# Displayed:  []
# Hidden:     ['♥3', '♦6']
#
# Playable cards: ['♥A']
# natasja plays ♥A from hand.
#
# jasper's turn
# Top of stack:   ♥A
# Hand:       ['♠Q', '♦Q']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (1 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠6', '♣6', '♣8', '♥8', '♦8', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠6', '♣6', '♣8', '♥8', '♦8', '♦A']
# tim takes the stack (0 cards).
#
# natasja's turn
# Top of stack:   Empty
# Hand:       []
# Displayed:  []
# Hidden:     ['♥3', '♦6']
#
# Playable cards: ['♦6']
# natasja plays ♦6 from hidden.
#
# jasper's turn
# Top of stack:   ♦6
# Hand:       ['♠Q', '♦Q', '♥A']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♠Q', '♦Q', '♥A', 'take']
# jasper plays ♠Q from hand.
# jasper can play a double card (Q).
# jasper plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♠6', '♣6', '♣8', '♥8', '♦8', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♦A', 'take']
# tim plays ♦A from hand.
#
# natasja's turn
# Top of stack:   ♦A
# Hand:       []
# Displayed:  []
# Hidden:     ['♥3']
#
# Playable cards: ['♥3', 'take']
# natasja plays ♥3 from hidden.
# natasja has won the game!
#
# jasper's turn
# Top of stack:   ♥3
# Hand:       ['♥A']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['take']
# jasper takes the stack (5 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♠6', '♣6', '♣8', '♥8', '♦8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠6', '♣6', '♣8', '♥8', '♦8']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥A', '♦6', '♠Q', '♦Q', '♦A', '♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥A', '♦6', '♠Q', '♦Q', '♦A', '♥3']
# jasper plays ♦6 from hand.
#
# tim's turn
# Top of stack:   ♦6
# Hand:       ['♠6', '♣6', '♣8', '♥8', '♦8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♠6', '♣6', '♣8', '♥8', '♦8', 'take']
# tim plays ♠6 from hand.
# tim can play a double card (6).
# tim plays ♣6 from hand.
#
# jasper's turn
# Top of stack:   ♣6
# Hand:       ['♥A', '♠Q', '♦Q', '♦A', '♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥A', '♠Q', '♦Q', '♦A', '♥3', 'take']
# jasper plays ♠Q from hand.
# jasper can play a double card (Q).
# jasper plays ♦Q from hand.
#
# tim's turn
# Top of stack:   ♦Q
# Hand:       ['♣8', '♥8', '♦8']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['take']
# tim takes the stack (5 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥A', '♦A', '♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥A', '♦A', '♥3']
# jasper plays ♥A from hand.
# jasper can play a double card (A).
# jasper plays ♦A from hand.
#
# tim's turn
# Top of stack:   ♦A
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['take']
# tim takes the stack (2 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# ...
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# jasper's turn
# Top of stack:   Empty
# Hand:       ['♥3']
# Displayed:  []
# Hidden:     ['♣4', '♠10', '♦7']
#
# Playable cards: ['♥3']
# jasper takes the stack (0 cards).
#
# tim's turn
# Top of stack:   Empty
# Hand:       ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# Displayed:  ['♦10', '♠A', '♠4']
# Hidden:     ['♥9', '♠8', '♣3']
#
# Playable cards: ['♣8', '♥8', '♦8', '♦6', '♠6', '♣6', '♠Q', '♦Q', '♥A', '♦A']
# tim takes the stack (0 cards).
#
# Game over! Winners in order: ['busse', 'natasja', None]

# %% [markdown]
# Laat zien bij hoeveel rondes van het spel de spelers de eerste plaats (goud), de tweede plaats (zilver) of de derde plaats (brons) hebben behaald.

# %%
# Het simuleren van 10000 games
game.simulate_games(10000)
# Out:
# Algemene performance in nummers:
#                     Aantal Games  Aantal Punten  Performance Score      1st  \
# jasper                   2400000        3534722         2116695.57   606679
# busse                    2400000        5222331         4374748.02  1147335
# tim                      2400000        1818224          407546.76   249354
# natasja                  2400000        2406031          961094.33   367380
# low                      2400000        3531094         2112843.86   605836
# justice_and_terror       2400000        3438317         1963099.70   570766
#
#                        2nd     3rd      DNF 1st Ratio 2nd Ratio 3rd Ratio  \
# jasper              633903  446879   712539    25.28%    26.41%    18.62%
# busse               703685  372956   176024    47.81%    29.32%    15.54%
# tim                 306431  457300  1386915    10.39%    12.77%    19.05%
# natasja             413769  476353  1142498    15.31%    17.24%    19.85%
# low                 633309  446968   713887    25.24%    26.39%    18.62%
# justice_and_terror  623714  478591   726929    23.78%    25.99%    19.94%
#
#                    DNF Ratio  Gem Eindpositie  Gem punten per game
# jasper                29.69%             2.53                 1.47
# busse                  7.33%             1.82                 2.18
# tim                   57.79%             3.24                 0.76
# natasja                47.6%             3.00                 1.00
# low                   29.75%             2.53                 1.47
# justice_and_terror    30.29%             2.57                 1.43
# Overwinningen vanaf verschillende startplekken:
# Punten en Podium verdeling:
# Performance per speler per combinatie van spelers:
